# %% [markdown]
# <a href="https://colab.research.google.com/github/bwsi-hadr/01-intro-to-python-dylan-pham/blob/master/01b_Intro_to_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Pandas
#
# Pandas is a package built on top of numpy which incorporates many additional features which make it more convenient for data analysis. One main addition is the inclusion of row and column labels, which make pandas function much like spreadsheet software. It also includes tools for much more complex computations than regular numpy allows

# %%
import pandas as pd
import numpy as np
# by default, pandas only shows the beginning and end of a large dataframe
# here we set it to 600 so that we see more of the dataframe
pd.options.display.max_rows = 600

# %% [markdown]
# ## Importing data
# There are a lot of built-in functions for importing data to pandas, for example, from files, database, and web sources. For a full list of the supported methods, see [the documentation on pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html).
#
# In this example, we're going to load data formatted as a csv from a website URL. In particular, it is a direct link to a file hosted in our course github repository.
#
# The data we're loading is a simplified pokedex which includes the number, name, base stats, types, abilities, and colors of each pokemon. We'll be using this data to explore the functionality of pandas.
#
# The primary class of pandas is the DataFrame, which functions like a spreadsheet (like in excel). It allows for named rows and columns. Data types between two different columns can vary, but entries within the same column should have the same type.

# %%
# URL for data
pokedex_url = 'https://raw.githubusercontent.com/bwsi-hadr/01-Intro-to-python/master/pokedex.csv?token=AK6STNOT3VACKCD37B6THDK5DYG4M' 
# instead of a url, you could instead put a path to a csv file on the local system where python is running. However, since colab is on the cloud, it's easier to use a url
pokedex_df = pd.read_csv(pokedex_url, index_col='Index') # create a dataframe from a csv, set the column titled "Index" as the row labels

pokedex_df = pokedex_df.fillna('') #fill in the NaN values with empty string 
pokedex_df # prints out the dataframe
# Out:
#                    Pokemon   HP  ...                    Hidden Ability   Color
# Index                            ...
# 1.0              Bulbasaur   45  ...                       Chlorophyll   Green
# 2.0                Ivysaur   60  ...                       Chlorophyll   Green
# 3.0               Venusaur   80  ...                       Chlorophyll   Green
# 4.0             Charmander   39  ...                       Solar Power     Red
# 5.0             Charmeleon   58  ...                       Solar Power     Red
# 6.0              Charizard   78  ...                       Solar Power     Red
# 7.0               Squirtle   44  ...                         Rain Dish    Blue
# 8.0              Wartortle   59  ...                         Rain Dish    Blue
# 9.0              Blastoise   79  ...                         Rain Dish    Blue
# 10.0              Caterpie   45  ...                          Run Away   Green
# 11.0               Metapod   50  ...                                     Green
# 12.0            Butterfree   60  ...                       Tinted Lens   White
# 13.0                Weedle   40  ...                          Run Away   Brown
# 14.0                Kakuna   45  ...                                    Yellow
# 15.0              Beedrill   65  ...                            Sniper  Yellow
# 16.0                Pidgey   40  ...                         Big Pecks   Brown
# 17.0             Pidgeotto   63  ...                         Big Pecks   Brown
# 18.0               Pidgeot   83  ...                         Big Pecks   Brown
# 19.0               Rattata   30  ...                            Hustle  Purple
# 20.0              Raticate   55  ...                            Hustle   Brown
# 21.0               Spearow   40  ...                            Sniper   Brown
# 22.0                Fearow   65  ...                            Sniper   Brown
# 23.0                 Ekans   30  ...                           Unnerve  Purple
# 24.0                 Arbok   60  ...                           Unnerve  Purple
# 26.0               Pikachu   35  ...                      Lightningrod  Yellow
# 27.0                Raichu   60  ...                      Lightningrod  Yellow
# 28.0             Sandshrew   50  ...                         Sand Rush  Yellow
# 29.0             Sandslash   75  ...                         Sand Rush  Yellow
# 30.0              Nidoran♀   55  ...                            Hustle    Blue
# 31.0              Nidorina   70  ...                            Hustle    Blue
# 32.0             Nidoqueen   90  ...                       Sheer Force    Blue
# 33.0              Nidoran♂   46  ...                            Hustle  Purple
# 34.0              Nidorino   61  ...                            Hustle  Purple
# 35.0              Nidoking   81  ...                       Sheer Force  Purple
# 37.0              Clefairy   70  ...                      Friend Guard    Pink
# 38.0              Clefable   95  ...                           Unaware    Pink
# 39.0                Vulpix   38  ...                           Drought   Brown
# 40.0             Ninetales   73  ...                           Drought  Yellow
# 42.0            Jigglypuff  115  ...                      Friend Guard    Pink
# 43.0            Wigglytuff  140  ...                             Frisk    Pink
# 44.0                 Zubat   40  ...                       Infiltrator  Purple
# 45.0                Golbat   75  ...                       Infiltrator  Purple
# 47.0                Oddish   45  ...                          Run Away    Blue
# 48.0                 Gloom   60  ...                            Stench    Blue
# 49.0             Vileplume   75  ...                      Effect Spore     Red
# 51.0                 Paras   35  ...                              Damp     Red
# 52.0              Parasect   60  ...                              Damp     Red
# 53.0               Venonat   60  ...                          Run Away  Purple
# 54.0              Venomoth   70  ...                       Wonder Skin  Purple
# 55.0               Diglett   10  ...                        Sand Force   Brown
# 56.0               Dugtrio   35  ...                        Sand Force   Brown
# 57.0                Meowth   40  ...                           Unnerve  Yellow
# 58.0               Persian   65  ...                           Unnerve  Yellow
# 59.0               Psyduck   50  ...                        Swift Swim  Yellow
# 60.0               Golduck   80  ...                        Swift Swim    Blue
# 61.0                Mankey   40  ...                           Defiant   Brown
# 62.0              Primeape   65  ...                           Defiant   Brown
# 63.0             Growlithe   55  ...                         Justified   Brown
# 64.0              Arcanine   90  ...                         Justified   Brown
# 65.0               Poliwag   40  ...                        Swift Swim    Blue
# 66.0             Poliwhirl   65  ...                        Swift Swim    Blue
# 67.0             Poliwrath   90  ...                        Swift Swim    Blue
# 69.0                  Abra   25  ...                       Magic Guard   Brown
# 70.0               Kadabra   40  ...                       Magic Guard   Brown
# 71.0              Alakazam   55  ...                       Magic Guard   Brown
# 72.0                Machop   70  ...                         Steadfast    Gray
# 73.0               Machoke   80  ...                         Steadfast    Gray
# 74.0               Machamp   90  ...                         Steadfast    Gray
# 75.0            Bellsprout   50  ...                          Gluttony   Green
# 76.0            Weepinbell   65  ...                          Gluttony   Green
# 77.0            Victreebel   80  ...                          Gluttony   Green
# 78.0             Tentacool   40  ...                         Rain Dish    Blue
# 79.0            Tentacruel   80  ...                         Rain Dish    Blue
# 80.0               Geodude   40  ...                         Sand Veil   Brown
# 81.0              Graveler   55  ...                         Sand Veil   Brown
# 82.0                 Golem   80  ...                         Sand Veil   Brown
# 83.0                Ponyta   50  ...                        Flame Body  Yellow
# 84.0              Rapidash   65  ...                        Flame Body  Yellow
# 85.0              Slowpoke   90  ...                       Regenerator    Pink
# 86.0               Slowbro   95  ...                       Regenerator    Pink
# 88.0             Magnemite   25  ...                          Analytic    Gray
# 89.0              Magneton   50  ...                          Analytic    Gray
# 91.0            Farfetch'd   52  ...                           Defiant   Brown
# 92.0                 Doduo   35  ...                      Tangled Feet   Brown
# 93.0                Dodrio   60  ...                      Tangled Feet   Brown
# 94.0                  Seel   65  ...                          Ice Body   White
# 95.0               Dewgong   90  ...                          Ice Body   White
# 96.0                Grimer   80  ...                      Poison Touch  Purple
# 97.0                   Muk  105  ...                      Poison Touch  Purple
# 98.0              Shellder   30  ...                          Overcoat  Purple
# 99.0              Cloyster   50  ...                          Overcoat  Purple
# 100.0               Gastly   30  ...                                    Purple
# 101.0              Haunter   45  ...                                    Purple
# 102.0               Gengar   60  ...                                    Purple
# 103.0                 Onix   35  ...                        Weak Armor    Gray
# 105.0              Drowzee   60  ...                       Inner Focus  Yellow
# 106.0                Hypno   85  ...                       Inner Focus  Yellow
# 107.0               Krabby   30  ...                       Sheer Force     Red
# 108.0              Kingler   55  ...                       Sheer Force     Red
# 109.0              Voltorb   40  ...                         Aftermath     Red
# 110.0            Electrode   60  ...                         Aftermath     Red
# 111.0            Exeggcute   60  ...                           Harvest    Pink
# 112.0            Exeggutor   95  ...                           Harvest  Yellow
# 113.0               Cubone   50  ...                      Battle Armor   Brown
# 114.0              Marowak   60  ...                      Battle Armor   Brown
# 116.0            Hitmonlee   50  ...                          Unburden   Brown
# 117.0           Hitmonchan   50  ...                       Inner Focus   Brown
# 119.0            Lickitung   90  ...                        Cloud Nine    Pink
# 121.0              Koffing   40  ...                                    Purple
# 122.0              Weezing   65  ...                                    Purple
# 123.0              Rhyhorn   80  ...                          Reckless    Gray
# 124.0               Rhydon  105  ...                          Reckless    Gray
# 127.0              Chansey  250  ...                            Healer    Pink
# 129.0              Tangela   65  ...                       Regenerator    Blue
# 131.0           Kangaskhan  105  ...                       Inner Focus   Brown
# 132.0               Horsea   30  ...                              Damp    Blue
# 133.0               Seadra   55  ...                              Damp    Blue
# 135.0              Goldeen   45  ...                      Lightningrod     Red
# 136.0              Seaking   80  ...                      Lightningrod     Red
# 137.0               Staryu   30  ...                          Analytic   Brown
# 138.0              Starmie   60  ...                          Analytic  Purple
# 140.0             Mr. Mime   40  ...                        Technician    Pink
# 141.0              Scyther   70  ...                         Steadfast   Green
# 144.0                 Jynx   65  ...                          Dry Skin     Red
# 146.0           Electabuzz   65  ...                      Vital Spirit  Yellow
# 149.0               Magmar   65  ...                      Vital Spirit     Red
# 151.0               Pinsir   65  ...                             Moxie   Brown
# 152.0               Tauros   75  ...                       Sheer Force   Brown
# 153.0             Magikarp   20  ...                           Rattled     Red
# 154.0             Gyarados   95  ...                             Moxie    Blue
# 155.0               Lapras  130  ...                         Hydration    Blue
# 156.0                Ditto   48  ...                          Imposter  Purple
# 157.0                Eevee   55  ...                      Anticipation   Brown
# 158.0             Vaporeon  130  ...                         Hydration    Blue
# 159.0              Jolteon   65  ...                        Quick Feet  Yellow
# 160.0              Flareon   65  ...                              Guts     Red
# 165.0              Porygon   65  ...                          Analytic    Pink
# 168.0              Omanyte   35  ...                        Weak Armor    Blue
# 169.0              Omastar   70  ...                        Weak Armor    Blue
# 170.0               Kabuto   30  ...                        Weak Armor   Brown
# 171.0             Kabutops   60  ...                        Weak Armor   Brown
# 172.0           Aerodactyl   80  ...                           Unnerve  Purple
# 174.0              Snorlax  160  ...                          Gluttony   Black
# 175.0             Articuno   90  ...                        Snow Cloak    Blue
# 176.0               Zapdos   90  ...                      Lightningrod  Yellow
# 177.0              Moltres   90  ...                        Flame Body  Yellow
# 178.0              Dratini   41  ...                      Marvel Scale    Blue
# 179.0            Dragonair   61  ...                      Marvel Scale    Blue
# 180.0            Dragonite   91  ...                        Multiscale   Brown
# 181.0               Mewtwo  106  ...                           Unnerve  Purple
# 182.0                  Mew  100  ...                                      Pink
# 183.0            Chikorita   45  ...                        Leaf Guard   Green
# 184.0              Bayleef   60  ...                        Leaf Guard   Green
# 185.0             Meganium   80  ...                        Leaf Guard   Green
# 186.0            Cyndaquil   39  ...                        Flash Fire  Yellow
# 187.0              Quilava   58  ...                        Flash Fire  Yellow
# 188.0           Typhlosion   78  ...                        Flash Fire  Yellow
# 189.0             Totodile   50  ...                       Sheer Force    Blue
# 190.0             Croconaw   65  ...                       Sheer Force    Blue
# 191.0           Feraligatr   85  ...                       Sheer Force    Blue
# 192.0              Sentret   35  ...                             Frisk   Brown
# 193.0               Furret   85  ...                             Frisk   Brown
# 194.0             Hoothoot   60  ...                       Tinted Lens   Brown
# 195.0              Noctowl  100  ...                       Tinted Lens   Brown
# 196.0               Ledyba   40  ...                           Rattled     Red
# 197.0               Ledian   55  ...                         Iron Fist     Red
# 198.0             Spinarak   40  ...                            Sniper   Green
# 199.0              Ariados   70  ...                            Sniper     Red
# 46.0                Crobat   85  ...                       Infiltrator  Purple
# 200.0             Chinchou   75  ...                      Water Absorb    Blue
# 201.0              Lanturn  125  ...                      Water Absorb    Blue
# 25.0                 Pichu   20  ...                      Lightningrod  Yellow
# 36.0                Cleffa   50  ...                      Friend Guard    Pink
# 41.0             Igglybuff   90  ...                      Friend Guard    Pink
# 202.0               Togepi   35  ...                        Super Luck   White
# 203.0              Togetic   55  ...                        Super Luck   White
# 205.0                 Natu   40  ...                      Magic Bounce   Green
# 206.0                 Xatu   65  ...                      Magic Bounce   Green
# 207.0               Mareep   55  ...                              Plus   White
# 208.0              Flaaffy   70  ...                              Plus    Pink
# 209.0             Ampharos   90  ...                              Plus  Yellow
# 50.0             Bellossom   75  ...                            Healer   Green
# 211.0               Marill   70  ...                        Sap Sipper    Blue
# 212.0            Azumarill  100  ...                        Sap Sipper    Blue
# 214.0            Sudowoodo   70  ...                           Rattled   Brown
# 68.0              Politoed   90  ...                           Drizzle   Green
# 215.0               Hoppip   35  ...                       Infiltrator    Pink
# 216.0             Skiploom   55  ...                       Infiltrator   Green
# 217.0             Jumpluff   75  ...                       Infiltrator    Blue
# 218.0                Aipom   55  ...                        Skill Link  Purple
# 220.0              Sunkern   30  ...                        Early Bird  Yellow
# 221.0             Sunflora   75  ...                        Early Bird  Yellow
# 222.0                Yanma   65  ...                             Frisk     Red
# 224.0               Wooper   55  ...                           Unaware    Blue
# 225.0             Quagsire   95  ...                           Unaware    Blue
# 161.0               Espeon   65  ...                      Magic Bounce  Purple
# 162.0              Umbreon   95  ...                       Inner Focus   Black
# 226.0              Murkrow   60  ...                         Prankster   Black
# 87.0              Slowking   95  ...                       Regenerator    Pink
# 228.0           Misdreavus   60  ...                                      Gray
# 230.0                Unown   48  ...                                     Black
# 232.0            Wobbuffet  190  ...                         Telepathy    Blue
# 233.0            Girafarig   70  ...                        Sap Sipper  Yellow
# 234.0               Pineco   50  ...                          Overcoat    Gray
# 235.0           Forretress   75  ...                          Overcoat  Purple
# 236.0            Dunsparce  100  ...                           Rattled  Yellow
# 237.0               Gligar   65  ...                          Immunity  Purple
# 104.0              Steelix   75  ...                       Sheer Force    Gray
# 239.0             Snubbull   60  ...                           Rattled    Pink
# 240.0             Granbull   90  ...                           Rattled  Purple
# 241.0             Qwilfish   65  ...                        Intimidate    Gray
# 142.0               Scizor   70  ...                       Light Metal     Red
# 242.0              Shuckle   20  ...                          Contrary  Yellow
# 243.0            Heracross   80  ...                             Moxie    Blue
# 244.0              Sneasel   55  ...                        Pickpocket   Black
# 246.0            Teddiursa   60  ...                      Honey Gather   Brown
# 247.0             Ursaring   90  ...                           Unnerve   Brown
# 248.0               Slugma   40  ...                        Weak Armor     Red
# 249.0             Magcargo   50  ...                        Weak Armor     Red
# 250.0               Swinub   50  ...                         Thick Fat   Brown
# 251.0            Piloswine  100  ...                         Thick Fat   Brown
# 253.0              Corsola   55  ...                       Regenerator    Pink
# 254.0             Remoraid   35  ...                             Moody    Gray
# 255.0            Octillery   75  ...                             Moody     Red
# 256.0             Delibird   45  ...                          Insomnia     Red
# 258.0              Mantine   65  ...                        Water Veil  Purple
# 259.0             Skarmory   65  ...                        Weak Armor    Gray
# 260.0             Houndour   45  ...                           Unnerve   Black
# 261.0             Houndoom   75  ...                           Unnerve   Black
# 134.0              Kingdra   75  ...                              Damp    Blue
# 262.0               Phanpy   90  ...                         Sand Veil    Blue
# 263.0              Donphan   90  ...                         Sand Veil    Gray
# 166.0             Porygon2   85  ...                          Analytic     Red
# 264.0             Stantler   73  ...                        Sap Sipper   Brown
# 265.0             Smeargle   55  ...                             Moody   White
# 115.0              Tyrogue   35  ...                      Vital Spirit  Purple
# 118.0            Hitmontop   50  ...                         Steadfast   Brown
# 143.0             Smoochum   45  ...                         Hydration    Pink
# 145.0               Elekid   45  ...                      Vital Spirit  Yellow
# 148.0                Magby   45  ...                      Vital Spirit     Red
# 266.0              Miltank   95  ...                        Sap Sipper    Pink
# 128.0              Blissey  255  ...                            Healer    Pink
# 267.0               Raikou   90  ...                       Volt Absorb  Yellow
# 268.0                Entei  115  ...                        Flash Fire   Brown
# 269.0              Suicune  100  ...                      Water Absorb    Blue
# 270.0             Larvitar   50  ...                         Sand Veil   Green
# 271.0              Pupitar   70  ...                                      Gray
# 272.0            Tyranitar  100  ...                           Unnerve   Green
# 273.0                Lugia  106  ...                        Multiscale   White
# 274.0                Ho-oh  106  ...                       Regenerator     Red
# 275.0               Celebi  100  ...                                     Green
# 276.0              Treecko   40  ...                          Unburden   Green
# 277.0              Grovyle   50  ...                          Unburden   Green
# 278.0             Sceptile   70  ...                          Unburden   Green
# 279.0              Torchic   45  ...                       Speed Boost     Red
# 280.0            Combusken   60  ...                       Speed Boost     Red
# 281.0             Blaziken   80  ...                       Speed Boost     Red
# 282.0               Mudkip   50  ...                              Damp    Blue
# 283.0            Marshtomp   70  ...                              Damp    Blue
# 284.0             Swampert  100  ...                              Damp    Blue
# 285.0            Poochyena   35  ...                           Rattled    Gray
# 286.0            Mightyena   70  ...                             Moxie    Gray
# 287.0            Zigzagoon   38  ...                        Quick Feet   Brown
# 288.0              Linoone   78  ...                        Quick Feet   White
# 289.0              Wurmple   45  ...                          Run Away     Red
# 290.0              Silcoon   50  ...                                     White
# 291.0            Beautifly   60  ...                           Rivalry  Yellow
# 292.0              Cascoon   50  ...                                    Purple
# 293.0               Dustox   60  ...                      Compoundeyes   Green
# 294.0                Lotad   40  ...                         Own Tempo   Green
# 295.0               Lombre   60  ...                         Own Tempo   Green
# 296.0             Ludicolo   80  ...                         Own Tempo   Green
# 297.0               Seedot   40  ...                        Pickpocket   Brown
# 298.0              Nuzleaf   70  ...                        Pickpocket   Brown
# 299.0              Shiftry   90  ...                        Pickpocket   Brown
# 300.0              Taillow   40  ...                           Scrappy    Blue
# 301.0              Swellow   60  ...                           Scrappy    Blue
# 302.0              Wingull   40  ...                         Rain Dish   White
# 303.0             Pelipper   60  ...                         Rain Dish  Yellow
# 304.0                Ralts   28  ...                         Telepathy   White
# 305.0               Kirlia   38  ...                         Telepathy   White
# 306.0            Gardevoir   68  ...                         Telepathy   White
# 308.0              Surskit   40  ...                         Rain Dish    Blue
# 309.0           Masquerain   70  ...                           Unnerve    Blue
# 310.0            Shroomish   60  ...                        Quick Feet   Brown
# 311.0              Breloom   60  ...                        Technician   Green
# 312.0              Slakoth   60  ...                                     Brown
# 313.0             Vigoroth   80  ...                                     White
# 314.0              Slaking  150  ...                                     Brown
# 315.0              Nincada   31  ...                          Run Away    Gray
# 316.0              Ninjask   61  ...                       Infiltrator  Yellow
# 317.0             Shedinja    1  ...                                     Brown
# 318.0              Whismur   64  ...                           Rattled    Pink
# 319.0              Loudred   84  ...                           Scrappy    Blue
# 320.0              Exploud  104  ...                           Scrappy    Blue
# 321.0             Makuhita   72  ...                       Sheer Force  Yellow
# 322.0             Hariyama  144  ...                       Sheer Force   Brown
# 210.0              Azurill   50  ...                        Sap Sipper    Blue
# 323.0             Nosepass   30  ...                        Sand Force    Gray
# 325.0               Skitty   50  ...                       Wonder Skin    Pink
# ...                    ...  ...  ...                               ...     ...
# 509.0             Purrloin   41  ...                         Prankster  Purple
# 510.0              Liepard   64  ...                         Prankster  Purple
# 511.0              Pansage   50  ...                          Overgrow   Green
# 512.0             Simisage   75  ...                          Overgrow   Green
# 513.0              Pansear   50  ...                             Blaze     Red
# 514.0             Simisear   75  ...                             Blaze     Red
# 515.0              Panpour   50  ...                           Torrent    Blue
# 516.0             Simipour   75  ...                           Torrent    Blue
# 517.0                Munna   76  ...                         Telepathy    Pink
# 518.0             Musharna  116  ...                         Telepathy    Pink
# 519.0               Pidove   50  ...                           Rivalry    Gray
# 520.0            Tranquill   62  ...                           Rivalry    Gray
# 521.0             Unfezant   80  ...                           Rivalry    Gray
# 522.0              Blitzle   45  ...                        Sap Sipper   Black
# 523.0            Zebstrika   75  ...                        Sap Sipper   Black
# 524.0           Roggenrola   55  ...                        Sand Force    Blue
# 525.0              Boldore   70  ...                        Sand Force    Blue
# 526.0             Gigalith   85  ...                        Sand Force    Blue
# 527.0               Woobat   55  ...                            Simple    Blue
# 528.0              Swoobat   67  ...                            Simple    Blue
# 529.0              Drilbur   60  ...                      Mold Breaker    Gray
# 530.0            Excadrill  110  ...                      Mold Breaker    Gray
# 531.0               Audino  103  ...                             Klutz    Pink
# 532.0              Timburr   75  ...                         Iron Fist    Gray
# 533.0              Gurdurr   85  ...                         Iron Fist    Gray
# 534.0           Conkeldurr  105  ...                         Iron Fist   Brown
# 535.0              Tympole   50  ...                      Water Absorb    Blue
# 536.0            Palpitoad   75  ...                      Water Absorb    Blue
# 537.0           Seismitoad  105  ...                      Water Absorb    Blue
# 538.0                Throh  120  ...                      Mold Breaker     Red
# 539.0                 Sawk   75  ...                      Mold Breaker    Blue
# 540.0             Sewaddle   45  ...                          Overcoat  Yellow
# 541.0             Swadloon   55  ...                          Overcoat   Green
# 542.0             Leavanny   75  ...                          Overcoat  Yellow
# 543.0             Venipede   30  ...                        Quick Feet     Red
# 544.0           Whirlipede   40  ...                        Quick Feet    Gray
# 545.0            Scolipede   60  ...                        Quick Feet     Red
# 546.0             Cottonee   40  ...                       Chlorophyll   Green
# 547.0           Whimsicott   60  ...                       Chlorophyll   Green
# 548.0              Petilil   45  ...                        Leaf Guard   Green
# 549.0            Lilligant   70  ...                        Leaf Guard   Green
# 550.0             Basculin   70  ...                      Mold Breaker   Green
# 551.0              Sandile   50  ...                       Anger Point   Brown
# 552.0             Krokorok   60  ...                       Anger Point   Brown
# 553.0           Krookodile   95  ...                       Anger Point     Red
# 554.0             Darumaka   70  ...                       Inner Focus     Red
# 555.0           Darmanitan  105  ...                          Zen Mode     Red
# 555.1       Darmanitan (Z)  105  ...                          Zen Mode     Red
# 556.0             Maractus   75  ...                       Storm Drain   Green
# 557.0              Dwebble   50  ...                        Weak Armor     Red
# 558.0              Crustle   70  ...                        Weak Armor     Red
# 559.0              Scraggy   50  ...                        Intimidate  Yellow
# 560.0              Scrafty   65  ...                        Intimidate     Red
# 561.0             Sigilyph   72  ...                       Tinted Lens   Black
# 562.0               Yamask   38  ...                                     Black
# 563.0           Cofagrigus   58  ...                                    Yellow
# 564.0             Tirtouga   54  ...                        Swift Swim    Blue
# 565.0           Carracosta   74  ...                        Swift Swim    Blue
# 566.0               Archen   55  ...                                    Yellow
# 567.0             Archeops   75  ...                                    Yellow
# 568.0             Trubbish   50  ...                         Aftermath   Green
# 569.0             Garbodor   80  ...                         Aftermath   Green
# 570.0                Zorua   40  ...                                      Gray
# 571.0              Zoroark   60  ...                                      Gray
# 572.0             Minccino   55  ...                        Skill Link    Gray
# 573.0             Cinccino   75  ...                        Skill Link    Gray
# 574.0              Gothita   45  ...                        Shadow Tag  Purple
# 575.0            Gothorita   60  ...                        Shadow Tag  Purple
# 576.0           Gothitelle   70  ...                        Shadow Tag  Purple
# 577.0              Solosis   45  ...                       Regenerator   Green
# 578.0              Duosion   65  ...                       Regenerator   Green
# 579.0            Reuniclus  110  ...                       Regenerator   Green
# 580.0             Ducklett   62  ...                         Hydration    Blue
# 581.0               Swanna   75  ...                         Hydration   White
# 582.0            Vanillite   36  ...                        Weak Armor   White
# 583.0            Vanillish   51  ...                        Weak Armor   White
# 584.0            Vanilluxe   71  ...                        Weak Armor   White
# 585.0             Deerling   60  ...                      Serene Grace  Yellow
# 586.0             Sawsbuck   80  ...                      Serene Grace   Brown
# 587.0               Emolga   55  ...                       Motor Drive   White
# 588.0           Karrablast   50  ...                          No Guard    Blue
# 589.0           Escavalier   70  ...                          Overcoat    Gray
# 590.0              Foongus   69  ...                       Regenerator   White
# 591.0            Amoonguss  114  ...                       Regenerator   White
# 592.0             Frillish   55  ...                                     White
# 593.0            Jellicent  100  ...                              Damp   White
# 594.0            Alomomola  165  ...                       Regenerator    Pink
# 595.0               Joltik   50  ...                             Swarm  Yellow
# 596.0           Galvantula   70  ...                             Swarm  Yellow
# 597.0            Ferroseed   44  ...                                      Gray
# 598.0           Ferrothorn   74  ...                                      Gray
# 599.0                Klink   40  ...                        Clear Body    Gray
# 600.0                Klang   60  ...                        Clear Body    Gray
# 601.0            Klinklang   60  ...                        Clear Body    Gray
# 602.0               Tynamo   35  ...                                     White
# 603.0            Eelektrik   65  ...                                      Blue
# 604.0           Eelektross   85  ...                                      Blue
# 605.0               Elgyem   55  ...                          Analytic    Blue
# 606.0             Beheeyem   75  ...                          Analytic   Brown
# 607.0              Litwick   50  ...                        Shadow Tag   White
# 608.0              Lampent   60  ...                        Shadow Tag   Black
# 609.0           Chandelure   60  ...                        Shadow Tag   Black
# 610.0                 Axew   46  ...                           Unnerve   Green
# 611.0              Fraxure   66  ...                           Unnerve   Green
# 612.0              Haxorus   76  ...                           Unnerve  Yellow
# 613.0              Cubchoo   55  ...                           Rattled   White
# 614.0              Beartic   95  ...                        Swift Swim   White
# 615.0            Cryogonal   70  ...                                      Blue
# 616.0              Shelmet   50  ...                          Overcoat     Red
# 617.0             Accelgor   80  ...                          Unburden     Red
# 618.0             Stunfisk  109  ...                         Sand Veil   Brown
# 619.0              Mienfoo   45  ...                          Reckless  Yellow
# 620.0             Mienshao   65  ...                          Reckless  Purple
# 621.0            Druddigon   77  ...                      Mold Breaker     Red
# 622.0               Golett   59  ...                          No Guard   Green
# 623.0               Golurk   89  ...                          No Guard   Green
# 624.0             Pawniard   45  ...                          Pressure     Red
# 625.0              Bisharp   65  ...                          Pressure     Red
# 626.0           Bouffalant   95  ...                        Soundproof   Brown
# 627.0              Rufflet   70  ...                            Hustle   White
# 628.0             Braviary  100  ...                           Defiant     Red
# 629.0              Vullaby   70  ...                        Weak Armor   Brown
# 630.0            Mandibuzz  110  ...                        Weak Armor   Brown
# 631.0              Heatmor   85  ...                       White Smoke     Red
# 632.0               Durant   58  ...                            Truant    Gray
# 633.0                Deino   52  ...                                      Blue
# 634.0             Zweilous   72  ...                                      Blue
# 635.0            Hydreigon   92  ...                                      Blue
# 636.0             Larvesta   55  ...                             Swarm   White
# 637.0            Volcarona   85  ...                             Swarm   White
# 638.0             Cobalion   91  ...                                      Blue
# 639.0            Terrakion   91  ...                                      Gray
# 640.0             Virizion   91  ...                                     Green
# 641.0             Tornadus   79  ...                           Defiant   Green
# 642.0            Thundurus   79  ...                           Defiant    Blue
# 643.0             Reshiram  100  ...                                     White
# 644.0               Zekrom  100  ...                                     Black
# 645.0             Landorus   89  ...                       Sheer Force   Brown
# 646.0               Kyurem  125  ...                                      Gray
# 647.0               Keldeo   91  ...                                    Yellow
# 648.0         Meloetta (A)  100  ...                                     White
# 648.1         Meloetta (P)  100  ...                                     White
# 649.0             Genesect   71  ...                                    Purple
# 650.0              Chespin   56  ...                       Bulletproof   Green
# 651.0            Quilladin   61  ...                       Bulletproof   Green
# 652.0           Chesnaught   88  ...                       Bulletproof   Green
# 653.0             Fennekin   40  ...                          Magician     Red
# 654.0              Braixen   59  ...                          Magician     Red
# 655.0              Delphox   75  ...                          Magician     Red
# 656.0              Froakie   41  ...                           Protean    Blue
# 657.0            Frogadier   54  ...                           Protean    Blue
# 658.0             Greninja   72  ...                           Protean    Blue
# 659.0             Bunnelby   38  ...                        Huge Power   Brown
# 660.0            Diggersby   85  ...                        Huge Power   Brown
# 661.0           Fletchling   45  ...                        Gale Wings     Red
# 662.0          Fletchinder   62  ...                        Gale Wings     Red
# 663.0           Talonflame   78  ...                        Gale Wings     Red
# 664.0           Scatterbug   38  ...                      Friend Guard   Black
# 665.0               Spewpa   45  ...                      Friend Guard   Black
# 666.0             Vivillon   80  ...                      Friend Guard   Black
# 667.0               Litleo   62  ...                             Moxie   Brown
# 668.0               Pyroar   86  ...                             Moxie   Brown
# 669.0              Flabébé   44  ...                         Symbiosis   White
# 670.0              Floette   54  ...                         Symbiosis   White
# 671.0              Florges   78  ...                         Symbiosis   White
# 672.0               Skiddo   66  ...                        Grass Pelt   Brown
# 673.0               Gogoat  123  ...                        Grass Pelt   Brown
# 674.0              Pancham   67  ...                           Scrappy   White
# 675.0              Pangoro   95  ...                           Scrappy   White
# 676.0              Furfrou   75  ...                                     White
# 677.0               Espurr   62  ...                         Own Tempo    Gray
# 678.0             Meowstic   74  ...  Prankster (M) or Competitive (F)   White
# 679.0              Honedge   45  ...                                     Brown
# 680.0             Doublade   59  ...                                     Brown
# 681.0            Aegislash   60  ...                                     Brown
# 682.0             Spritzee   78  ...                        Aroma Veil    Pink
# 683.0           Aromatisse  101  ...                        Aroma Veil    Pink
# 684.0              Swirlix   62  ...                          Unburden   White
# 685.0             Slurpuff   82  ...                          Unburden   White
# 686.0                Inkay   53  ...                       Infiltrator    Blue
# 687.0              Malamar   86  ...                       Infiltrator    Blue
# 688.0              Binacle   42  ...                        Pickpocket   Brown
# 689.0           Barbaracle   72  ...                        Pickpocket   Brown
# 690.0               Skrelp   50  ...                      Adaptability   Brown
# 691.0             Dragalge   65  ...                      Adaptability   Brown
# 692.0            Clauncher   50  ...                                      Blue
# 693.0            Clawitzer   71  ...                                      Blue
# 694.0           Helioptile   44  ...                       Solar Power  Yellow
# 695.0            Heliolisk   62  ...                       Solar Power  Yellow
# 696.0               Tyrunt   58  ...                            Sturdy   Brown
# 697.0            Tyrantrum   82  ...                            Sturdy     Red
# 698.0               Amaura   77  ...                      Snow Warning    Blue
# 699.0              Aurorus  123  ...                      Snow Warning    Blue
# 700.0              Sylveon   95  ...                          Pixilate    Pink
# 701.0             Hawlucha   78  ...                      Mold Breaker   Green
# 702.0              Dedenne   67  ...                              Plus  Yellow
# 703.0              Carbink   50  ...                            Sturdy    Gray
# 704.0                Goomy   45  ...                             Gooey  Purple
# 705.0              Sliggoo   68  ...                             Gooey  Purple
# 706.0               Goodra   90  ...                             Gooey  Purple
# 707.0               Klefki   57  ...                          Magician    Gray
# 708.0             Phantump   43  ...                           Harvest   Brown
# 709.0            Trevenant   85  ...                           Harvest   Brown
# 710.0            Pumpkaboo   44  ...                          Insomnia   Brown
# 711.0            Gourgeist   55  ...                          Insomnia   Brown
# 712.0             Bergmite   55  ...                            Sturdy    Blue
# 713.0              Avalugg   95  ...                            Sturdy    Blue
# 714.0               Noibat   40  ...                         Telepathy  Purple
# 715.0              Noivern   85  ...                         Telepathy  Purple
# 716.0              Xerneas  126  ...                                      Blue
# 717.0              Yveltal  126  ...                                       Red
# 718.0              Zygarde  108  ...                                     Green
# 719.0              Diancie   50  ...               Magic Bounce (Mega)    Pink
# 720.0            Hoopa (C)   80  ...                                    Purple
# 720.0            Hoopa (U)   80  ...                                    Purple
# 721.0            Volcanion   80  ...                                     Brown
# 722.0               Rowlet   68  ...                                     Brown
# 723.0              Dartrix   78  ...                                     Brown
# 724.0            Decidueye   78  ...                                     Brown
# 725.0               Litten   45  ...                                       Red
# 726.0             Torracat   65  ...                                       Red
# 727.0           Incineroar   95  ...                                       Red
# 728.0              Popplio   50  ...                                      Blue
# 729.0              Brionne   60  ...                                      Blue
# 730.0            Primarina   80  ...                                      Blue
# 731.0              Pikipek   35  ...                            Pickup   Black
# 732.0             Trumbeak   55  ...                            Pickup   Black
# 733.0            Toucannon   80  ...                       Sheer Force   Black
# 734.0              Yungoos   48  ...                      Adaptability   Brown
# 735.0             Gumshoos   88  ...                      Adaptability   Brown
# 736.0              Grubbin   47  ...                                      Gray
# 737.0            Charjabug   57  ...                                     Green
# 738.0             Vikavolt   77  ...                                      Blue
# 739.0           Crabrawler   47  ...                       Anger Point  Purple
# 740.0         Crabominable   97  ...                       Anger Point   White
# 741.0             Oricorio   75  ...                                       Red
# 742.0             Cutiefly   40  ...                        Sweet Veil  Yellow
# 743.0             Ribombee   60  ...                        Sweet Veil  Yellow
# 744.0             Rockruff   45  ...                         Steadfast   Brown
# 745.0    Lycanroc (midday)   75  ...                         Steadfast
# 745.1  Lycanroc (midnight)   85  ...                          No Guard   Brown
# 746.0    Wishiwashi (solo)   45  ...                                      Blue
# 746.1  Wishiwashi (school)   45  ...                                      Blue
# 747.0             Mareanie   50  ...                       Regenerator    Blue
# 748.0              Toxapex   50  ...                       Regenerator    Blue
# 749.0              Mudbray   70  ...                       Inner Focus   Brown
# 750.0             Mudsdale  100  ...                       Inner Focus   Brown
# 751.0             Dewpider   38  ...                      Water Absorb   Green
# 752.0            Araquanid   68  ...                      Water Absorb   Green
# 753.0             Fomantis   40  ...                          Contrary    Pink
# 754.0             Lurantis   70  ...                          Contrary    Pink
# 755.0             Morelull   40  ...                         Rain Dish  Purple
# 756.0            Shiinotic   60  ...                         Rain Dish  Purple
# 757.0             Salandit   48  ...                         Oblivious   Black
# 758.0             Salazzle   68  ...                         Oblivious   Black
# 759.0              Stufful   70  ...                        Cute Charm    Pink
# 760.0               Bewear  120  ...                           Unnerve    Pink
# 761.0            Bounsweet   42  ...                        Sweet Veil  Purple
# 762.0              Steenee   52  ...                        Sweet Veil  Purple
# 763.0             Tsareena   72  ...                        Sweet Veil  Purple
# 764.0               Comfey   51  ...                      Natural Cure   Green
# 765.0             Oranguru   90  ...                                     White
# 766.0            Passimian  100  ...                                     White
# 767.0               Wimpod   25  ...                                      Gray
# 768.0            Golisopod   75  ...                                      Gray
# 769.0            Sandygast   55  ...                         Sand Veil   Brown
# 770.0            Palossand   85  ...                         Sand Veil   Brown
# 771.0            Pyukumuku   55  ...                           Unaware   Black
# 772.0           Type: Null   95  ...                                      Gray
# 773.0             Silvally   95  ...                                      Gray
# 774.0      Minior (meteor)   60  ...                                     Brown
# 774.1        Minior (core)   60  ...                                      Pink
# 775.0               Komala   65  ...                                      Blue
# 776.0           Turtonator   60  ...                                       Red
# 777.0           Togedemaru   65  ...                            Sturdy    Gray
# 778.0              Mimikyu   55  ...                                    Yellow
# 779.0              Bruxish   68  ...                       Wonder Skin    Pink
# 780.0               Drampa   78  ...                        Cloud Nine   White
# 781.0             Dhelmise   70  ...                                     Green
# 782.0             Jangmo-o   45  ...                          Overcoat    Gray
# 783.0             Hakamo-o   55  ...                          Overcoat    Gray
# 784.0              Kommo-o   75  ...                          Overcoat    Gray
# 785.0            Tapu Koko   70  ...                                    Yellow
# 786.0            Tapu Lele   70  ...                                      Pink
# 787.0            Tapu Bulu   70  ...                                       Red
# 788.0            Tapu Fini   70  ...                                    Purple
# 789.0               Cosmog   43  ...                                      Blue
# 790.0              Cosmoem   43  ...                                      Blue
# 791.0             Solgaleo  137  ...                                     White
# 792.0               Lunala  137  ...                                    Purple
# 793.0             Nihilego  109  ...                                     White
# 794.0             Buzzwole  107  ...                                       Red
# 795.0            Pheromosa   71  ...                                     White
# 796.0            Xurkitree   83  ...                                     Black
# 797.0           Celesteela   97  ...                                     Green
# 798.0              Kartana   59  ...                                     White
# 799.0             Guzzlord  223  ...                                     Black
# 800.0             Necrozma   97  ...                                     Black
# 801.0             Magearna   80  ...                                      Gray
# 802.0            Marshadow   90  ...                                      Gray
#
# [820 rows x 14 columns]

# %% [markdown]
# ## Indexing
# Like numpy, you can index a dataframe to select elements or subsets of entries. There are a number of ways to index pandas dataframes. The two following methods are recommended:
# `.loc[]` and `.iloc[]`

# %% [markdown]
# ### .loc[ ] name-based indexing
# The first way, using `.loc[a,b]` indexes based on the __values__ of the row index and column names. This allows us to get entries where the row index value equals `a` and the column name equals `b`.

# %%
# Get the entry for index value 745.1
pokedex_df.loc[745.1]
# Out:
# Pokemon           Lycanroc (midnight)
# HP                                 85
# Atk                               115
# Def                                75
# SpAtk                              55
# SpDef                              75
# Speed                              82
# Total                             487
# Type I                           Rock
# Type II
# Ability I                    Keen Eye
# Ability II              Vital Spirit
# Hidden Ability               No Guard
# Color                           Brown
# Name: 745.1, dtype: object

# %%
pokedex_df.iloc[0]
# Out:
# Pokemon             Bulbasaur
# HP                         45
# Atk                        49
# Def                        49
# SpAtk                      65
# SpDef                      65
# Speed                      45
# Total                     318
# Type I                  Grass
# Type II                Poison
# Ability I            Overgrow
# Ability II
# Hidden Ability    Chlorophyll
# Color                   Green
# Name: 1.0, dtype: object

# %%
# You can get specific column values for a single entry
pokedex_df.loc[250,['Pokemon','Type I','Type II']]
# Out:
# Pokemon    Swinub
# Type I        Ice
# Type II    Ground
# Name: 250.0, dtype: object

# %%
# you can use the : notation to slice multiple rows and columns
pokedex_df.loc[690:700,'Pokemon':'Total']
# Out:
#           Pokemon   HP  Atk  Def  SpAtk  SpDef  Speed  Total
# Index
# 690.0      Skrelp   50   60   60     60     60     30    320
# 691.0    Dragalge   65   75   90     97    123     44    494
# 692.0   Clauncher   50   53   62     58     63     44    330
# 693.0   Clawitzer   71   73   88    120     89     59    500
# 694.0  Helioptile   44   38   33     61     43     70    289
# 695.0   Heliolisk   62   55   52    109     94    109    481
# 696.0      Tyrunt   58   89   77     45     45     48    362
# 697.0   Tyrantrum   82  121  119     69     59     71    521
# 698.0      Amaura   77   59   50     67     63     46    362
# 699.0     Aurorus  123   77   72     99     92     58    521
# 700.0     Sylveon   95   65   65    110    130     60    525

# %%
# Similarly to numpy, you can use the : notation without indices on a side to mean "from beginning" or "to end"
pokedex_df.loc[:10,"Ability I":]
# Out:
#          Ability I Ability II Hidden Ability  Color
# Index
# 1.0       Overgrow               Chlorophyll  Green
# 2.0       Overgrow               Chlorophyll  Green
# 3.0       Overgrow               Chlorophyll  Green
# 4.0          Blaze               Solar Power    Red
# 5.0          Blaze               Solar Power    Red
# 6.0          Blaze               Solar Power    Red
# 7.0        Torrent                 Rain Dish   Blue
# 8.0        Torrent                 Rain Dish   Blue
# 9.0        Torrent                 Rain Dish   Blue
# 10.0   Shield Dust                  Run Away  Green

# %%
# and : by itself gives all of the entries in that dimension
pokedex_df.loc[:,'Pokemon'].head(10) #just return top 10 entries
# Out:
# Index
# 1.0      Bulbasaur
# 2.0        Ivysaur
# 3.0       Venusaur
# 4.0     Charmander
# 5.0     Charmeleon
# 6.0      Charizard
# 7.0       Squirtle
# 8.0      Wartortle
# 9.0      Blastoise
# 10.0      Caterpie
# Name: Pokemon, dtype: object

# %% [markdown]
# ### .iloc[ ] integer indexing
#
# The second way, using `.iloc[i,j]` uses the numpy-style integer indices to get a value. In this case, iloc takes integer values from 0 to the number of entries in that dimension.
#
# Like numpy, `.iloc[i,j]` gives the entry at the $i^{th}$ row and $j^{th}$ column.

# %%
pokedex_df.iloc[100] # gets 101st row (recall python counts from 0)
# Out:
# Pokemon            Electrode
# HP                        60
# Atk                       50
# Def                       70
# SpAtk                     80
# SpDef                     80
# Speed                    140
# Total                    480
# Type I              Electric
# Type II
# Ability I         Soundproof
# Ability II            Static
# Hidden Ability     Aftermath
# Color                    Red
# Name: 110.0, dtype: object

# %%
# The : style indexing also works for iloc
pokedex_df.iloc[25:30, 0:8]
# Out:
#          Pokemon  HP  Atk  Def  SpAtk  SpDef  Speed  Total
# Index
# 27.0      Raichu  60   90   55     90     80    100    475
# 28.0   Sandshrew  50   75   85     20     30     40    300
# 29.0   Sandslash  75  100  110     45     55     65    450
# 30.0    Nidoran♀  55   47   52     40     40     41    275
# 31.0    Nidorina  70   62   67     55     55     56    365

# %% [markdown]
# ## Adding columns, rows, and changing values
# You can add another column like:
# ```
# dataframe['NewColumnName'] = value
# ```
# `value` can be a single value, an array of the same size as the index of `dataframe`, a pandas `Series`, or a dictionary mapping `index: value` for entries in the dataframe index

# %%
pokedex_df['Nickname'] = None
pokedex_df
# Out:
#                    Pokemon   HP  ...   Color  Nickname
# Index                            ...
# 1.0              Bulbasaur   45  ...   Green      None
# 2.0                Ivysaur   60  ...   Green      None
# 3.0               Venusaur   80  ...   Green      None
# 4.0             Charmander   39  ...     Red      None
# 5.0             Charmeleon   58  ...     Red      None
# 6.0              Charizard   78  ...     Red      None
# 7.0               Squirtle   44  ...    Blue      None
# 8.0              Wartortle   59  ...    Blue      None
# 9.0              Blastoise   79  ...    Blue      None
# 10.0              Caterpie   45  ...   Green      None
# 11.0               Metapod   50  ...   Green      None
# 12.0            Butterfree   60  ...   White      None
# 13.0                Weedle   40  ...   Brown      None
# 14.0                Kakuna   45  ...  Yellow      None
# 15.0              Beedrill   65  ...  Yellow      None
# 16.0                Pidgey   40  ...   Brown      None
# 17.0             Pidgeotto   63  ...   Brown      None
# 18.0               Pidgeot   83  ...   Brown      None
# 19.0               Rattata   30  ...  Purple      None
# 20.0              Raticate   55  ...   Brown      None
# 21.0               Spearow   40  ...   Brown      None
# 22.0                Fearow   65  ...   Brown      None
# 23.0                 Ekans   30  ...  Purple      None
# 24.0                 Arbok   60  ...  Purple      None
# 26.0               Pikachu   35  ...  Yellow      None
# 27.0                Raichu   60  ...  Yellow      None
# 28.0             Sandshrew   50  ...  Yellow      None
# 29.0             Sandslash   75  ...  Yellow      None
# 30.0              Nidoran♀   55  ...    Blue      None
# 31.0              Nidorina   70  ...    Blue      None
# 32.0             Nidoqueen   90  ...    Blue      None
# 33.0              Nidoran♂   46  ...  Purple      None
# 34.0              Nidorino   61  ...  Purple      None
# 35.0              Nidoking   81  ...  Purple      None
# 37.0              Clefairy   70  ...    Pink      None
# 38.0              Clefable   95  ...    Pink      None
# 39.0                Vulpix   38  ...   Brown      None
# 40.0             Ninetales   73  ...  Yellow      None
# 42.0            Jigglypuff  115  ...    Pink      None
# 43.0            Wigglytuff  140  ...    Pink      None
# 44.0                 Zubat   40  ...  Purple      None
# 45.0                Golbat   75  ...  Purple      None
# 47.0                Oddish   45  ...    Blue      None
# 48.0                 Gloom   60  ...    Blue      None
# 49.0             Vileplume   75  ...     Red      None
# 51.0                 Paras   35  ...     Red      None
# 52.0              Parasect   60  ...     Red      None
# 53.0               Venonat   60  ...  Purple      None
# 54.0              Venomoth   70  ...  Purple      None
# 55.0               Diglett   10  ...   Brown      None
# 56.0               Dugtrio   35  ...   Brown      None
# 57.0                Meowth   40  ...  Yellow      None
# 58.0               Persian   65  ...  Yellow      None
# 59.0               Psyduck   50  ...  Yellow      None
# 60.0               Golduck   80  ...    Blue      None
# 61.0                Mankey   40  ...   Brown      None
# 62.0              Primeape   65  ...   Brown      None
# 63.0             Growlithe   55  ...   Brown      None
# 64.0              Arcanine   90  ...   Brown      None
# 65.0               Poliwag   40  ...    Blue      None
# 66.0             Poliwhirl   65  ...    Blue      None
# 67.0             Poliwrath   90  ...    Blue      None
# 69.0                  Abra   25  ...   Brown      None
# 70.0               Kadabra   40  ...   Brown      None
# 71.0              Alakazam   55  ...   Brown      None
# 72.0                Machop   70  ...    Gray      None
# 73.0               Machoke   80  ...    Gray      None
# 74.0               Machamp   90  ...    Gray      None
# 75.0            Bellsprout   50  ...   Green      None
# 76.0            Weepinbell   65  ...   Green      None
# 77.0            Victreebel   80  ...   Green      None
# 78.0             Tentacool   40  ...    Blue      None
# 79.0            Tentacruel   80  ...    Blue      None
# 80.0               Geodude   40  ...   Brown      None
# 81.0              Graveler   55  ...   Brown      None
# 82.0                 Golem   80  ...   Brown      None
# 83.0                Ponyta   50  ...  Yellow      None
# 84.0              Rapidash   65  ...  Yellow      None
# 85.0              Slowpoke   90  ...    Pink      None
# 86.0               Slowbro   95  ...    Pink      None
# 88.0             Magnemite   25  ...    Gray      None
# 89.0              Magneton   50  ...    Gray      None
# 91.0            Farfetch'd   52  ...   Brown      None
# 92.0                 Doduo   35  ...   Brown      None
# 93.0                Dodrio   60  ...   Brown      None
# 94.0                  Seel   65  ...   White      None
# 95.0               Dewgong   90  ...   White      None
# 96.0                Grimer   80  ...  Purple      None
# 97.0                   Muk  105  ...  Purple      None
# 98.0              Shellder   30  ...  Purple      None
# 99.0              Cloyster   50  ...  Purple      None
# 100.0               Gastly   30  ...  Purple      None
# 101.0              Haunter   45  ...  Purple      None
# 102.0               Gengar   60  ...  Purple      None
# 103.0                 Onix   35  ...    Gray      None
# 105.0              Drowzee   60  ...  Yellow      None
# 106.0                Hypno   85  ...  Yellow      None
# 107.0               Krabby   30  ...     Red      None
# 108.0              Kingler   55  ...     Red      None
# 109.0              Voltorb   40  ...     Red      None
# 110.0            Electrode   60  ...     Red      None
# 111.0            Exeggcute   60  ...    Pink      None
# 112.0            Exeggutor   95  ...  Yellow      None
# 113.0               Cubone   50  ...   Brown      None
# 114.0              Marowak   60  ...   Brown      None
# 116.0            Hitmonlee   50  ...   Brown      None
# 117.0           Hitmonchan   50  ...   Brown      None
# 119.0            Lickitung   90  ...    Pink      None
# 121.0              Koffing   40  ...  Purple      None
# 122.0              Weezing   65  ...  Purple      None
# 123.0              Rhyhorn   80  ...    Gray      None
# 124.0               Rhydon  105  ...    Gray      None
# 127.0              Chansey  250  ...    Pink      None
# 129.0              Tangela   65  ...    Blue      None
# 131.0           Kangaskhan  105  ...   Brown      None
# 132.0               Horsea   30  ...    Blue      None
# 133.0               Seadra   55  ...    Blue      None
# 135.0              Goldeen   45  ...     Red      None
# 136.0              Seaking   80  ...     Red      None
# 137.0               Staryu   30  ...   Brown      None
# 138.0              Starmie   60  ...  Purple      None
# 140.0             Mr. Mime   40  ...    Pink      None
# 141.0              Scyther   70  ...   Green      None
# 144.0                 Jynx   65  ...     Red      None
# 146.0           Electabuzz   65  ...  Yellow      None
# 149.0               Magmar   65  ...     Red      None
# 151.0               Pinsir   65  ...   Brown      None
# 152.0               Tauros   75  ...   Brown      None
# 153.0             Magikarp   20  ...     Red      None
# 154.0             Gyarados   95  ...    Blue      None
# 155.0               Lapras  130  ...    Blue      None
# 156.0                Ditto   48  ...  Purple      None
# 157.0                Eevee   55  ...   Brown      None
# 158.0             Vaporeon  130  ...    Blue      None
# 159.0              Jolteon   65  ...  Yellow      None
# 160.0              Flareon   65  ...     Red      None
# 165.0              Porygon   65  ...    Pink      None
# 168.0              Omanyte   35  ...    Blue      None
# 169.0              Omastar   70  ...    Blue      None
# 170.0               Kabuto   30  ...   Brown      None
# 171.0             Kabutops   60  ...   Brown      None
# 172.0           Aerodactyl   80  ...  Purple      None
# 174.0              Snorlax  160  ...   Black      None
# 175.0             Articuno   90  ...    Blue      None
# 176.0               Zapdos   90  ...  Yellow      None
# 177.0              Moltres   90  ...  Yellow      None
# 178.0              Dratini   41  ...    Blue      None
# 179.0            Dragonair   61  ...    Blue      None
# 180.0            Dragonite   91  ...   Brown      None
# 181.0               Mewtwo  106  ...  Purple      None
# 182.0                  Mew  100  ...    Pink      None
# 183.0            Chikorita   45  ...   Green      None
# 184.0              Bayleef   60  ...   Green      None
# 185.0             Meganium   80  ...   Green      None
# 186.0            Cyndaquil   39  ...  Yellow      None
# 187.0              Quilava   58  ...  Yellow      None
# 188.0           Typhlosion   78  ...  Yellow      None
# 189.0             Totodile   50  ...    Blue      None
# 190.0             Croconaw   65  ...    Blue      None
# 191.0           Feraligatr   85  ...    Blue      None
# 192.0              Sentret   35  ...   Brown      None
# 193.0               Furret   85  ...   Brown      None
# 194.0             Hoothoot   60  ...   Brown      None
# 195.0              Noctowl  100  ...   Brown      None
# 196.0               Ledyba   40  ...     Red      None
# 197.0               Ledian   55  ...     Red      None
# 198.0             Spinarak   40  ...   Green      None
# 199.0              Ariados   70  ...     Red      None
# 46.0                Crobat   85  ...  Purple      None
# 200.0             Chinchou   75  ...    Blue      None
# 201.0              Lanturn  125  ...    Blue      None
# 25.0                 Pichu   20  ...  Yellow      None
# 36.0                Cleffa   50  ...    Pink      None
# 41.0             Igglybuff   90  ...    Pink      None
# 202.0               Togepi   35  ...   White      None
# 203.0              Togetic   55  ...   White      None
# 205.0                 Natu   40  ...   Green      None
# 206.0                 Xatu   65  ...   Green      None
# 207.0               Mareep   55  ...   White      None
# 208.0              Flaaffy   70  ...    Pink      None
# 209.0             Ampharos   90  ...  Yellow      None
# 50.0             Bellossom   75  ...   Green      None
# 211.0               Marill   70  ...    Blue      None
# 212.0            Azumarill  100  ...    Blue      None
# 214.0            Sudowoodo   70  ...   Brown      None
# 68.0              Politoed   90  ...   Green      None
# 215.0               Hoppip   35  ...    Pink      None
# 216.0             Skiploom   55  ...   Green      None
# 217.0             Jumpluff   75  ...    Blue      None
# 218.0                Aipom   55  ...  Purple      None
# 220.0              Sunkern   30  ...  Yellow      None
# 221.0             Sunflora   75  ...  Yellow      None
# 222.0                Yanma   65  ...     Red      None
# 224.0               Wooper   55  ...    Blue      None
# 225.0             Quagsire   95  ...    Blue      None
# 161.0               Espeon   65  ...  Purple      None
# 162.0              Umbreon   95  ...   Black      None
# 226.0              Murkrow   60  ...   Black      None
# 87.0              Slowking   95  ...    Pink      None
# 228.0           Misdreavus   60  ...    Gray      None
# 230.0                Unown   48  ...   Black      None
# 232.0            Wobbuffet  190  ...    Blue      None
# 233.0            Girafarig   70  ...  Yellow      None
# 234.0               Pineco   50  ...    Gray      None
# 235.0           Forretress   75  ...  Purple      None
# 236.0            Dunsparce  100  ...  Yellow      None
# 237.0               Gligar   65  ...  Purple      None
# 104.0              Steelix   75  ...    Gray      None
# 239.0             Snubbull   60  ...    Pink      None
# 240.0             Granbull   90  ...  Purple      None
# 241.0             Qwilfish   65  ...    Gray      None
# 142.0               Scizor   70  ...     Red      None
# 242.0              Shuckle   20  ...  Yellow      None
# 243.0            Heracross   80  ...    Blue      None
# 244.0              Sneasel   55  ...   Black      None
# 246.0            Teddiursa   60  ...   Brown      None
# 247.0             Ursaring   90  ...   Brown      None
# 248.0               Slugma   40  ...     Red      None
# 249.0             Magcargo   50  ...     Red      None
# 250.0               Swinub   50  ...   Brown      None
# 251.0            Piloswine  100  ...   Brown      None
# 253.0              Corsola   55  ...    Pink      None
# 254.0             Remoraid   35  ...    Gray      None
# 255.0            Octillery   75  ...     Red      None
# 256.0             Delibird   45  ...     Red      None
# 258.0              Mantine   65  ...  Purple      None
# 259.0             Skarmory   65  ...    Gray      None
# 260.0             Houndour   45  ...   Black      None
# 261.0             Houndoom   75  ...   Black      None
# 134.0              Kingdra   75  ...    Blue      None
# 262.0               Phanpy   90  ...    Blue      None
# 263.0              Donphan   90  ...    Gray      None
# 166.0             Porygon2   85  ...     Red      None
# 264.0             Stantler   73  ...   Brown      None
# 265.0             Smeargle   55  ...   White      None
# 115.0              Tyrogue   35  ...  Purple      None
# 118.0            Hitmontop   50  ...   Brown      None
# 143.0             Smoochum   45  ...    Pink      None
# 145.0               Elekid   45  ...  Yellow      None
# 148.0                Magby   45  ...     Red      None
# 266.0              Miltank   95  ...    Pink      None
# 128.0              Blissey  255  ...    Pink      None
# 267.0               Raikou   90  ...  Yellow      None
# 268.0                Entei  115  ...   Brown      None
# 269.0              Suicune  100  ...    Blue      None
# 270.0             Larvitar   50  ...   Green      None
# 271.0              Pupitar   70  ...    Gray      None
# 272.0            Tyranitar  100  ...   Green      None
# 273.0                Lugia  106  ...   White      None
# 274.0                Ho-oh  106  ...     Red      None
# 275.0               Celebi  100  ...   Green      None
# 276.0              Treecko   40  ...   Green      None
# 277.0              Grovyle   50  ...   Green      None
# 278.0             Sceptile   70  ...   Green      None
# 279.0              Torchic   45  ...     Red      None
# 280.0            Combusken   60  ...     Red      None
# 281.0             Blaziken   80  ...     Red      None
# 282.0               Mudkip   50  ...    Blue      None
# 283.0            Marshtomp   70  ...    Blue      None
# 284.0             Swampert  100  ...    Blue      None
# 285.0            Poochyena   35  ...    Gray      None
# 286.0            Mightyena   70  ...    Gray      None
# 287.0            Zigzagoon   38  ...   Brown      None
# 288.0              Linoone   78  ...   White      None
# 289.0              Wurmple   45  ...     Red      None
# 290.0              Silcoon   50  ...   White      None
# 291.0            Beautifly   60  ...  Yellow      None
# 292.0              Cascoon   50  ...  Purple      None
# 293.0               Dustox   60  ...   Green      None
# 294.0                Lotad   40  ...   Green      None
# 295.0               Lombre   60  ...   Green      None
# 296.0             Ludicolo   80  ...   Green      None
# 297.0               Seedot   40  ...   Brown      None
# 298.0              Nuzleaf   70  ...   Brown      None
# 299.0              Shiftry   90  ...   Brown      None
# 300.0              Taillow   40  ...    Blue      None
# 301.0              Swellow   60  ...    Blue      None
# 302.0              Wingull   40  ...   White      None
# 303.0             Pelipper   60  ...  Yellow      None
# 304.0                Ralts   28  ...   White      None
# 305.0               Kirlia   38  ...   White      None
# 306.0            Gardevoir   68  ...   White      None
# 308.0              Surskit   40  ...    Blue      None
# 309.0           Masquerain   70  ...    Blue      None
# 310.0            Shroomish   60  ...   Brown      None
# 311.0              Breloom   60  ...   Green      None
# 312.0              Slakoth   60  ...   Brown      None
# 313.0             Vigoroth   80  ...   White      None
# 314.0              Slaking  150  ...   Brown      None
# 315.0              Nincada   31  ...    Gray      None
# 316.0              Ninjask   61  ...  Yellow      None
# 317.0             Shedinja    1  ...   Brown      None
# 318.0              Whismur   64  ...    Pink      None
# 319.0              Loudred   84  ...    Blue      None
# 320.0              Exploud  104  ...    Blue      None
# 321.0             Makuhita   72  ...  Yellow      None
# 322.0             Hariyama  144  ...   Brown      None
# 210.0              Azurill   50  ...    Blue      None
# 323.0             Nosepass   30  ...    Gray      None
# 325.0               Skitty   50  ...    Pink      None
# ...                    ...  ...  ...     ...       ...
# 509.0             Purrloin   41  ...  Purple      None
# 510.0              Liepard   64  ...  Purple      None
# 511.0              Pansage   50  ...   Green      None
# 512.0             Simisage   75  ...   Green      None
# 513.0              Pansear   50  ...     Red      None
# 514.0             Simisear   75  ...     Red      None
# 515.0              Panpour   50  ...    Blue      None
# 516.0             Simipour   75  ...    Blue      None
# 517.0                Munna   76  ...    Pink      None
# 518.0             Musharna  116  ...    Pink      None
# 519.0               Pidove   50  ...    Gray      None
# 520.0            Tranquill   62  ...    Gray      None
# 521.0             Unfezant   80  ...    Gray      None
# 522.0              Blitzle   45  ...   Black      None
# 523.0            Zebstrika   75  ...   Black      None
# 524.0           Roggenrola   55  ...    Blue      None
# 525.0              Boldore   70  ...    Blue      None
# 526.0             Gigalith   85  ...    Blue      None
# 527.0               Woobat   55  ...    Blue      None
# 528.0              Swoobat   67  ...    Blue      None
# 529.0              Drilbur   60  ...    Gray      None
# 530.0            Excadrill  110  ...    Gray      None
# 531.0               Audino  103  ...    Pink      None
# 532.0              Timburr   75  ...    Gray      None
# 533.0              Gurdurr   85  ...    Gray      None
# 534.0           Conkeldurr  105  ...   Brown      None
# 535.0              Tympole   50  ...    Blue      None
# 536.0            Palpitoad   75  ...    Blue      None
# 537.0           Seismitoad  105  ...    Blue      None
# 538.0                Throh  120  ...     Red      None
# 539.0                 Sawk   75  ...    Blue      None
# 540.0             Sewaddle   45  ...  Yellow      None
# 541.0             Swadloon   55  ...   Green      None
# 542.0             Leavanny   75  ...  Yellow      None
# 543.0             Venipede   30  ...     Red      None
# 544.0           Whirlipede   40  ...    Gray      None
# 545.0            Scolipede   60  ...     Red      None
# 546.0             Cottonee   40  ...   Green      None
# 547.0           Whimsicott   60  ...   Green      None
# 548.0              Petilil   45  ...   Green      None
# 549.0            Lilligant   70  ...   Green      None
# 550.0             Basculin   70  ...   Green      None
# 551.0              Sandile   50  ...   Brown      None
# 552.0             Krokorok   60  ...   Brown      None
# 553.0           Krookodile   95  ...     Red      None
# 554.0             Darumaka   70  ...     Red      None
# 555.0           Darmanitan  105  ...     Red      None
# 555.1       Darmanitan (Z)  105  ...     Red      None
# 556.0             Maractus   75  ...   Green      None
# 557.0              Dwebble   50  ...     Red      None
# 558.0              Crustle   70  ...     Red      None
# 559.0              Scraggy   50  ...  Yellow      None
# 560.0              Scrafty   65  ...     Red      None
# 561.0             Sigilyph   72  ...   Black      None
# 562.0               Yamask   38  ...   Black      None
# 563.0           Cofagrigus   58  ...  Yellow      None
# 564.0             Tirtouga   54  ...    Blue      None
# 565.0           Carracosta   74  ...    Blue      None
# 566.0               Archen   55  ...  Yellow      None
# 567.0             Archeops   75  ...  Yellow      None
# 568.0             Trubbish   50  ...   Green      None
# 569.0             Garbodor   80  ...   Green      None
# 570.0                Zorua   40  ...    Gray      None
# 571.0              Zoroark   60  ...    Gray      None
# 572.0             Minccino   55  ...    Gray      None
# 573.0             Cinccino   75  ...    Gray      None
# 574.0              Gothita   45  ...  Purple      None
# 575.0            Gothorita   60  ...  Purple      None
# 576.0           Gothitelle   70  ...  Purple      None
# 577.0              Solosis   45  ...   Green      None
# 578.0              Duosion   65  ...   Green      None
# 579.0            Reuniclus  110  ...   Green      None
# 580.0             Ducklett   62  ...    Blue      None
# 581.0               Swanna   75  ...   White      None
# 582.0            Vanillite   36  ...   White      None
# 583.0            Vanillish   51  ...   White      None
# 584.0            Vanilluxe   71  ...   White      None
# 585.0             Deerling   60  ...  Yellow      None
# 586.0             Sawsbuck   80  ...   Brown      None
# 587.0               Emolga   55  ...   White      None
# 588.0           Karrablast   50  ...    Blue      None
# 589.0           Escavalier   70  ...    Gray      None
# 590.0              Foongus   69  ...   White      None
# 591.0            Amoonguss  114  ...   White      None
# 592.0             Frillish   55  ...   White      None
# 593.0            Jellicent  100  ...   White      None
# 594.0            Alomomola  165  ...    Pink      None
# 595.0               Joltik   50  ...  Yellow      None
# 596.0           Galvantula   70  ...  Yellow      None
# 597.0            Ferroseed   44  ...    Gray      None
# 598.0           Ferrothorn   74  ...    Gray      None
# 599.0                Klink   40  ...    Gray      None
# 600.0                Klang   60  ...    Gray      None
# 601.0            Klinklang   60  ...    Gray      None
# 602.0               Tynamo   35  ...   White      None
# 603.0            Eelektrik   65  ...    Blue      None
# 604.0           Eelektross   85  ...    Blue      None
# 605.0               Elgyem   55  ...    Blue      None
# 606.0             Beheeyem   75  ...   Brown      None
# 607.0              Litwick   50  ...   White      None
# 608.0              Lampent   60  ...   Black      None
# 609.0           Chandelure   60  ...   Black      None
# 610.0                 Axew   46  ...   Green      None
# 611.0              Fraxure   66  ...   Green      None
# 612.0              Haxorus   76  ...  Yellow      None
# 613.0              Cubchoo   55  ...   White      None
# 614.0              Beartic   95  ...   White      None
# 615.0            Cryogonal   70  ...    Blue      None
# 616.0              Shelmet   50  ...     Red      None
# 617.0             Accelgor   80  ...     Red      None
# 618.0             Stunfisk  109  ...   Brown      None
# 619.0              Mienfoo   45  ...  Yellow      None
# 620.0             Mienshao   65  ...  Purple      None
# 621.0            Druddigon   77  ...     Red      None
# 622.0               Golett   59  ...   Green      None
# 623.0               Golurk   89  ...   Green      None
# 624.0             Pawniard   45  ...     Red      None
# 625.0              Bisharp   65  ...     Red      None
# 626.0           Bouffalant   95  ...   Brown      None
# 627.0              Rufflet   70  ...   White      None
# 628.0             Braviary  100  ...     Red      None
# 629.0              Vullaby   70  ...   Brown      None
# 630.0            Mandibuzz  110  ...   Brown      None
# 631.0              Heatmor   85  ...     Red      None
# 632.0               Durant   58  ...    Gray      None
# 633.0                Deino   52  ...    Blue      None
# 634.0             Zweilous   72  ...    Blue      None
# 635.0            Hydreigon   92  ...    Blue      None
# 636.0             Larvesta   55  ...   White      None
# 637.0            Volcarona   85  ...   White      None
# 638.0             Cobalion   91  ...    Blue      None
# 639.0            Terrakion   91  ...    Gray      None
# 640.0             Virizion   91  ...   Green      None
# 641.0             Tornadus   79  ...   Green      None
# 642.0            Thundurus   79  ...    Blue      None
# 643.0             Reshiram  100  ...   White      None
# 644.0               Zekrom  100  ...   Black      None
# 645.0             Landorus   89  ...   Brown      None
# 646.0               Kyurem  125  ...    Gray      None
# 647.0               Keldeo   91  ...  Yellow      None
# 648.0         Meloetta (A)  100  ...   White      None
# 648.1         Meloetta (P)  100  ...   White      None
# 649.0             Genesect   71  ...  Purple      None
# 650.0              Chespin   56  ...   Green      None
# 651.0            Quilladin   61  ...   Green      None
# 652.0           Chesnaught   88  ...   Green      None
# 653.0             Fennekin   40  ...     Red      None
# 654.0              Braixen   59  ...     Red      None
# 655.0              Delphox   75  ...     Red      None
# 656.0              Froakie   41  ...    Blue      None
# 657.0            Frogadier   54  ...    Blue      None
# 658.0             Greninja   72  ...    Blue      None
# 659.0             Bunnelby   38  ...   Brown      None
# 660.0            Diggersby   85  ...   Brown      None
# 661.0           Fletchling   45  ...     Red      None
# 662.0          Fletchinder   62  ...     Red      None
# 663.0           Talonflame   78  ...     Red      None
# 664.0           Scatterbug   38  ...   Black      None
# 665.0               Spewpa   45  ...   Black      None
# 666.0             Vivillon   80  ...   Black      None
# 667.0               Litleo   62  ...   Brown      None
# 668.0               Pyroar   86  ...   Brown      None
# 669.0              Flabébé   44  ...   White      None
# 670.0              Floette   54  ...   White      None
# 671.0              Florges   78  ...   White      None
# 672.0               Skiddo   66  ...   Brown      None
# 673.0               Gogoat  123  ...   Brown      None
# 674.0              Pancham   67  ...   White      None
# 675.0              Pangoro   95  ...   White      None
# 676.0              Furfrou   75  ...   White      None
# 677.0               Espurr   62  ...    Gray      None
# 678.0             Meowstic   74  ...   White      None
# 679.0              Honedge   45  ...   Brown      None
# 680.0             Doublade   59  ...   Brown      None
# 681.0            Aegislash   60  ...   Brown      None
# 682.0             Spritzee   78  ...    Pink      None
# 683.0           Aromatisse  101  ...    Pink      None
# 684.0              Swirlix   62  ...   White      None
# 685.0             Slurpuff   82  ...   White      None
# 686.0                Inkay   53  ...    Blue      None
# 687.0              Malamar   86  ...    Blue      None
# 688.0              Binacle   42  ...   Brown      None
# 689.0           Barbaracle   72  ...   Brown      None
# 690.0               Skrelp   50  ...   Brown      None
# 691.0             Dragalge   65  ...   Brown      None
# 692.0            Clauncher   50  ...    Blue      None
# 693.0            Clawitzer   71  ...    Blue      None
# 694.0           Helioptile   44  ...  Yellow      None
# 695.0            Heliolisk   62  ...  Yellow      None
# 696.0               Tyrunt   58  ...   Brown      None
# 697.0            Tyrantrum   82  ...     Red      None
# 698.0               Amaura   77  ...    Blue      None
# 699.0              Aurorus  123  ...    Blue      None
# 700.0              Sylveon   95  ...    Pink      None
# 701.0             Hawlucha   78  ...   Green      None
# 702.0              Dedenne   67  ...  Yellow      None
# 703.0              Carbink   50  ...    Gray      None
# 704.0                Goomy   45  ...  Purple      None
# 705.0              Sliggoo   68  ...  Purple      None
# 706.0               Goodra   90  ...  Purple      None
# 707.0               Klefki   57  ...    Gray      None
# 708.0             Phantump   43  ...   Brown      None
# 709.0            Trevenant   85  ...   Brown      None
# 710.0            Pumpkaboo   44  ...   Brown      None
# 711.0            Gourgeist   55  ...   Brown      None
# 712.0             Bergmite   55  ...    Blue      None
# 713.0              Avalugg   95  ...    Blue      None
# 714.0               Noibat   40  ...  Purple      None
# 715.0              Noivern   85  ...  Purple      None
# 716.0              Xerneas  126  ...    Blue      None
# 717.0              Yveltal  126  ...     Red      None
# 718.0              Zygarde  108  ...   Green      None
# 719.0              Diancie   50  ...    Pink      None
# 720.0            Hoopa (C)   80  ...  Purple      None
# 720.0            Hoopa (U)   80  ...  Purple      None
# 721.0            Volcanion   80  ...   Brown      None
# 722.0               Rowlet   68  ...   Brown      None
# 723.0              Dartrix   78  ...   Brown      None
# 724.0            Decidueye   78  ...   Brown      None
# 725.0               Litten   45  ...     Red      None
# 726.0             Torracat   65  ...     Red      None
# 727.0           Incineroar   95  ...     Red      None
# 728.0              Popplio   50  ...    Blue      None
# 729.0              Brionne   60  ...    Blue      None
# 730.0            Primarina   80  ...    Blue      None
# 731.0              Pikipek   35  ...   Black      None
# 732.0             Trumbeak   55  ...   Black      None
# 733.0            Toucannon   80  ...   Black      None
# 734.0              Yungoos   48  ...   Brown      None
# 735.0             Gumshoos   88  ...   Brown      None
# 736.0              Grubbin   47  ...    Gray      None
# 737.0            Charjabug   57  ...   Green      None
# 738.0             Vikavolt   77  ...    Blue      None
# 739.0           Crabrawler   47  ...  Purple      None
# 740.0         Crabominable   97  ...   White      None
# 741.0             Oricorio   75  ...     Red      None
# 742.0             Cutiefly   40  ...  Yellow      None
# 743.0             Ribombee   60  ...  Yellow      None
# 744.0             Rockruff   45  ...   Brown      None
# 745.0    Lycanroc (midday)   75  ...              None
# 745.1  Lycanroc (midnight)   85  ...   Brown      None
# 746.0    Wishiwashi (solo)   45  ...    Blue      None
# 746.1  Wishiwashi (school)   45  ...    Blue      None
# 747.0             Mareanie   50  ...    Blue      None
# 748.0              Toxapex   50  ...    Blue      None
# 749.0              Mudbray   70  ...   Brown      None
# 750.0             Mudsdale  100  ...   Brown      None
# 751.0             Dewpider   38  ...   Green      None
# 752.0            Araquanid   68  ...   Green      None
# 753.0             Fomantis   40  ...    Pink      None
# 754.0             Lurantis   70  ...    Pink      None
# 755.0             Morelull   40  ...  Purple      None
# 756.0            Shiinotic   60  ...  Purple      None
# 757.0             Salandit   48  ...   Black      None
# 758.0             Salazzle   68  ...   Black      None
# 759.0              Stufful   70  ...    Pink      None
# 760.0               Bewear  120  ...    Pink      None
# 761.0            Bounsweet   42  ...  Purple      None
# 762.0              Steenee   52  ...  Purple      None
# 763.0             Tsareena   72  ...  Purple      None
# 764.0               Comfey   51  ...   Green      None
# 765.0             Oranguru   90  ...   White      None
# 766.0            Passimian  100  ...   White      None
# 767.0               Wimpod   25  ...    Gray      None
# 768.0            Golisopod   75  ...    Gray      None
# 769.0            Sandygast   55  ...   Brown      None
# 770.0            Palossand   85  ...   Brown      None
# 771.0            Pyukumuku   55  ...   Black      None
# 772.0           Type: Null   95  ...    Gray      None
# 773.0             Silvally   95  ...    Gray      None
# 774.0      Minior (meteor)   60  ...   Brown      None
# 774.1        Minior (core)   60  ...    Pink      None
# 775.0               Komala   65  ...    Blue      None
# 776.0           Turtonator   60  ...     Red      None
# 777.0           Togedemaru   65  ...    Gray      None
# 778.0              Mimikyu   55  ...  Yellow      None
# 779.0              Bruxish   68  ...    Pink      None
# 780.0               Drampa   78  ...   White      None
# 781.0             Dhelmise   70  ...   Green      None
# 782.0             Jangmo-o   45  ...    Gray      None
# 783.0             Hakamo-o   55  ...    Gray      None
# 784.0              Kommo-o   75  ...    Gray      None
# 785.0            Tapu Koko   70  ...  Yellow      None
# 786.0            Tapu Lele   70  ...    Pink      None
# 787.0            Tapu Bulu   70  ...     Red      None
# 788.0            Tapu Fini   70  ...  Purple      None
# 789.0               Cosmog   43  ...    Blue      None
# 790.0              Cosmoem   43  ...    Blue      None
# 791.0             Solgaleo  137  ...   White      None
# 792.0               Lunala  137  ...  Purple      None
# 793.0             Nihilego  109  ...   White      None
# 794.0             Buzzwole  107  ...     Red      None
# 795.0            Pheromosa   71  ...   White      None
# 796.0            Xurkitree   83  ...   Black      None
# 797.0           Celesteela   97  ...   Green      None
# 798.0              Kartana   59  ...   White      None
# 799.0             Guzzlord  223  ...   Black      None
# 800.0             Necrozma   97  ...   Black      None
# 801.0             Magearna   80  ...    Gray      None
# 802.0            Marshadow   90  ...    Gray      None
#
# [820 rows x 15 columns]

# %%
# you can change the value of an entry using indexing and assignment =
pokedex_df.loc[4,'Nickname'] = 'Abby' # indexing using .loc[] pokedex entry 4, 'Nickname column'
pokedex_df.iloc[113,-1] = 'Terry' # indexing using .iloc[] 113rd row, last column
pokedex_df.iloc[[3,113],:] # item at row 3 and 113
# Out:
#           Pokemon  HP  Atk  Def  ...  Ability II  Hidden Ability  Color  Nickname
# Index                            ...
# 4.0    Charmander  39   52   43  ...                 Solar Power    Red      Abby
# 129.0     Tangela  65   55  115  ...  Leaf Guard     Regenerator   Blue     Terry
#
# [2 rows x 15 columns]

# %%
# you can add another dataframe on to the end using append()
new_pokemon = pd.DataFrame([{'Pokemon':'Grookey', 'Type I':'Grass', 'Color':'Green'},
                            {'Pokemon':'Scorbunny', 'Type I':'Fire', 'Color':'Red'},
                            {'Pokemon':'Sobble', 'Type I':'Water', 'Color':'Blue'}], 
                           index=[803.0, 804.0, 805.0]) # create a dataframe with new entries using a list of dictionaries
pokedex_df = pokedex_df.append(new_pokemon, sort=False) # the sort=False keyword prevents the columns from being reordered alphabetically
pokedex_df = pokedex_df.fillna('').drop_duplicates() # some cleanup operations, replace NaN with emptry strings, and drop duplicate rows
pokedex_df.tail()
# Out:
#          Pokemon  HP  Atk  Def  ... Ability II Hidden Ability  Color Nickname
# 801.0   Magearna  80   95  115  ...                             Gray
# 802.0  Marshadow  90  125   80  ...                             Gray
# 803.0    Grookey                ...                            Green
# 804.0  Scorbunny                ...                              Red
# 805.0     Sobble                ...                             Blue
#
# [5 rows x 15 columns]

# %% [markdown]
# ## Changing index column
# You can change the index column of the dataframe with `.set_index()` or reset it to default numerical indexing with `.reset_index()`.
#
# Note however, that these operations create a __copy__ of the original dataframe, and do not change the dataframe "in place" (i.e. doesn't change the original object)

# %%
# reset index to be default numerical index
reindexed_pokedex = pokedex_df.reset_index()
reindexed_pokedex
# Out:
#      index              Pokemon  ...   Color Nickname
# 0      1.0            Bulbasaur  ...   Green
# 1      2.0              Ivysaur  ...   Green
# 2      3.0             Venusaur  ...   Green
# 3      4.0           Charmander  ...     Red     Abby
# 4      5.0           Charmeleon  ...     Red
# 5      6.0            Charizard  ...     Red
# 6      7.0             Squirtle  ...    Blue
# 7      8.0            Wartortle  ...    Blue
# 8      9.0            Blastoise  ...    Blue
# 9     10.0             Caterpie  ...   Green
# 10    11.0              Metapod  ...   Green
# 11    12.0           Butterfree  ...   White
# 12    13.0               Weedle  ...   Brown
# 13    14.0               Kakuna  ...  Yellow
# 14    15.0             Beedrill  ...  Yellow
# 15    16.0               Pidgey  ...   Brown
# 16    17.0            Pidgeotto  ...   Brown
# 17    18.0              Pidgeot  ...   Brown
# 18    19.0              Rattata  ...  Purple
# 19    20.0             Raticate  ...   Brown
# 20    21.0              Spearow  ...   Brown
# 21    22.0               Fearow  ...   Brown
# 22    23.0                Ekans  ...  Purple
# 23    24.0                Arbok  ...  Purple
# 24    26.0              Pikachu  ...  Yellow
# 25    27.0               Raichu  ...  Yellow
# 26    28.0            Sandshrew  ...  Yellow
# 27    29.0            Sandslash  ...  Yellow
# 28    30.0             Nidoran♀  ...    Blue
# 29    31.0             Nidorina  ...    Blue
# 30    32.0            Nidoqueen  ...    Blue
# 31    33.0             Nidoran♂  ...  Purple
# 32    34.0             Nidorino  ...  Purple
# 33    35.0             Nidoking  ...  Purple
# 34    37.0             Clefairy  ...    Pink
# 35    38.0             Clefable  ...    Pink
# 36    39.0               Vulpix  ...   Brown
# 37    40.0            Ninetales  ...  Yellow
# 38    42.0           Jigglypuff  ...    Pink
# 39    43.0           Wigglytuff  ...    Pink
# 40    44.0                Zubat  ...  Purple
# 41    45.0               Golbat  ...  Purple
# 42    47.0               Oddish  ...    Blue
# 43    48.0                Gloom  ...    Blue
# 44    49.0            Vileplume  ...     Red
# 45    51.0                Paras  ...     Red
# 46    52.0             Parasect  ...     Red
# 47    53.0              Venonat  ...  Purple
# 48    54.0             Venomoth  ...  Purple
# 49    55.0              Diglett  ...   Brown
# 50    56.0              Dugtrio  ...   Brown
# 51    57.0               Meowth  ...  Yellow
# 52    58.0              Persian  ...  Yellow
# 53    59.0              Psyduck  ...  Yellow
# 54    60.0              Golduck  ...    Blue
# 55    61.0               Mankey  ...   Brown
# 56    62.0             Primeape  ...   Brown
# 57    63.0            Growlithe  ...   Brown
# 58    64.0             Arcanine  ...   Brown
# 59    65.0              Poliwag  ...    Blue
# 60    66.0            Poliwhirl  ...    Blue
# 61    67.0            Poliwrath  ...    Blue
# 62    69.0                 Abra  ...   Brown
# 63    70.0              Kadabra  ...   Brown
# 64    71.0             Alakazam  ...   Brown
# 65    72.0               Machop  ...    Gray
# 66    73.0              Machoke  ...    Gray
# 67    74.0              Machamp  ...    Gray
# 68    75.0           Bellsprout  ...   Green
# 69    76.0           Weepinbell  ...   Green
# 70    77.0           Victreebel  ...   Green
# 71    78.0            Tentacool  ...    Blue
# 72    79.0           Tentacruel  ...    Blue
# 73    80.0              Geodude  ...   Brown
# 74    81.0             Graveler  ...   Brown
# 75    82.0                Golem  ...   Brown
# 76    83.0               Ponyta  ...  Yellow
# 77    84.0             Rapidash  ...  Yellow
# 78    85.0             Slowpoke  ...    Pink
# 79    86.0              Slowbro  ...    Pink
# 80    88.0            Magnemite  ...    Gray
# 81    89.0             Magneton  ...    Gray
# 82    91.0           Farfetch'd  ...   Brown
# 83    92.0                Doduo  ...   Brown
# 84    93.0               Dodrio  ...   Brown
# 85    94.0                 Seel  ...   White
# 86    95.0              Dewgong  ...   White
# 87    96.0               Grimer  ...  Purple
# 88    97.0                  Muk  ...  Purple
# 89    98.0             Shellder  ...  Purple
# 90    99.0             Cloyster  ...  Purple
# 91   100.0               Gastly  ...  Purple
# 92   101.0              Haunter  ...  Purple
# 93   102.0               Gengar  ...  Purple
# 94   103.0                 Onix  ...    Gray
# 95   105.0              Drowzee  ...  Yellow
# 96   106.0                Hypno  ...  Yellow
# 97   107.0               Krabby  ...     Red
# 98   108.0              Kingler  ...     Red
# 99   109.0              Voltorb  ...     Red
# 100  110.0            Electrode  ...     Red
# 101  111.0            Exeggcute  ...    Pink
# 102  112.0            Exeggutor  ...  Yellow
# 103  113.0               Cubone  ...   Brown
# 104  114.0              Marowak  ...   Brown
# 105  116.0            Hitmonlee  ...   Brown
# 106  117.0           Hitmonchan  ...   Brown
# 107  119.0            Lickitung  ...    Pink
# 108  121.0              Koffing  ...  Purple
# 109  122.0              Weezing  ...  Purple
# 110  123.0              Rhyhorn  ...    Gray
# 111  124.0               Rhydon  ...    Gray
# 112  127.0              Chansey  ...    Pink
# 113  129.0              Tangela  ...    Blue    Terry
# 114  131.0           Kangaskhan  ...   Brown
# 115  132.0               Horsea  ...    Blue
# 116  133.0               Seadra  ...    Blue
# 117  135.0              Goldeen  ...     Red
# 118  136.0              Seaking  ...     Red
# 119  137.0               Staryu  ...   Brown
# 120  138.0              Starmie  ...  Purple
# 121  140.0             Mr. Mime  ...    Pink
# 122  141.0              Scyther  ...   Green
# 123  144.0                 Jynx  ...     Red
# 124  146.0           Electabuzz  ...  Yellow
# 125  149.0               Magmar  ...     Red
# 126  151.0               Pinsir  ...   Brown
# 127  152.0               Tauros  ...   Brown
# 128  153.0             Magikarp  ...     Red
# 129  154.0             Gyarados  ...    Blue
# 130  155.0               Lapras  ...    Blue
# 131  156.0                Ditto  ...  Purple
# 132  157.0                Eevee  ...   Brown
# 133  158.0             Vaporeon  ...    Blue
# 134  159.0              Jolteon  ...  Yellow
# 135  160.0              Flareon  ...     Red
# 136  165.0              Porygon  ...    Pink
# 137  168.0              Omanyte  ...    Blue
# 138  169.0              Omastar  ...    Blue
# 139  170.0               Kabuto  ...   Brown
# 140  171.0             Kabutops  ...   Brown
# 141  172.0           Aerodactyl  ...  Purple
# 142  174.0              Snorlax  ...   Black
# 143  175.0             Articuno  ...    Blue
# 144  176.0               Zapdos  ...  Yellow
# 145  177.0              Moltres  ...  Yellow
# 146  178.0              Dratini  ...    Blue
# 147  179.0            Dragonair  ...    Blue
# 148  180.0            Dragonite  ...   Brown
# 149  181.0               Mewtwo  ...  Purple
# 150  182.0                  Mew  ...    Pink
# 151  183.0            Chikorita  ...   Green
# 152  184.0              Bayleef  ...   Green
# 153  185.0             Meganium  ...   Green
# 154  186.0            Cyndaquil  ...  Yellow
# 155  187.0              Quilava  ...  Yellow
# 156  188.0           Typhlosion  ...  Yellow
# 157  189.0             Totodile  ...    Blue
# 158  190.0             Croconaw  ...    Blue
# 159  191.0           Feraligatr  ...    Blue
# 160  192.0              Sentret  ...   Brown
# 161  193.0               Furret  ...   Brown
# 162  194.0             Hoothoot  ...   Brown
# 163  195.0              Noctowl  ...   Brown
# 164  196.0               Ledyba  ...     Red
# 165  197.0               Ledian  ...     Red
# 166  198.0             Spinarak  ...   Green
# 167  199.0              Ariados  ...     Red
# 168   46.0               Crobat  ...  Purple
# 169  200.0             Chinchou  ...    Blue
# 170  201.0              Lanturn  ...    Blue
# 171   25.0                Pichu  ...  Yellow
# 172   36.0               Cleffa  ...    Pink
# 173   41.0            Igglybuff  ...    Pink
# 174  202.0               Togepi  ...   White
# 175  203.0              Togetic  ...   White
# 176  205.0                 Natu  ...   Green
# 177  206.0                 Xatu  ...   Green
# 178  207.0               Mareep  ...   White
# 179  208.0              Flaaffy  ...    Pink
# 180  209.0             Ampharos  ...  Yellow
# 181   50.0            Bellossom  ...   Green
# 182  211.0               Marill  ...    Blue
# 183  212.0            Azumarill  ...    Blue
# 184  214.0            Sudowoodo  ...   Brown
# 185   68.0             Politoed  ...   Green
# 186  215.0               Hoppip  ...    Pink
# 187  216.0             Skiploom  ...   Green
# 188  217.0             Jumpluff  ...    Blue
# 189  218.0                Aipom  ...  Purple
# 190  220.0              Sunkern  ...  Yellow
# 191  221.0             Sunflora  ...  Yellow
# 192  222.0                Yanma  ...     Red
# 193  224.0               Wooper  ...    Blue
# 194  225.0             Quagsire  ...    Blue
# 195  161.0               Espeon  ...  Purple
# 196  162.0              Umbreon  ...   Black
# 197  226.0              Murkrow  ...   Black
# 198   87.0             Slowking  ...    Pink
# 199  228.0           Misdreavus  ...    Gray
# 200  230.0                Unown  ...   Black
# 201  232.0            Wobbuffet  ...    Blue
# 202  233.0            Girafarig  ...  Yellow
# 203  234.0               Pineco  ...    Gray
# 204  235.0           Forretress  ...  Purple
# 205  236.0            Dunsparce  ...  Yellow
# 206  237.0               Gligar  ...  Purple
# 207  104.0              Steelix  ...    Gray
# 208  239.0             Snubbull  ...    Pink
# 209  240.0             Granbull  ...  Purple
# 210  241.0             Qwilfish  ...    Gray
# 211  142.0               Scizor  ...     Red
# 212  242.0              Shuckle  ...  Yellow
# 213  243.0            Heracross  ...    Blue
# 214  244.0              Sneasel  ...   Black
# 215  246.0            Teddiursa  ...   Brown
# 216  247.0             Ursaring  ...   Brown
# 217  248.0               Slugma  ...     Red
# 218  249.0             Magcargo  ...     Red
# 219  250.0               Swinub  ...   Brown
# 220  251.0            Piloswine  ...   Brown
# 221  253.0              Corsola  ...    Pink
# 222  254.0             Remoraid  ...    Gray
# 223  255.0            Octillery  ...     Red
# 224  256.0             Delibird  ...     Red
# 225  258.0              Mantine  ...  Purple
# 226  259.0             Skarmory  ...    Gray
# 227  260.0             Houndour  ...   Black
# 228  261.0             Houndoom  ...   Black
# 229  134.0              Kingdra  ...    Blue
# 230  262.0               Phanpy  ...    Blue
# 231  263.0              Donphan  ...    Gray
# 232  166.0             Porygon2  ...     Red
# 233  264.0             Stantler  ...   Brown
# 234  265.0             Smeargle  ...   White
# 235  115.0              Tyrogue  ...  Purple
# 236  118.0            Hitmontop  ...   Brown
# 237  143.0             Smoochum  ...    Pink
# 238  145.0               Elekid  ...  Yellow
# 239  148.0                Magby  ...     Red
# 240  266.0              Miltank  ...    Pink
# 241  128.0              Blissey  ...    Pink
# 242  267.0               Raikou  ...  Yellow
# 243  268.0                Entei  ...   Brown
# 244  269.0              Suicune  ...    Blue
# 245  270.0             Larvitar  ...   Green
# 246  271.0              Pupitar  ...    Gray
# 247  272.0            Tyranitar  ...   Green
# 248  273.0                Lugia  ...   White
# 249  274.0                Ho-oh  ...     Red
# 250  275.0               Celebi  ...   Green
# 251  276.0              Treecko  ...   Green
# 252  277.0              Grovyle  ...   Green
# 253  278.0             Sceptile  ...   Green
# 254  279.0              Torchic  ...     Red
# 255  280.0            Combusken  ...     Red
# 256  281.0             Blaziken  ...     Red
# 257  282.0               Mudkip  ...    Blue
# 258  283.0            Marshtomp  ...    Blue
# 259  284.0             Swampert  ...    Blue
# 260  285.0            Poochyena  ...    Gray
# 261  286.0            Mightyena  ...    Gray
# 262  287.0            Zigzagoon  ...   Brown
# 263  288.0              Linoone  ...   White
# 264  289.0              Wurmple  ...     Red
# 265  290.0              Silcoon  ...   White
# 266  291.0            Beautifly  ...  Yellow
# 267  292.0              Cascoon  ...  Purple
# 268  293.0               Dustox  ...   Green
# 269  294.0                Lotad  ...   Green
# 270  295.0               Lombre  ...   Green
# 271  296.0             Ludicolo  ...   Green
# 272  297.0               Seedot  ...   Brown
# 273  298.0              Nuzleaf  ...   Brown
# 274  299.0              Shiftry  ...   Brown
# 275  300.0              Taillow  ...    Blue
# 276  301.0              Swellow  ...    Blue
# 277  302.0              Wingull  ...   White
# 278  303.0             Pelipper  ...  Yellow
# 279  304.0                Ralts  ...   White
# 280  305.0               Kirlia  ...   White
# 281  306.0            Gardevoir  ...   White
# 282  308.0              Surskit  ...    Blue
# 283  309.0           Masquerain  ...    Blue
# 284  310.0            Shroomish  ...   Brown
# 285  311.0              Breloom  ...   Green
# 286  312.0              Slakoth  ...   Brown
# 287  313.0             Vigoroth  ...   White
# 288  314.0              Slaking  ...   Brown
# 289  315.0              Nincada  ...    Gray
# 290  316.0              Ninjask  ...  Yellow
# 291  317.0             Shedinja  ...   Brown
# 292  318.0              Whismur  ...    Pink
# 293  319.0              Loudred  ...    Blue
# 294  320.0              Exploud  ...    Blue
# 295  321.0             Makuhita  ...  Yellow
# 296  322.0             Hariyama  ...   Brown
# 297  210.0              Azurill  ...    Blue
# 298  323.0             Nosepass  ...    Gray
# 299  325.0               Skitty  ...    Pink
# ..     ...                  ...  ...     ...      ...
# 523  512.0             Simisage  ...   Green
# 524  513.0              Pansear  ...     Red
# 525  514.0             Simisear  ...     Red
# 526  515.0              Panpour  ...    Blue
# 527  516.0             Simipour  ...    Blue
# 528  517.0                Munna  ...    Pink
# 529  518.0             Musharna  ...    Pink
# 530  519.0               Pidove  ...    Gray
# 531  520.0            Tranquill  ...    Gray
# 532  521.0             Unfezant  ...    Gray
# 533  522.0              Blitzle  ...   Black
# 534  523.0            Zebstrika  ...   Black
# 535  524.0           Roggenrola  ...    Blue
# 536  525.0              Boldore  ...    Blue
# 537  526.0             Gigalith  ...    Blue
# 538  527.0               Woobat  ...    Blue
# 539  528.0              Swoobat  ...    Blue
# 540  529.0              Drilbur  ...    Gray
# 541  530.0            Excadrill  ...    Gray
# 542  531.0               Audino  ...    Pink
# 543  532.0              Timburr  ...    Gray
# 544  533.0              Gurdurr  ...    Gray
# 545  534.0           Conkeldurr  ...   Brown
# 546  535.0              Tympole  ...    Blue
# 547  536.0            Palpitoad  ...    Blue
# 548  537.0           Seismitoad  ...    Blue
# 549  538.0                Throh  ...     Red
# 550  539.0                 Sawk  ...    Blue
# 551  540.0             Sewaddle  ...  Yellow
# 552  541.0             Swadloon  ...   Green
# 553  542.0             Leavanny  ...  Yellow
# 554  543.0             Venipede  ...     Red
# 555  544.0           Whirlipede  ...    Gray
# 556  545.0            Scolipede  ...     Red
# 557  546.0             Cottonee  ...   Green
# 558  547.0           Whimsicott  ...   Green
# 559  548.0              Petilil  ...   Green
# 560  549.0            Lilligant  ...   Green
# 561  550.0             Basculin  ...   Green
# 562  551.0              Sandile  ...   Brown
# 563  552.0             Krokorok  ...   Brown
# 564  553.0           Krookodile  ...     Red
# 565  554.0             Darumaka  ...     Red
# 566  555.0           Darmanitan  ...     Red
# 567  555.1       Darmanitan (Z)  ...     Red
# 568  556.0             Maractus  ...   Green
# 569  557.0              Dwebble  ...     Red
# 570  558.0              Crustle  ...     Red
# 571  559.0              Scraggy  ...  Yellow
# 572  560.0              Scrafty  ...     Red
# 573  561.0             Sigilyph  ...   Black
# 574  562.0               Yamask  ...   Black
# 575  563.0           Cofagrigus  ...  Yellow
# 576  564.0             Tirtouga  ...    Blue
# 577  565.0           Carracosta  ...    Blue
# 578  566.0               Archen  ...  Yellow
# 579  567.0             Archeops  ...  Yellow
# 580  568.0             Trubbish  ...   Green
# 581  569.0             Garbodor  ...   Green
# 582  570.0                Zorua  ...    Gray
# 583  571.0              Zoroark  ...    Gray
# 584  572.0             Minccino  ...    Gray
# 585  573.0             Cinccino  ...    Gray
# 586  574.0              Gothita  ...  Purple
# 587  575.0            Gothorita  ...  Purple
# 588  576.0           Gothitelle  ...  Purple
# 589  577.0              Solosis  ...   Green
# 590  578.0              Duosion  ...   Green
# 591  579.0            Reuniclus  ...   Green
# 592  580.0             Ducklett  ...    Blue
# 593  581.0               Swanna  ...   White
# 594  582.0            Vanillite  ...   White
# 595  583.0            Vanillish  ...   White
# 596  584.0            Vanilluxe  ...   White
# 597  585.0             Deerling  ...  Yellow
# 598  586.0             Sawsbuck  ...   Brown
# 599  587.0               Emolga  ...   White
# 600  588.0           Karrablast  ...    Blue
# 601  589.0           Escavalier  ...    Gray
# 602  590.0              Foongus  ...   White
# 603  591.0            Amoonguss  ...   White
# 604  592.0             Frillish  ...   White
# 605  593.0            Jellicent  ...   White
# 606  594.0            Alomomola  ...    Pink
# 607  595.0               Joltik  ...  Yellow
# 608  596.0           Galvantula  ...  Yellow
# 609  597.0            Ferroseed  ...    Gray
# 610  598.0           Ferrothorn  ...    Gray
# 611  599.0                Klink  ...    Gray
# 612  600.0                Klang  ...    Gray
# 613  601.0            Klinklang  ...    Gray
# 614  602.0               Tynamo  ...   White
# 615  603.0            Eelektrik  ...    Blue
# 616  604.0           Eelektross  ...    Blue
# 617  605.0               Elgyem  ...    Blue
# 618  606.0             Beheeyem  ...   Brown
# 619  607.0              Litwick  ...   White
# 620  608.0              Lampent  ...   Black
# 621  609.0           Chandelure  ...   Black
# 622  610.0                 Axew  ...   Green
# 623  611.0              Fraxure  ...   Green
# 624  612.0              Haxorus  ...  Yellow
# 625  613.0              Cubchoo  ...   White
# 626  614.0              Beartic  ...   White
# 627  615.0            Cryogonal  ...    Blue
# 628  616.0              Shelmet  ...     Red
# 629  617.0             Accelgor  ...     Red
# 630  618.0             Stunfisk  ...   Brown
# 631  619.0              Mienfoo  ...  Yellow
# 632  620.0             Mienshao  ...  Purple
# 633  621.0            Druddigon  ...     Red
# 634  622.0               Golett  ...   Green
# 635  623.0               Golurk  ...   Green
# 636  624.0             Pawniard  ...     Red
# 637  625.0              Bisharp  ...     Red
# 638  626.0           Bouffalant  ...   Brown
# 639  627.0              Rufflet  ...   White
# 640  628.0             Braviary  ...     Red
# 641  629.0              Vullaby  ...   Brown
# 642  630.0            Mandibuzz  ...   Brown
# 643  631.0              Heatmor  ...     Red
# 644  632.0               Durant  ...    Gray
# 645  633.0                Deino  ...    Blue
# 646  634.0             Zweilous  ...    Blue
# 647  635.0            Hydreigon  ...    Blue
# 648  636.0             Larvesta  ...   White
# 649  637.0            Volcarona  ...   White
# 650  638.0             Cobalion  ...    Blue
# 651  639.0            Terrakion  ...    Gray
# 652  640.0             Virizion  ...   Green
# 653  641.0             Tornadus  ...   Green
# 654  642.0            Thundurus  ...    Blue
# 655  643.0             Reshiram  ...   White
# 656  644.0               Zekrom  ...   Black
# 657  645.0             Landorus  ...   Brown
# 658  646.0               Kyurem  ...    Gray
# 659  647.0               Keldeo  ...  Yellow
# 660  648.0         Meloetta (A)  ...   White
# 661  648.1         Meloetta (P)  ...   White
# 662  649.0             Genesect  ...  Purple
# 663  650.0              Chespin  ...   Green
# 664  651.0            Quilladin  ...   Green
# 665  652.0           Chesnaught  ...   Green
# 666  653.0             Fennekin  ...     Red
# 667  654.0              Braixen  ...     Red
# 668  655.0              Delphox  ...     Red
# 669  656.0              Froakie  ...    Blue
# 670  657.0            Frogadier  ...    Blue
# 671  658.0             Greninja  ...    Blue
# 672  659.0             Bunnelby  ...   Brown
# 673  660.0            Diggersby  ...   Brown
# 674  661.0           Fletchling  ...     Red
# 675  662.0          Fletchinder  ...     Red
# 676  663.0           Talonflame  ...     Red
# 677  664.0           Scatterbug  ...   Black
# 678  665.0               Spewpa  ...   Black
# 679  666.0             Vivillon  ...   Black
# 680  667.0               Litleo  ...   Brown
# 681  668.0               Pyroar  ...   Brown
# 682  669.0              Flabébé  ...   White
# 683  670.0              Floette  ...   White
# 684  671.0              Florges  ...   White
# 685  672.0               Skiddo  ...   Brown
# 686  673.0               Gogoat  ...   Brown
# 687  674.0              Pancham  ...   White
# 688  675.0              Pangoro  ...   White
# 689  676.0              Furfrou  ...   White
# 690  677.0               Espurr  ...    Gray
# 691  678.0             Meowstic  ...   White
# 692  679.0              Honedge  ...   Brown
# 693  680.0             Doublade  ...   Brown
# 694  681.0            Aegislash  ...   Brown
# 695  682.0             Spritzee  ...    Pink
# 696  683.0           Aromatisse  ...    Pink
# 697  684.0              Swirlix  ...   White
# 698  685.0             Slurpuff  ...   White
# 699  686.0                Inkay  ...    Blue
# 700  687.0              Malamar  ...    Blue
# 701  688.0              Binacle  ...   Brown
# 702  689.0           Barbaracle  ...   Brown
# 703  690.0               Skrelp  ...   Brown
# 704  691.0             Dragalge  ...   Brown
# 705  692.0            Clauncher  ...    Blue
# 706  693.0            Clawitzer  ...    Blue
# 707  694.0           Helioptile  ...  Yellow
# 708  695.0            Heliolisk  ...  Yellow
# 709  696.0               Tyrunt  ...   Brown
# 710  697.0            Tyrantrum  ...     Red
# 711  698.0               Amaura  ...    Blue
# 712  699.0              Aurorus  ...    Blue
# 713  700.0              Sylveon  ...    Pink
# 714  701.0             Hawlucha  ...   Green
# 715  702.0              Dedenne  ...  Yellow
# 716  703.0              Carbink  ...    Gray
# 717  704.0                Goomy  ...  Purple
# 718  705.0              Sliggoo  ...  Purple
# 719  706.0               Goodra  ...  Purple
# 720  707.0               Klefki  ...    Gray
# 721  708.0             Phantump  ...   Brown
# 722  709.0            Trevenant  ...   Brown
# 723  710.0            Pumpkaboo  ...   Brown
# 724  711.0            Gourgeist  ...   Brown
# 725  712.0             Bergmite  ...    Blue
# 726  713.0              Avalugg  ...    Blue
# 727  714.0               Noibat  ...  Purple
# 728  715.0              Noivern  ...  Purple
# 729  716.0              Xerneas  ...    Blue
# 730  717.0              Yveltal  ...     Red
# 731  718.0              Zygarde  ...   Green
# 732  719.0              Diancie  ...    Pink
# 733  720.0            Hoopa (C)  ...  Purple
# 734  720.0            Hoopa (U)  ...  Purple
# 735  721.0            Volcanion  ...   Brown
# 736  722.0               Rowlet  ...   Brown
# 737  723.0              Dartrix  ...   Brown
# 738  724.0            Decidueye  ...   Brown
# 739  725.0               Litten  ...     Red
# 740  726.0             Torracat  ...     Red
# 741  727.0           Incineroar  ...     Red
# 742  728.0              Popplio  ...    Blue
# 743  729.0              Brionne  ...    Blue
# 744  730.0            Primarina  ...    Blue
# 745  731.0              Pikipek  ...   Black
# 746  732.0             Trumbeak  ...   Black
# 747  733.0            Toucannon  ...   Black
# 748  734.0              Yungoos  ...   Brown
# 749  735.0             Gumshoos  ...   Brown
# 750  736.0              Grubbin  ...    Gray
# 751  737.0            Charjabug  ...   Green
# 752  738.0             Vikavolt  ...    Blue
# 753  739.0           Crabrawler  ...  Purple
# 754  740.0         Crabominable  ...   White
# 755  741.0             Oricorio  ...     Red
# 756  742.0             Cutiefly  ...  Yellow
# 757  743.0             Ribombee  ...  Yellow
# 758  744.0             Rockruff  ...   Brown
# 759  745.0    Lycanroc (midday)  ...
# 760  745.1  Lycanroc (midnight)  ...   Brown
# 761  746.0    Wishiwashi (solo)  ...    Blue
# 762  746.1  Wishiwashi (school)  ...    Blue
# 763  747.0             Mareanie  ...    Blue
# 764  748.0              Toxapex  ...    Blue
# 765  749.0              Mudbray  ...   Brown
# 766  750.0             Mudsdale  ...   Brown
# 767  751.0             Dewpider  ...   Green
# 768  752.0            Araquanid  ...   Green
# 769  753.0             Fomantis  ...    Pink
# 770  754.0             Lurantis  ...    Pink
# 771  755.0             Morelull  ...  Purple
# 772  756.0            Shiinotic  ...  Purple
# 773  757.0             Salandit  ...   Black
# 774  758.0             Salazzle  ...   Black
# 775  759.0              Stufful  ...    Pink
# 776  760.0               Bewear  ...    Pink
# 777  761.0            Bounsweet  ...  Purple
# 778  762.0              Steenee  ...  Purple
# 779  763.0             Tsareena  ...  Purple
# 780  764.0               Comfey  ...   Green
# 781  765.0             Oranguru  ...   White
# 782  766.0            Passimian  ...   White
# 783  767.0               Wimpod  ...    Gray
# 784  768.0            Golisopod  ...    Gray
# 785  769.0            Sandygast  ...   Brown
# 786  770.0            Palossand  ...   Brown
# 787  771.0            Pyukumuku  ...   Black
# 788  772.0           Type: Null  ...    Gray
# 789  773.0             Silvally  ...    Gray
# 790  774.0      Minior (meteor)  ...   Brown
# 791  774.1        Minior (core)  ...    Pink
# 792  775.0               Komala  ...    Blue
# 793  776.0           Turtonator  ...     Red
# 794  777.0           Togedemaru  ...    Gray
# 795  778.0              Mimikyu  ...  Yellow
# 796  779.0              Bruxish  ...    Pink
# 797  780.0               Drampa  ...   White
# 798  781.0             Dhelmise  ...   Green
# 799  782.0             Jangmo-o  ...    Gray
# 800  783.0             Hakamo-o  ...    Gray
# 801  784.0              Kommo-o  ...    Gray
# 802  785.0            Tapu Koko  ...  Yellow
# 803  786.0            Tapu Lele  ...    Pink
# 804  787.0            Tapu Bulu  ...     Red
# 805  788.0            Tapu Fini  ...  Purple
# 806  789.0               Cosmog  ...    Blue
# 807  790.0              Cosmoem  ...    Blue
# 808  791.0             Solgaleo  ...   White
# 809  792.0               Lunala  ...  Purple
# 810  793.0             Nihilego  ...   White
# 811  794.0             Buzzwole  ...     Red
# 812  795.0            Pheromosa  ...   White
# 813  796.0            Xurkitree  ...   Black
# 814  797.0           Celesteela  ...   Green
# 815  798.0              Kartana  ...   White
# 816  799.0             Guzzlord  ...   Black
# 817  800.0             Necrozma  ...   Black
# 818  801.0             Magearna  ...    Gray
# 819  802.0            Marshadow  ...    Gray
# 820  803.0              Grookey  ...   Green
# 821  804.0            Scorbunny  ...     Red
# 822  805.0               Sobble  ...    Blue
#
# [823 rows x 16 columns]

# %%
# Change the index to the Pokemon name column
pokedex_indexed_by_name = pokedex_df.set_index('Pokemon')
pokedex_indexed_by_name
# Out:
#                       HP  Atk  ...   Color Nickname
# Pokemon                        ...
# Bulbasaur             45   49  ...   Green
# Ivysaur               60   62  ...   Green
# Venusaur              80   82  ...   Green
# Charmander            39   52  ...     Red     Abby
# Charmeleon            58   64  ...     Red
# Charizard             78   84  ...     Red
# Squirtle              44   48  ...    Blue
# Wartortle             59   63  ...    Blue
# Blastoise             79   83  ...    Blue
# Caterpie              45   30  ...   Green
# Metapod               50   20  ...   Green
# Butterfree            60   45  ...   White
# Weedle                40   35  ...   Brown
# Kakuna                45   25  ...  Yellow
# Beedrill              65   80  ...  Yellow
# Pidgey                40   45  ...   Brown
# Pidgeotto             63   60  ...   Brown
# Pidgeot               83   80  ...   Brown
# Rattata               30   56  ...  Purple
# Raticate              55   81  ...   Brown
# Spearow               40   60  ...   Brown
# Fearow                65   90  ...   Brown
# Ekans                 30   60  ...  Purple
# Arbok                 60   85  ...  Purple
# Pikachu               35   55  ...  Yellow
# Raichu                60   90  ...  Yellow
# Sandshrew             50   75  ...  Yellow
# Sandslash             75  100  ...  Yellow
# Nidoran♀              55   47  ...    Blue
# Nidorina              70   62  ...    Blue
# Nidoqueen             90   82  ...    Blue
# Nidoran♂              46   57  ...  Purple
# Nidorino              61   72  ...  Purple
# Nidoking              81   92  ...  Purple
# Clefairy              70   45  ...    Pink
# Clefable              95   70  ...    Pink
# Vulpix                38   41  ...   Brown
# Ninetales             73   76  ...  Yellow
# Jigglypuff           115   45  ...    Pink
# Wigglytuff           140   70  ...    Pink
# Zubat                 40   45  ...  Purple
# Golbat                75   80  ...  Purple
# Oddish                45   50  ...    Blue
# Gloom                 60   65  ...    Blue
# Vileplume             75   80  ...     Red
# Paras                 35   70  ...     Red
# Parasect              60   95  ...     Red
# Venonat               60   55  ...  Purple
# Venomoth              70   65  ...  Purple
# Diglett               10   55  ...   Brown
# Dugtrio               35   80  ...   Brown
# Meowth                40   45  ...  Yellow
# Persian               65   70  ...  Yellow
# Psyduck               50   52  ...  Yellow
# Golduck               80   82  ...    Blue
# Mankey                40   80  ...   Brown
# Primeape              65  105  ...   Brown
# Growlithe             55   70  ...   Brown
# Arcanine              90  110  ...   Brown
# Poliwag               40   50  ...    Blue
# Poliwhirl             65   65  ...    Blue
# Poliwrath             90   85  ...    Blue
# Abra                  25   20  ...   Brown
# Kadabra               40   35  ...   Brown
# Alakazam              55   50  ...   Brown
# Machop                70   80  ...    Gray
# Machoke               80  100  ...    Gray
# Machamp               90  130  ...    Gray
# Bellsprout            50   75  ...   Green
# Weepinbell            65   90  ...   Green
# Victreebel            80  105  ...   Green
# Tentacool             40   40  ...    Blue
# Tentacruel            80   70  ...    Blue
# Geodude               40   80  ...   Brown
# Graveler              55   95  ...   Brown
# Golem                 80  110  ...   Brown
# Ponyta                50   85  ...  Yellow
# Rapidash              65  100  ...  Yellow
# Slowpoke              90   65  ...    Pink
# Slowbro               95   75  ...    Pink
# Magnemite             25   35  ...    Gray
# Magneton              50   60  ...    Gray
# Farfetch'd            52   65  ...   Brown
# Doduo                 35   85  ...   Brown
# Dodrio                60  110  ...   Brown
# Seel                  65   45  ...   White
# Dewgong               90   70  ...   White
# Grimer                80   80  ...  Purple
# Muk                  105  105  ...  Purple
# Shellder              30   65  ...  Purple
# Cloyster              50   90  ...  Purple
# Gastly                30   35  ...  Purple
# Haunter               45   50  ...  Purple
# Gengar                60   65  ...  Purple
# Onix                  35   45  ...    Gray
# Drowzee               60   48  ...  Yellow
# Hypno                 85   73  ...  Yellow
# Krabby                30  105  ...     Red
# Kingler               55  130  ...     Red
# Voltorb               40   30  ...     Red
# Electrode             60   50  ...     Red
# Exeggcute             60   40  ...    Pink
# Exeggutor             95   95  ...  Yellow
# Cubone                50   50  ...   Brown
# Marowak               60   80  ...   Brown
# Hitmonlee             50  120  ...   Brown
# Hitmonchan            50  105  ...   Brown
# Lickitung             90   55  ...    Pink
# Koffing               40   65  ...  Purple
# Weezing               65   90  ...  Purple
# Rhyhorn               80   85  ...    Gray
# Rhydon               105  130  ...    Gray
# Chansey              250    5  ...    Pink
# Tangela               65   55  ...    Blue    Terry
# Kangaskhan           105   95  ...   Brown
# Horsea                30   40  ...    Blue
# Seadra                55   65  ...    Blue
# Goldeen               45   67  ...     Red
# Seaking               80   92  ...     Red
# Staryu                30   45  ...   Brown
# Starmie               60   75  ...  Purple
# Mr. Mime              40   45  ...    Pink
# Scyther               70  110  ...   Green
# Jynx                  65   50  ...     Red
# Electabuzz            65   83  ...  Yellow
# Magmar                65   95  ...     Red
# Pinsir                65  125  ...   Brown
# Tauros                75  100  ...   Brown
# Magikarp              20   10  ...     Red
# Gyarados              95  125  ...    Blue
# Lapras               130   85  ...    Blue
# Ditto                 48   48  ...  Purple
# Eevee                 55   55  ...   Brown
# Vaporeon             130   65  ...    Blue
# Jolteon               65   65  ...  Yellow
# Flareon               65  130  ...     Red
# Porygon               65   60  ...    Pink
# Omanyte               35   40  ...    Blue
# Omastar               70   60  ...    Blue
# Kabuto                30   80  ...   Brown
# Kabutops              60  115  ...   Brown
# Aerodactyl            80  105  ...  Purple
# Snorlax              160  110  ...   Black
# Articuno              90   85  ...    Blue
# Zapdos                90   90  ...  Yellow
# Moltres               90  100  ...  Yellow
# Dratini               41   64  ...    Blue
# Dragonair             61   84  ...    Blue
# Dragonite             91  134  ...   Brown
# Mewtwo               106  110  ...  Purple
# Mew                  100  100  ...    Pink
# Chikorita             45   49  ...   Green
# Bayleef               60   62  ...   Green
# Meganium              80   82  ...   Green
# Cyndaquil             39   52  ...  Yellow
# Quilava               58   64  ...  Yellow
# Typhlosion            78   84  ...  Yellow
# Totodile              50   65  ...    Blue
# Croconaw              65   80  ...    Blue
# Feraligatr            85  105  ...    Blue
# Sentret               35   46  ...   Brown
# Furret                85   76  ...   Brown
# Hoothoot              60   30  ...   Brown
# Noctowl              100   50  ...   Brown
# Ledyba                40   20  ...     Red
# Ledian                55   35  ...     Red
# Spinarak              40   60  ...   Green
# Ariados               70   90  ...     Red
# Crobat                85   90  ...  Purple
# Chinchou              75   38  ...    Blue
# Lanturn              125   58  ...    Blue
# Pichu                 20   40  ...  Yellow
# Cleffa                50   25  ...    Pink
# Igglybuff             90   30  ...    Pink
# Togepi                35   20  ...   White
# Togetic               55   40  ...   White
# Natu                  40   50  ...   Green
# Xatu                  65   75  ...   Green
# Mareep                55   40  ...   White
# Flaaffy               70   55  ...    Pink
# Ampharos              90   75  ...  Yellow
# Bellossom             75   80  ...   Green
# Marill                70   20  ...    Blue
# Azumarill            100   50  ...    Blue
# Sudowoodo             70  100  ...   Brown
# Politoed              90   75  ...   Green
# Hoppip                35   35  ...    Pink
# Skiploom              55   45  ...   Green
# Jumpluff              75   55  ...    Blue
# Aipom                 55   70  ...  Purple
# Sunkern               30   30  ...  Yellow
# Sunflora              75   75  ...  Yellow
# Yanma                 65   65  ...     Red
# Wooper                55   45  ...    Blue
# Quagsire              95   85  ...    Blue
# Espeon                65   65  ...  Purple
# Umbreon               95   65  ...   Black
# Murkrow               60   85  ...   Black
# Slowking              95   75  ...    Pink
# Misdreavus            60   60  ...    Gray
# Unown                 48   72  ...   Black
# Wobbuffet            190   33  ...    Blue
# Girafarig             70   80  ...  Yellow
# Pineco                50   65  ...    Gray
# Forretress            75   90  ...  Purple
# Dunsparce            100   70  ...  Yellow
# Gligar                65   75  ...  Purple
# Steelix               75   85  ...    Gray
# Snubbull              60   80  ...    Pink
# Granbull              90  120  ...  Purple
# Qwilfish              65   95  ...    Gray
# Scizor                70  130  ...     Red
# Shuckle               20   10  ...  Yellow
# Heracross             80  125  ...    Blue
# Sneasel               55   95  ...   Black
# Teddiursa             60   80  ...   Brown
# Ursaring              90  130  ...   Brown
# Slugma                40   40  ...     Red
# Magcargo              50   50  ...     Red
# Swinub                50   50  ...   Brown
# Piloswine            100  100  ...   Brown
# Corsola               55   55  ...    Pink
# Remoraid              35   65  ...    Gray
# Octillery             75  105  ...     Red
# Delibird              45   55  ...     Red
# Mantine               65   40  ...  Purple
# Skarmory              65   80  ...    Gray
# Houndour              45   60  ...   Black
# Houndoom              75   90  ...   Black
# Kingdra               75   95  ...    Blue
# Phanpy                90   60  ...    Blue
# Donphan               90  120  ...    Gray
# Porygon2              85   80  ...     Red
# Stantler              73   95  ...   Brown
# Smeargle              55   20  ...   White
# Tyrogue               35   35  ...  Purple
# Hitmontop             50   95  ...   Brown
# Smoochum              45   30  ...    Pink
# Elekid                45   63  ...  Yellow
# Magby                 45   75  ...     Red
# Miltank               95   80  ...    Pink
# Blissey              255   10  ...    Pink
# Raikou                90   85  ...  Yellow
# Entei                115  115  ...   Brown
# Suicune              100   75  ...    Blue
# Larvitar              50   64  ...   Green
# Pupitar               70   84  ...    Gray
# Tyranitar            100  134  ...   Green
# Lugia                106   90  ...   White
# Ho-oh                106  130  ...     Red
# Celebi               100  100  ...   Green
# Treecko               40   45  ...   Green
# Grovyle               50   65  ...   Green
# Sceptile              70   85  ...   Green
# Torchic               45   60  ...     Red
# Combusken             60   85  ...     Red
# Blaziken              80  120  ...     Red
# Mudkip                50   70  ...    Blue
# Marshtomp             70   85  ...    Blue
# Swampert             100  110  ...    Blue
# Poochyena             35   55  ...    Gray
# Mightyena             70   90  ...    Gray
# Zigzagoon             38   30  ...   Brown
# Linoone               78   70  ...   White
# Wurmple               45   45  ...     Red
# Silcoon               50   35  ...   White
# Beautifly             60   70  ...  Yellow
# Cascoon               50   35  ...  Purple
# Dustox                60   50  ...   Green
# Lotad                 40   30  ...   Green
# Lombre                60   50  ...   Green
# Ludicolo              80   70  ...   Green
# Seedot                40   40  ...   Brown
# Nuzleaf               70   70  ...   Brown
# Shiftry               90  100  ...   Brown
# Taillow               40   55  ...    Blue
# Swellow               60   85  ...    Blue
# Wingull               40   30  ...   White
# Pelipper              60   50  ...  Yellow
# Ralts                 28   25  ...   White
# Kirlia                38   35  ...   White
# Gardevoir             68   65  ...   White
# Surskit               40   30  ...    Blue
# Masquerain            70   60  ...    Blue
# Shroomish             60   40  ...   Brown
# Breloom               60  130  ...   Green
# Slakoth               60   60  ...   Brown
# Vigoroth              80   80  ...   White
# Slaking              150  160  ...   Brown
# Nincada               31   45  ...    Gray
# Ninjask               61   90  ...  Yellow
# Shedinja               1   90  ...   Brown
# Whismur               64   51  ...    Pink
# Loudred               84   71  ...    Blue
# Exploud              104   91  ...    Blue
# Makuhita              72   60  ...  Yellow
# Hariyama             144  120  ...   Brown
# Azurill               50   20  ...    Blue
# Nosepass              30   45  ...    Gray
# Skitty                50   45  ...    Pink
# ...                  ...  ...  ...     ...      ...
# Simisage              75   98  ...   Green
# Pansear               50   53  ...     Red
# Simisear              75   98  ...     Red
# Panpour               50   53  ...    Blue
# Simipour              75   98  ...    Blue
# Munna                 76   25  ...    Pink
# Musharna             116   55  ...    Pink
# Pidove                50   55  ...    Gray
# Tranquill             62   77  ...    Gray
# Unfezant              80  105  ...    Gray
# Blitzle               45   60  ...   Black
# Zebstrika             75  100  ...   Black
# Roggenrola            55   75  ...    Blue
# Boldore               70  105  ...    Blue
# Gigalith              85  135  ...    Blue
# Woobat                55   45  ...    Blue
# Swoobat               67   57  ...    Blue
# Drilbur               60   85  ...    Gray
# Excadrill            110  135  ...    Gray
# Audino               103   60  ...    Pink
# Timburr               75   80  ...    Gray
# Gurdurr               85  105  ...    Gray
# Conkeldurr           105  140  ...   Brown
# Tympole               50   50  ...    Blue
# Palpitoad             75   65  ...    Blue
# Seismitoad           105   85  ...    Blue
# Throh                120  100  ...     Red
# Sawk                  75  125  ...    Blue
# Sewaddle              45   53  ...  Yellow
# Swadloon              55   63  ...   Green
# Leavanny              75  103  ...  Yellow
# Venipede              30   45  ...     Red
# Whirlipede            40   55  ...    Gray
# Scolipede             60   90  ...     Red
# Cottonee              40   27  ...   Green
# Whimsicott            60   67  ...   Green
# Petilil               45   35  ...   Green
# Lilligant             70   60  ...   Green
# Basculin              70   92  ...   Green
# Sandile               50   72  ...   Brown
# Krokorok              60   82  ...   Brown
# Krookodile            95  117  ...     Red
# Darumaka              70   90  ...     Red
# Darmanitan           105  140  ...     Red
# Darmanitan (Z)       105   30  ...     Red
# Maractus              75   86  ...   Green
# Dwebble               50   65  ...     Red
# Crustle               70   95  ...     Red
# Scraggy               50   75  ...  Yellow
# Scrafty               65   90  ...     Red
# Sigilyph              72   58  ...   Black
# Yamask                38   30  ...   Black
# Cofagrigus            58   50  ...  Yellow
# Tirtouga              54   78  ...    Blue
# Carracosta            74  108  ...    Blue
# Archen                55  112  ...  Yellow
# Archeops              75  140  ...  Yellow
# Trubbish              50   50  ...   Green
# Garbodor              80   95  ...   Green
# Zorua                 40   65  ...    Gray
# Zoroark               60  105  ...    Gray
# Minccino              55   50  ...    Gray
# Cinccino              75   95  ...    Gray
# Gothita               45   30  ...  Purple
# Gothorita             60   45  ...  Purple
# Gothitelle            70   55  ...  Purple
# Solosis               45   30  ...   Green
# Duosion               65   40  ...   Green
# Reuniclus            110   65  ...   Green
# Ducklett              62   44  ...    Blue
# Swanna                75   87  ...   White
# Vanillite             36   50  ...   White
# Vanillish             51   65  ...   White
# Vanilluxe             71   95  ...   White
# Deerling              60   60  ...  Yellow
# Sawsbuck              80  100  ...   Brown
# Emolga                55   75  ...   White
# Karrablast            50   75  ...    Blue
# Escavalier            70  135  ...    Gray
# Foongus               69   55  ...   White
# Amoonguss            114   85  ...   White
# Frillish              55   40  ...   White
# Jellicent            100   60  ...   White
# Alomomola            165   75  ...    Pink
# Joltik                50   47  ...  Yellow
# Galvantula            70   77  ...  Yellow
# Ferroseed             44   50  ...    Gray
# Ferrothorn            74   94  ...    Gray
# Klink                 40   55  ...    Gray
# Klang                 60   80  ...    Gray
# Klinklang             60  100  ...    Gray
# Tynamo                35   55  ...   White
# Eelektrik             65   85  ...    Blue
# Eelektross            85  115  ...    Blue
# Elgyem                55   55  ...    Blue
# Beheeyem              75   75  ...   Brown
# Litwick               50   30  ...   White
# Lampent               60   40  ...   Black
# Chandelure            60   55  ...   Black
# Axew                  46   87  ...   Green
# Fraxure               66  117  ...   Green
# Haxorus               76  147  ...  Yellow
# Cubchoo               55   70  ...   White
# Beartic               95  110  ...   White
# Cryogonal             70   50  ...    Blue
# Shelmet               50   40  ...     Red
# Accelgor              80   70  ...     Red
# Stunfisk             109   66  ...   Brown
# Mienfoo               45   85  ...  Yellow
# Mienshao              65  125  ...  Purple
# Druddigon             77  120  ...     Red
# Golett                59   74  ...   Green
# Golurk                89  124  ...   Green
# Pawniard              45   85  ...     Red
# Bisharp               65  125  ...     Red
# Bouffalant            95  110  ...   Brown
# Rufflet               70   83  ...   White
# Braviary             100  123  ...     Red
# Vullaby               70   55  ...   Brown
# Mandibuzz            110   65  ...   Brown
# Heatmor               85   97  ...     Red
# Durant                58  109  ...    Gray
# Deino                 52   65  ...    Blue
# Zweilous              72   85  ...    Blue
# Hydreigon             92  105  ...    Blue
# Larvesta              55   85  ...   White
# Volcarona             85   60  ...   White
# Cobalion              91   90  ...    Blue
# Terrakion             91  129  ...    Gray
# Virizion              91   90  ...   Green
# Tornadus              79  115  ...   Green
# Thundurus             79  115  ...    Blue
# Reshiram             100  120  ...   White
# Zekrom               100  150  ...   Black
# Landorus              89  125  ...   Brown
# Kyurem               125  130  ...    Gray
# Keldeo                91   72  ...  Yellow
# Meloetta (A)         100   77  ...   White
# Meloetta (P)         100  128  ...   White
# Genesect              71  120  ...  Purple
# Chespin               56   61  ...   Green
# Quilladin             61   78  ...   Green
# Chesnaught            88  107  ...   Green
# Fennekin              40   45  ...     Red
# Braixen               59   59  ...     Red
# Delphox               75   69  ...     Red
# Froakie               41   56  ...    Blue
# Frogadier             54   63  ...    Blue
# Greninja              72   95  ...    Blue
# Bunnelby              38   36  ...   Brown
# Diggersby             85   56  ...   Brown
# Fletchling            45   50  ...     Red
# Fletchinder           62   73  ...     Red
# Talonflame            78   81  ...     Red
# Scatterbug            38   35  ...   Black
# Spewpa                45   22  ...   Black
# Vivillon              80   52  ...   Black
# Litleo                62   50  ...   Brown
# Pyroar                86   68  ...   Brown
# Flabébé               44   38  ...   White
# Floette               54   45  ...   White
# Florges               78   65  ...   White
# Skiddo                66   65  ...   Brown
# Gogoat               123  100  ...   Brown
# Pancham               67   82  ...   White
# Pangoro               95  124  ...   White
# Furfrou               75   80  ...   White
# Espurr                62   48  ...    Gray
# Meowstic              74   48  ...   White
# Honedge               45   80  ...   Brown
# Doublade              59  110  ...   Brown
# Aegislash             60   50  ...   Brown
# Spritzee              78   52  ...    Pink
# Aromatisse           101   72  ...    Pink
# Swirlix               62   48  ...   White
# Slurpuff              82   80  ...   White
# Inkay                 53   54  ...    Blue
# Malamar               86   92  ...    Blue
# Binacle               42   52  ...   Brown
# Barbaracle            72  105  ...   Brown
# Skrelp                50   60  ...   Brown
# Dragalge              65   75  ...   Brown
# Clauncher             50   53  ...    Blue
# Clawitzer             71   73  ...    Blue
# Helioptile            44   38  ...  Yellow
# Heliolisk             62   55  ...  Yellow
# Tyrunt                58   89  ...   Brown
# Tyrantrum             82  121  ...     Red
# Amaura                77   59  ...    Blue
# Aurorus              123   77  ...    Blue
# Sylveon               95   65  ...    Pink
# Hawlucha              78   92  ...   Green
# Dedenne               67   58  ...  Yellow
# Carbink               50   50  ...    Gray
# Goomy                 45   50  ...  Purple
# Sliggoo               68   75  ...  Purple
# Goodra                90  100  ...  Purple
# Klefki                57   80  ...    Gray
# Phantump              43   70  ...   Brown
# Trevenant             85  110  ...   Brown
# Pumpkaboo             44   66  ...   Brown
# Gourgeist             55   85  ...   Brown
# Bergmite              55   69  ...    Blue
# Avalugg               95  117  ...    Blue
# Noibat                40   30  ...  Purple
# Noivern               85   70  ...  Purple
# Xerneas              126  131  ...    Blue
# Yveltal              126  131  ...     Red
# Zygarde              108  100  ...   Green
# Diancie               50  100  ...    Pink
# Hoopa (C)             80  110  ...  Purple
# Hoopa (U)             80  160  ...  Purple
# Volcanion             80  110  ...   Brown
# Rowlet                68   55  ...   Brown
# Dartrix               78   75  ...   Brown
# Decidueye             78  107  ...   Brown
# Litten                45   65  ...     Red
# Torracat              65   85  ...     Red
# Incineroar            95  115  ...     Red
# Popplio               50   54  ...    Blue
# Brionne               60   69  ...    Blue
# Primarina             80   74  ...    Blue
# Pikipek               35   75  ...   Black
# Trumbeak              55   85  ...   Black
# Toucannon             80  120  ...   Black
# Yungoos               48   70  ...   Brown
# Gumshoos              88  110  ...   Brown
# Grubbin               47   62  ...    Gray
# Charjabug             57   82  ...   Green
# Vikavolt              77   70  ...    Blue
# Crabrawler            47   82  ...  Purple
# Crabominable          97  132  ...   White
# Oricorio              75   70  ...     Red
# Cutiefly              40   45  ...  Yellow
# Ribombee              60   55  ...  Yellow
# Rockruff              45   65  ...   Brown
# Lycanroc (midday)     75  115  ...
# Lycanroc (midnight)   85  115  ...   Brown
# Wishiwashi (solo)     45   20  ...    Blue
# Wishiwashi (school)   45  140  ...    Blue
# Mareanie              50   53  ...    Blue
# Toxapex               50   63  ...    Blue
# Mudbray               70  100  ...   Brown
# Mudsdale             100  125  ...   Brown
# Dewpider              38   40  ...   Green
# Araquanid             68   70  ...   Green
# Fomantis              40   55  ...    Pink
# Lurantis              70  105  ...    Pink
# Morelull              40   35  ...  Purple
# Shiinotic             60   45  ...  Purple
# Salandit              48   44  ...   Black
# Salazzle              68   64  ...   Black
# Stufful               70   75  ...    Pink
# Bewear               120  125  ...    Pink
# Bounsweet             42   30  ...  Purple
# Steenee               52   40  ...  Purple
# Tsareena              72  120  ...  Purple
# Comfey                51   52  ...   Green
# Oranguru              90   60  ...   White
# Passimian            100  120  ...   White
# Wimpod                25   35  ...    Gray
# Golisopod             75  125  ...    Gray
# Sandygast             55   55  ...   Brown
# Palossand             85   75  ...   Brown
# Pyukumuku             55   60  ...   Black
# Type: Null            95   95  ...    Gray
# Silvally              95   95  ...    Gray
# Minior (meteor)       60   60  ...   Brown
# Minior (core)         60  100  ...    Pink
# Komala                65  115  ...    Blue
# Turtonator            60   78  ...     Red
# Togedemaru            65   98  ...    Gray
# Mimikyu               55   90  ...  Yellow
# Bruxish               68  105  ...    Pink
# Drampa                78   60  ...   White
# Dhelmise              70  131  ...   Green
# Jangmo-o              45   55  ...    Gray
# Hakamo-o              55   75  ...    Gray
# Kommo-o               75  110  ...    Gray
# Tapu Koko             70  115  ...  Yellow
# Tapu Lele             70   85  ...    Pink
# Tapu Bulu             70  130  ...     Red
# Tapu Fini             70   75  ...  Purple
# Cosmog                43   29  ...    Blue
# Cosmoem               43   29  ...    Blue
# Solgaleo             137  137  ...   White
# Lunala               137  113  ...  Purple
# Nihilego             109   53  ...   White
# Buzzwole             107  139  ...     Red
# Pheromosa             71  137  ...   White
# Xurkitree             83   89  ...   Black
# Celesteela            97  101  ...   Green
# Kartana               59  181  ...   White
# Guzzlord             223  101  ...   Black
# Necrozma              97  107  ...   Black
# Magearna              80   95  ...    Gray
# Marshadow             90  125  ...    Gray
# Grookey                        ...   Green
# Scorbunny                      ...     Red
# Sobble                         ...    Blue
#
# [823 rows x 14 columns]

# %%
pokedex_df = pokedex_df.drop([803, 804, 805])

# %% [markdown]
# ## Logical indexing
# You can test conditionals on a column, for example, testing if the value of the column is greater than a value. What's returned is a boolean column of the same size, with a value of `True` wherever it is true, and `False` otherwise. (This can similarly be done in numpy).

# %%
# note that the original dataframe was not affected
pokedex_df
# Out:
#                    Pokemon   HP  ...   Color Nickname
# 1.0              Bulbasaur   45  ...   Green
# 2.0                Ivysaur   60  ...   Green
# 3.0               Venusaur   80  ...   Green
# 4.0             Charmander   39  ...     Red     Abby
# 5.0             Charmeleon   58  ...     Red
# 6.0              Charizard   78  ...     Red
# 7.0               Squirtle   44  ...    Blue
# 8.0              Wartortle   59  ...    Blue
# 9.0              Blastoise   79  ...    Blue
# 10.0              Caterpie   45  ...   Green
# 11.0               Metapod   50  ...   Green
# 12.0            Butterfree   60  ...   White
# 13.0                Weedle   40  ...   Brown
# 14.0                Kakuna   45  ...  Yellow
# 15.0              Beedrill   65  ...  Yellow
# 16.0                Pidgey   40  ...   Brown
# 17.0             Pidgeotto   63  ...   Brown
# 18.0               Pidgeot   83  ...   Brown
# 19.0               Rattata   30  ...  Purple
# 20.0              Raticate   55  ...   Brown
# 21.0               Spearow   40  ...   Brown
# 22.0                Fearow   65  ...   Brown
# 23.0                 Ekans   30  ...  Purple
# 24.0                 Arbok   60  ...  Purple
# 26.0               Pikachu   35  ...  Yellow
# 27.0                Raichu   60  ...  Yellow
# 28.0             Sandshrew   50  ...  Yellow
# 29.0             Sandslash   75  ...  Yellow
# 30.0              Nidoran♀   55  ...    Blue
# 31.0              Nidorina   70  ...    Blue
# 32.0             Nidoqueen   90  ...    Blue
# 33.0              Nidoran♂   46  ...  Purple
# 34.0              Nidorino   61  ...  Purple
# 35.0              Nidoking   81  ...  Purple
# 37.0              Clefairy   70  ...    Pink
# 38.0              Clefable   95  ...    Pink
# 39.0                Vulpix   38  ...   Brown
# 40.0             Ninetales   73  ...  Yellow
# 42.0            Jigglypuff  115  ...    Pink
# 43.0            Wigglytuff  140  ...    Pink
# 44.0                 Zubat   40  ...  Purple
# 45.0                Golbat   75  ...  Purple
# 47.0                Oddish   45  ...    Blue
# 48.0                 Gloom   60  ...    Blue
# 49.0             Vileplume   75  ...     Red
# 51.0                 Paras   35  ...     Red
# 52.0              Parasect   60  ...     Red
# 53.0               Venonat   60  ...  Purple
# 54.0              Venomoth   70  ...  Purple
# 55.0               Diglett   10  ...   Brown
# 56.0               Dugtrio   35  ...   Brown
# 57.0                Meowth   40  ...  Yellow
# 58.0               Persian   65  ...  Yellow
# 59.0               Psyduck   50  ...  Yellow
# 60.0               Golduck   80  ...    Blue
# 61.0                Mankey   40  ...   Brown
# 62.0              Primeape   65  ...   Brown
# 63.0             Growlithe   55  ...   Brown
# 64.0              Arcanine   90  ...   Brown
# 65.0               Poliwag   40  ...    Blue
# 66.0             Poliwhirl   65  ...    Blue
# 67.0             Poliwrath   90  ...    Blue
# 69.0                  Abra   25  ...   Brown
# 70.0               Kadabra   40  ...   Brown
# 71.0              Alakazam   55  ...   Brown
# 72.0                Machop   70  ...    Gray
# 73.0               Machoke   80  ...    Gray
# 74.0               Machamp   90  ...    Gray
# 75.0            Bellsprout   50  ...   Green
# 76.0            Weepinbell   65  ...   Green
# 77.0            Victreebel   80  ...   Green
# 78.0             Tentacool   40  ...    Blue
# 79.0            Tentacruel   80  ...    Blue
# 80.0               Geodude   40  ...   Brown
# 81.0              Graveler   55  ...   Brown
# 82.0                 Golem   80  ...   Brown
# 83.0                Ponyta   50  ...  Yellow
# 84.0              Rapidash   65  ...  Yellow
# 85.0              Slowpoke   90  ...    Pink
# 86.0               Slowbro   95  ...    Pink
# 88.0             Magnemite   25  ...    Gray
# 89.0              Magneton   50  ...    Gray
# 91.0            Farfetch'd   52  ...   Brown
# 92.0                 Doduo   35  ...   Brown
# 93.0                Dodrio   60  ...   Brown
# 94.0                  Seel   65  ...   White
# 95.0               Dewgong   90  ...   White
# 96.0                Grimer   80  ...  Purple
# 97.0                   Muk  105  ...  Purple
# 98.0              Shellder   30  ...  Purple
# 99.0              Cloyster   50  ...  Purple
# 100.0               Gastly   30  ...  Purple
# 101.0              Haunter   45  ...  Purple
# 102.0               Gengar   60  ...  Purple
# 103.0                 Onix   35  ...    Gray
# 105.0              Drowzee   60  ...  Yellow
# 106.0                Hypno   85  ...  Yellow
# 107.0               Krabby   30  ...     Red
# 108.0              Kingler   55  ...     Red
# 109.0              Voltorb   40  ...     Red
# 110.0            Electrode   60  ...     Red
# 111.0            Exeggcute   60  ...    Pink
# 112.0            Exeggutor   95  ...  Yellow
# 113.0               Cubone   50  ...   Brown
# 114.0              Marowak   60  ...   Brown
# 116.0            Hitmonlee   50  ...   Brown
# 117.0           Hitmonchan   50  ...   Brown
# 119.0            Lickitung   90  ...    Pink
# 121.0              Koffing   40  ...  Purple
# 122.0              Weezing   65  ...  Purple
# 123.0              Rhyhorn   80  ...    Gray
# 124.0               Rhydon  105  ...    Gray
# 127.0              Chansey  250  ...    Pink
# 129.0              Tangela   65  ...    Blue    Terry
# 131.0           Kangaskhan  105  ...   Brown
# 132.0               Horsea   30  ...    Blue
# 133.0               Seadra   55  ...    Blue
# 135.0              Goldeen   45  ...     Red
# 136.0              Seaking   80  ...     Red
# 137.0               Staryu   30  ...   Brown
# 138.0              Starmie   60  ...  Purple
# 140.0             Mr. Mime   40  ...    Pink
# 141.0              Scyther   70  ...   Green
# 144.0                 Jynx   65  ...     Red
# 146.0           Electabuzz   65  ...  Yellow
# 149.0               Magmar   65  ...     Red
# 151.0               Pinsir   65  ...   Brown
# 152.0               Tauros   75  ...   Brown
# 153.0             Magikarp   20  ...     Red
# 154.0             Gyarados   95  ...    Blue
# 155.0               Lapras  130  ...    Blue
# 156.0                Ditto   48  ...  Purple
# 157.0                Eevee   55  ...   Brown
# 158.0             Vaporeon  130  ...    Blue
# 159.0              Jolteon   65  ...  Yellow
# 160.0              Flareon   65  ...     Red
# 165.0              Porygon   65  ...    Pink
# 168.0              Omanyte   35  ...    Blue
# 169.0              Omastar   70  ...    Blue
# 170.0               Kabuto   30  ...   Brown
# 171.0             Kabutops   60  ...   Brown
# 172.0           Aerodactyl   80  ...  Purple
# 174.0              Snorlax  160  ...   Black
# 175.0             Articuno   90  ...    Blue
# 176.0               Zapdos   90  ...  Yellow
# 177.0              Moltres   90  ...  Yellow
# 178.0              Dratini   41  ...    Blue
# 179.0            Dragonair   61  ...    Blue
# 180.0            Dragonite   91  ...   Brown
# 181.0               Mewtwo  106  ...  Purple
# 182.0                  Mew  100  ...    Pink
# 183.0            Chikorita   45  ...   Green
# 184.0              Bayleef   60  ...   Green
# 185.0             Meganium   80  ...   Green
# 186.0            Cyndaquil   39  ...  Yellow
# 187.0              Quilava   58  ...  Yellow
# 188.0           Typhlosion   78  ...  Yellow
# 189.0             Totodile   50  ...    Blue
# 190.0             Croconaw   65  ...    Blue
# 191.0           Feraligatr   85  ...    Blue
# 192.0              Sentret   35  ...   Brown
# 193.0               Furret   85  ...   Brown
# 194.0             Hoothoot   60  ...   Brown
# 195.0              Noctowl  100  ...   Brown
# 196.0               Ledyba   40  ...     Red
# 197.0               Ledian   55  ...     Red
# 198.0             Spinarak   40  ...   Green
# 199.0              Ariados   70  ...     Red
# 46.0                Crobat   85  ...  Purple
# 200.0             Chinchou   75  ...    Blue
# 201.0              Lanturn  125  ...    Blue
# 25.0                 Pichu   20  ...  Yellow
# 36.0                Cleffa   50  ...    Pink
# 41.0             Igglybuff   90  ...    Pink
# 202.0               Togepi   35  ...   White
# 203.0              Togetic   55  ...   White
# 205.0                 Natu   40  ...   Green
# 206.0                 Xatu   65  ...   Green
# 207.0               Mareep   55  ...   White
# 208.0              Flaaffy   70  ...    Pink
# 209.0             Ampharos   90  ...  Yellow
# 50.0             Bellossom   75  ...   Green
# 211.0               Marill   70  ...    Blue
# 212.0            Azumarill  100  ...    Blue
# 214.0            Sudowoodo   70  ...   Brown
# 68.0              Politoed   90  ...   Green
# 215.0               Hoppip   35  ...    Pink
# 216.0             Skiploom   55  ...   Green
# 217.0             Jumpluff   75  ...    Blue
# 218.0                Aipom   55  ...  Purple
# 220.0              Sunkern   30  ...  Yellow
# 221.0             Sunflora   75  ...  Yellow
# 222.0                Yanma   65  ...     Red
# 224.0               Wooper   55  ...    Blue
# 225.0             Quagsire   95  ...    Blue
# 161.0               Espeon   65  ...  Purple
# 162.0              Umbreon   95  ...   Black
# 226.0              Murkrow   60  ...   Black
# 87.0              Slowking   95  ...    Pink
# 228.0           Misdreavus   60  ...    Gray
# 230.0                Unown   48  ...   Black
# 232.0            Wobbuffet  190  ...    Blue
# 233.0            Girafarig   70  ...  Yellow
# 234.0               Pineco   50  ...    Gray
# 235.0           Forretress   75  ...  Purple
# 236.0            Dunsparce  100  ...  Yellow
# 237.0               Gligar   65  ...  Purple
# 104.0              Steelix   75  ...    Gray
# 239.0             Snubbull   60  ...    Pink
# 240.0             Granbull   90  ...  Purple
# 241.0             Qwilfish   65  ...    Gray
# 142.0               Scizor   70  ...     Red
# 242.0              Shuckle   20  ...  Yellow
# 243.0            Heracross   80  ...    Blue
# 244.0              Sneasel   55  ...   Black
# 246.0            Teddiursa   60  ...   Brown
# 247.0             Ursaring   90  ...   Brown
# 248.0               Slugma   40  ...     Red
# 249.0             Magcargo   50  ...     Red
# 250.0               Swinub   50  ...   Brown
# 251.0            Piloswine  100  ...   Brown
# 253.0              Corsola   55  ...    Pink
# 254.0             Remoraid   35  ...    Gray
# 255.0            Octillery   75  ...     Red
# 256.0             Delibird   45  ...     Red
# 258.0              Mantine   65  ...  Purple
# 259.0             Skarmory   65  ...    Gray
# 260.0             Houndour   45  ...   Black
# 261.0             Houndoom   75  ...   Black
# 134.0              Kingdra   75  ...    Blue
# 262.0               Phanpy   90  ...    Blue
# 263.0              Donphan   90  ...    Gray
# 166.0             Porygon2   85  ...     Red
# 264.0             Stantler   73  ...   Brown
# 265.0             Smeargle   55  ...   White
# 115.0              Tyrogue   35  ...  Purple
# 118.0            Hitmontop   50  ...   Brown
# 143.0             Smoochum   45  ...    Pink
# 145.0               Elekid   45  ...  Yellow
# 148.0                Magby   45  ...     Red
# 266.0              Miltank   95  ...    Pink
# 128.0              Blissey  255  ...    Pink
# 267.0               Raikou   90  ...  Yellow
# 268.0                Entei  115  ...   Brown
# 269.0              Suicune  100  ...    Blue
# 270.0             Larvitar   50  ...   Green
# 271.0              Pupitar   70  ...    Gray
# 272.0            Tyranitar  100  ...   Green
# 273.0                Lugia  106  ...   White
# 274.0                Ho-oh  106  ...     Red
# 275.0               Celebi  100  ...   Green
# 276.0              Treecko   40  ...   Green
# 277.0              Grovyle   50  ...   Green
# 278.0             Sceptile   70  ...   Green
# 279.0              Torchic   45  ...     Red
# 280.0            Combusken   60  ...     Red
# 281.0             Blaziken   80  ...     Red
# 282.0               Mudkip   50  ...    Blue
# 283.0            Marshtomp   70  ...    Blue
# 284.0             Swampert  100  ...    Blue
# 285.0            Poochyena   35  ...    Gray
# 286.0            Mightyena   70  ...    Gray
# 287.0            Zigzagoon   38  ...   Brown
# 288.0              Linoone   78  ...   White
# 289.0              Wurmple   45  ...     Red
# 290.0              Silcoon   50  ...   White
# 291.0            Beautifly   60  ...  Yellow
# 292.0              Cascoon   50  ...  Purple
# 293.0               Dustox   60  ...   Green
# 294.0                Lotad   40  ...   Green
# 295.0               Lombre   60  ...   Green
# 296.0             Ludicolo   80  ...   Green
# 297.0               Seedot   40  ...   Brown
# 298.0              Nuzleaf   70  ...   Brown
# 299.0              Shiftry   90  ...   Brown
# 300.0              Taillow   40  ...    Blue
# 301.0              Swellow   60  ...    Blue
# 302.0              Wingull   40  ...   White
# 303.0             Pelipper   60  ...  Yellow
# 304.0                Ralts   28  ...   White
# 305.0               Kirlia   38  ...   White
# 306.0            Gardevoir   68  ...   White
# 308.0              Surskit   40  ...    Blue
# 309.0           Masquerain   70  ...    Blue
# 310.0            Shroomish   60  ...   Brown
# 311.0              Breloom   60  ...   Green
# 312.0              Slakoth   60  ...   Brown
# 313.0             Vigoroth   80  ...   White
# 314.0              Slaking  150  ...   Brown
# 315.0              Nincada   31  ...    Gray
# 316.0              Ninjask   61  ...  Yellow
# 317.0             Shedinja    1  ...   Brown
# 318.0              Whismur   64  ...    Pink
# 319.0              Loudred   84  ...    Blue
# 320.0              Exploud  104  ...    Blue
# 321.0             Makuhita   72  ...  Yellow
# 322.0             Hariyama  144  ...   Brown
# 210.0              Azurill   50  ...    Blue
# 323.0             Nosepass   30  ...    Gray
# 325.0               Skitty   50  ...    Pink
# ...                    ...  ...  ...     ...      ...
# 509.0             Purrloin   41  ...  Purple
# 510.0              Liepard   64  ...  Purple
# 511.0              Pansage   50  ...   Green
# 512.0             Simisage   75  ...   Green
# 513.0              Pansear   50  ...     Red
# 514.0             Simisear   75  ...     Red
# 515.0              Panpour   50  ...    Blue
# 516.0             Simipour   75  ...    Blue
# 517.0                Munna   76  ...    Pink
# 518.0             Musharna  116  ...    Pink
# 519.0               Pidove   50  ...    Gray
# 520.0            Tranquill   62  ...    Gray
# 521.0             Unfezant   80  ...    Gray
# 522.0              Blitzle   45  ...   Black
# 523.0            Zebstrika   75  ...   Black
# 524.0           Roggenrola   55  ...    Blue
# 525.0              Boldore   70  ...    Blue
# 526.0             Gigalith   85  ...    Blue
# 527.0               Woobat   55  ...    Blue
# 528.0              Swoobat   67  ...    Blue
# 529.0              Drilbur   60  ...    Gray
# 530.0            Excadrill  110  ...    Gray
# 531.0               Audino  103  ...    Pink
# 532.0              Timburr   75  ...    Gray
# 533.0              Gurdurr   85  ...    Gray
# 534.0           Conkeldurr  105  ...   Brown
# 535.0              Tympole   50  ...    Blue
# 536.0            Palpitoad   75  ...    Blue
# 537.0           Seismitoad  105  ...    Blue
# 538.0                Throh  120  ...     Red
# 539.0                 Sawk   75  ...    Blue
# 540.0             Sewaddle   45  ...  Yellow
# 541.0             Swadloon   55  ...   Green
# 542.0             Leavanny   75  ...  Yellow
# 543.0             Venipede   30  ...     Red
# 544.0           Whirlipede   40  ...    Gray
# 545.0            Scolipede   60  ...     Red
# 546.0             Cottonee   40  ...   Green
# 547.0           Whimsicott   60  ...   Green
# 548.0              Petilil   45  ...   Green
# 549.0            Lilligant   70  ...   Green
# 550.0             Basculin   70  ...   Green
# 551.0              Sandile   50  ...   Brown
# 552.0             Krokorok   60  ...   Brown
# 553.0           Krookodile   95  ...     Red
# 554.0             Darumaka   70  ...     Red
# 555.0           Darmanitan  105  ...     Red
# 555.1       Darmanitan (Z)  105  ...     Red
# 556.0             Maractus   75  ...   Green
# 557.0              Dwebble   50  ...     Red
# 558.0              Crustle   70  ...     Red
# 559.0              Scraggy   50  ...  Yellow
# 560.0              Scrafty   65  ...     Red
# 561.0             Sigilyph   72  ...   Black
# 562.0               Yamask   38  ...   Black
# 563.0           Cofagrigus   58  ...  Yellow
# 564.0             Tirtouga   54  ...    Blue
# 565.0           Carracosta   74  ...    Blue
# 566.0               Archen   55  ...  Yellow
# 567.0             Archeops   75  ...  Yellow
# 568.0             Trubbish   50  ...   Green
# 569.0             Garbodor   80  ...   Green
# 570.0                Zorua   40  ...    Gray
# 571.0              Zoroark   60  ...    Gray
# 572.0             Minccino   55  ...    Gray
# 573.0             Cinccino   75  ...    Gray
# 574.0              Gothita   45  ...  Purple
# 575.0            Gothorita   60  ...  Purple
# 576.0           Gothitelle   70  ...  Purple
# 577.0              Solosis   45  ...   Green
# 578.0              Duosion   65  ...   Green
# 579.0            Reuniclus  110  ...   Green
# 580.0             Ducklett   62  ...    Blue
# 581.0               Swanna   75  ...   White
# 582.0            Vanillite   36  ...   White
# 583.0            Vanillish   51  ...   White
# 584.0            Vanilluxe   71  ...   White
# 585.0             Deerling   60  ...  Yellow
# 586.0             Sawsbuck   80  ...   Brown
# 587.0               Emolga   55  ...   White
# 588.0           Karrablast   50  ...    Blue
# 589.0           Escavalier   70  ...    Gray
# 590.0              Foongus   69  ...   White
# 591.0            Amoonguss  114  ...   White
# 592.0             Frillish   55  ...   White
# 593.0            Jellicent  100  ...   White
# 594.0            Alomomola  165  ...    Pink
# 595.0               Joltik   50  ...  Yellow
# 596.0           Galvantula   70  ...  Yellow
# 597.0            Ferroseed   44  ...    Gray
# 598.0           Ferrothorn   74  ...    Gray
# 599.0                Klink   40  ...    Gray
# 600.0                Klang   60  ...    Gray
# 601.0            Klinklang   60  ...    Gray
# 602.0               Tynamo   35  ...   White
# 603.0            Eelektrik   65  ...    Blue
# 604.0           Eelektross   85  ...    Blue
# 605.0               Elgyem   55  ...    Blue
# 606.0             Beheeyem   75  ...   Brown
# 607.0              Litwick   50  ...   White
# 608.0              Lampent   60  ...   Black
# 609.0           Chandelure   60  ...   Black
# 610.0                 Axew   46  ...   Green
# 611.0              Fraxure   66  ...   Green
# 612.0              Haxorus   76  ...  Yellow
# 613.0              Cubchoo   55  ...   White
# 614.0              Beartic   95  ...   White
# 615.0            Cryogonal   70  ...    Blue
# 616.0              Shelmet   50  ...     Red
# 617.0             Accelgor   80  ...     Red
# 618.0             Stunfisk  109  ...   Brown
# 619.0              Mienfoo   45  ...  Yellow
# 620.0             Mienshao   65  ...  Purple
# 621.0            Druddigon   77  ...     Red
# 622.0               Golett   59  ...   Green
# 623.0               Golurk   89  ...   Green
# 624.0             Pawniard   45  ...     Red
# 625.0              Bisharp   65  ...     Red
# 626.0           Bouffalant   95  ...   Brown
# 627.0              Rufflet   70  ...   White
# 628.0             Braviary  100  ...     Red
# 629.0              Vullaby   70  ...   Brown
# 630.0            Mandibuzz  110  ...   Brown
# 631.0              Heatmor   85  ...     Red
# 632.0               Durant   58  ...    Gray
# 633.0                Deino   52  ...    Blue
# 634.0             Zweilous   72  ...    Blue
# 635.0            Hydreigon   92  ...    Blue
# 636.0             Larvesta   55  ...   White
# 637.0            Volcarona   85  ...   White
# 638.0             Cobalion   91  ...    Blue
# 639.0            Terrakion   91  ...    Gray
# 640.0             Virizion   91  ...   Green
# 641.0             Tornadus   79  ...   Green
# 642.0            Thundurus   79  ...    Blue
# 643.0             Reshiram  100  ...   White
# 644.0               Zekrom  100  ...   Black
# 645.0             Landorus   89  ...   Brown
# 646.0               Kyurem  125  ...    Gray
# 647.0               Keldeo   91  ...  Yellow
# 648.0         Meloetta (A)  100  ...   White
# 648.1         Meloetta (P)  100  ...   White
# 649.0             Genesect   71  ...  Purple
# 650.0              Chespin   56  ...   Green
# 651.0            Quilladin   61  ...   Green
# 652.0           Chesnaught   88  ...   Green
# 653.0             Fennekin   40  ...     Red
# 654.0              Braixen   59  ...     Red
# 655.0              Delphox   75  ...     Red
# 656.0              Froakie   41  ...    Blue
# 657.0            Frogadier   54  ...    Blue
# 658.0             Greninja   72  ...    Blue
# 659.0             Bunnelby   38  ...   Brown
# 660.0            Diggersby   85  ...   Brown
# 661.0           Fletchling   45  ...     Red
# 662.0          Fletchinder   62  ...     Red
# 663.0           Talonflame   78  ...     Red
# 664.0           Scatterbug   38  ...   Black
# 665.0               Spewpa   45  ...   Black
# 666.0             Vivillon   80  ...   Black
# 667.0               Litleo   62  ...   Brown
# 668.0               Pyroar   86  ...   Brown
# 669.0              Flabébé   44  ...   White
# 670.0              Floette   54  ...   White
# 671.0              Florges   78  ...   White
# 672.0               Skiddo   66  ...   Brown
# 673.0               Gogoat  123  ...   Brown
# 674.0              Pancham   67  ...   White
# 675.0              Pangoro   95  ...   White
# 676.0              Furfrou   75  ...   White
# 677.0               Espurr   62  ...    Gray
# 678.0             Meowstic   74  ...   White
# 679.0              Honedge   45  ...   Brown
# 680.0             Doublade   59  ...   Brown
# 681.0            Aegislash   60  ...   Brown
# 682.0             Spritzee   78  ...    Pink
# 683.0           Aromatisse  101  ...    Pink
# 684.0              Swirlix   62  ...   White
# 685.0             Slurpuff   82  ...   White
# 686.0                Inkay   53  ...    Blue
# 687.0              Malamar   86  ...    Blue
# 688.0              Binacle   42  ...   Brown
# 689.0           Barbaracle   72  ...   Brown
# 690.0               Skrelp   50  ...   Brown
# 691.0             Dragalge   65  ...   Brown
# 692.0            Clauncher   50  ...    Blue
# 693.0            Clawitzer   71  ...    Blue
# 694.0           Helioptile   44  ...  Yellow
# 695.0            Heliolisk   62  ...  Yellow
# 696.0               Tyrunt   58  ...   Brown
# 697.0            Tyrantrum   82  ...     Red
# 698.0               Amaura   77  ...    Blue
# 699.0              Aurorus  123  ...    Blue
# 700.0              Sylveon   95  ...    Pink
# 701.0             Hawlucha   78  ...   Green
# 702.0              Dedenne   67  ...  Yellow
# 703.0              Carbink   50  ...    Gray
# 704.0                Goomy   45  ...  Purple
# 705.0              Sliggoo   68  ...  Purple
# 706.0               Goodra   90  ...  Purple
# 707.0               Klefki   57  ...    Gray
# 708.0             Phantump   43  ...   Brown
# 709.0            Trevenant   85  ...   Brown
# 710.0            Pumpkaboo   44  ...   Brown
# 711.0            Gourgeist   55  ...   Brown
# 712.0             Bergmite   55  ...    Blue
# 713.0              Avalugg   95  ...    Blue
# 714.0               Noibat   40  ...  Purple
# 715.0              Noivern   85  ...  Purple
# 716.0              Xerneas  126  ...    Blue
# 717.0              Yveltal  126  ...     Red
# 718.0              Zygarde  108  ...   Green
# 719.0              Diancie   50  ...    Pink
# 720.0            Hoopa (C)   80  ...  Purple
# 720.0            Hoopa (U)   80  ...  Purple
# 721.0            Volcanion   80  ...   Brown
# 722.0               Rowlet   68  ...   Brown
# 723.0              Dartrix   78  ...   Brown
# 724.0            Decidueye   78  ...   Brown
# 725.0               Litten   45  ...     Red
# 726.0             Torracat   65  ...     Red
# 727.0           Incineroar   95  ...     Red
# 728.0              Popplio   50  ...    Blue
# 729.0              Brionne   60  ...    Blue
# 730.0            Primarina   80  ...    Blue
# 731.0              Pikipek   35  ...   Black
# 732.0             Trumbeak   55  ...   Black
# 733.0            Toucannon   80  ...   Black
# 734.0              Yungoos   48  ...   Brown
# 735.0             Gumshoos   88  ...   Brown
# 736.0              Grubbin   47  ...    Gray
# 737.0            Charjabug   57  ...   Green
# 738.0             Vikavolt   77  ...    Blue
# 739.0           Crabrawler   47  ...  Purple
# 740.0         Crabominable   97  ...   White
# 741.0             Oricorio   75  ...     Red
# 742.0             Cutiefly   40  ...  Yellow
# 743.0             Ribombee   60  ...  Yellow
# 744.0             Rockruff   45  ...   Brown
# 745.0    Lycanroc (midday)   75  ...
# 745.1  Lycanroc (midnight)   85  ...   Brown
# 746.0    Wishiwashi (solo)   45  ...    Blue
# 746.1  Wishiwashi (school)   45  ...    Blue
# 747.0             Mareanie   50  ...    Blue
# 748.0              Toxapex   50  ...    Blue
# 749.0              Mudbray   70  ...   Brown
# 750.0             Mudsdale  100  ...   Brown
# 751.0             Dewpider   38  ...   Green
# 752.0            Araquanid   68  ...   Green
# 753.0             Fomantis   40  ...    Pink
# 754.0             Lurantis   70  ...    Pink
# 755.0             Morelull   40  ...  Purple
# 756.0            Shiinotic   60  ...  Purple
# 757.0             Salandit   48  ...   Black
# 758.0             Salazzle   68  ...   Black
# 759.0              Stufful   70  ...    Pink
# 760.0               Bewear  120  ...    Pink
# 761.0            Bounsweet   42  ...  Purple
# 762.0              Steenee   52  ...  Purple
# 763.0             Tsareena   72  ...  Purple
# 764.0               Comfey   51  ...   Green
# 765.0             Oranguru   90  ...   White
# 766.0            Passimian  100  ...   White
# 767.0               Wimpod   25  ...    Gray
# 768.0            Golisopod   75  ...    Gray
# 769.0            Sandygast   55  ...   Brown
# 770.0            Palossand   85  ...   Brown
# 771.0            Pyukumuku   55  ...   Black
# 772.0           Type: Null   95  ...    Gray
# 773.0             Silvally   95  ...    Gray
# 774.0      Minior (meteor)   60  ...   Brown
# 774.1        Minior (core)   60  ...    Pink
# 775.0               Komala   65  ...    Blue
# 776.0           Turtonator   60  ...     Red
# 777.0           Togedemaru   65  ...    Gray
# 778.0              Mimikyu   55  ...  Yellow
# 779.0              Bruxish   68  ...    Pink
# 780.0               Drampa   78  ...   White
# 781.0             Dhelmise   70  ...   Green
# 782.0             Jangmo-o   45  ...    Gray
# 783.0             Hakamo-o   55  ...    Gray
# 784.0              Kommo-o   75  ...    Gray
# 785.0            Tapu Koko   70  ...  Yellow
# 786.0            Tapu Lele   70  ...    Pink
# 787.0            Tapu Bulu   70  ...     Red
# 788.0            Tapu Fini   70  ...  Purple
# 789.0               Cosmog   43  ...    Blue
# 790.0              Cosmoem   43  ...    Blue
# 791.0             Solgaleo  137  ...   White
# 792.0               Lunala  137  ...  Purple
# 793.0             Nihilego  109  ...   White
# 794.0             Buzzwole  107  ...     Red
# 795.0            Pheromosa   71  ...   White
# 796.0            Xurkitree   83  ...   Black
# 797.0           Celesteela   97  ...   Green
# 798.0              Kartana   59  ...   White
# 799.0             Guzzlord  223  ...   Black
# 800.0             Necrozma   97  ...   Black
# 801.0             Magearna   80  ...    Gray
# 802.0            Marshadow   90  ...    Gray
#
# [820 rows x 15 columns]

# %%
pokedex_df['Total'] > 520
# Out:
# 1.0      False
# 2.0      False
# 3.0       True
# 4.0      False
# 5.0      False
# 6.0       True
# 7.0      False
# 8.0      False
# 9.0       True
# 10.0     False
# 11.0     False
# 12.0     False
# 13.0     False
# 14.0     False
# 15.0     False
# 16.0     False
# 17.0     False
# 18.0     False
# 19.0     False
# 20.0     False
# 21.0     False
# 22.0     False
# 23.0     False
# 24.0     False
# 26.0     False
# 27.0     False
# 28.0     False
# 29.0     False
# 30.0     False
# 31.0     False
# 32.0     False
# 33.0     False
# 34.0     False
# 35.0     False
# 37.0     False
# 38.0     False
# 39.0     False
# 40.0     False
# 42.0     False
# 43.0     False
# 44.0     False
# 45.0     False
# 47.0     False
# 48.0     False
# 49.0     False
# 51.0     False
# 52.0     False
# 53.0     False
# 54.0     False
# 55.0     False
# 56.0     False
# 57.0     False
# 58.0     False
# 59.0     False
# 60.0     False
# 61.0     False
# 62.0     False
# 63.0     False
# 64.0      True
# 65.0     False
# 66.0     False
# 67.0     False
# 69.0     False
# 70.0     False
# 71.0     False
# 72.0     False
# 73.0     False
# 74.0     False
# 75.0     False
# 76.0     False
# 77.0     False
# 78.0     False
# 79.0     False
# 80.0     False
# 81.0     False
# 82.0     False
# 83.0     False
# 84.0     False
# 85.0     False
# 86.0     False
# 88.0     False
# 89.0     False
# 91.0     False
# 92.0     False
# 93.0     False
# 94.0     False
# 95.0     False
# 96.0     False
# 97.0     False
# 98.0     False
# 99.0     False
# 100.0    False
# 101.0    False
# 102.0    False
# 103.0    False
# 105.0    False
# 106.0    False
# 107.0    False
# 108.0    False
# 109.0    False
# 110.0    False
# 111.0    False
# 112.0    False
# 113.0    False
# 114.0    False
# 116.0    False
# 117.0    False
# 119.0    False
# 121.0    False
# 122.0    False
# 123.0    False
# 124.0    False
# 127.0    False
# 129.0    False
# 131.0    False
# 132.0    False
# 133.0    False
# 135.0    False
# 136.0    False
# 137.0    False
# 138.0    False
# 140.0    False
# 141.0    False
# 144.0    False
# 146.0    False
# 149.0    False
# 151.0    False
# 152.0    False
# 153.0    False
# 154.0     True
# 155.0     True
# 156.0    False
# 157.0    False
# 158.0     True
# 159.0     True
# 160.0     True
# 165.0    False
# 168.0    False
# 169.0    False
# 170.0    False
# 171.0    False
# 172.0    False
# 174.0     True
# 175.0     True
# 176.0     True
# 177.0     True
# 178.0    False
# 179.0    False
# 180.0     True
# 181.0     True
# 182.0     True
# 183.0    False
# 184.0    False
# 185.0     True
# 186.0    False
# 187.0    False
# 188.0     True
# 189.0    False
# 190.0    False
# 191.0     True
# 192.0    False
# 193.0    False
# 194.0    False
# 195.0    False
# 196.0    False
# 197.0    False
# 198.0    False
# 199.0    False
# 46.0      True
# 200.0    False
# 201.0    False
# 25.0     False
# 36.0     False
# 41.0     False
# 202.0    False
# 203.0    False
# 205.0    False
# 206.0    False
# 207.0    False
# 208.0    False
# 209.0    False
# 50.0     False
# 211.0    False
# 212.0    False
# 214.0    False
# 68.0     False
# 215.0    False
# 216.0    False
# 217.0    False
# 218.0    False
# 220.0    False
# 221.0    False
# 222.0    False
# 224.0    False
# 225.0    False
# 161.0     True
# 162.0     True
# 226.0    False
# 87.0     False
# 228.0    False
# 230.0    False
# 232.0    False
# 233.0    False
# 234.0    False
# 235.0    False
# 236.0    False
# 237.0    False
# 104.0    False
# 239.0    False
# 240.0    False
# 241.0    False
# 142.0    False
# 242.0    False
# 243.0    False
# 244.0    False
# 246.0    False
# 247.0    False
# 248.0    False
# 249.0    False
# 250.0    False
# 251.0    False
# 253.0    False
# 254.0    False
# 255.0    False
# 256.0    False
# 258.0    False
# 259.0    False
# 260.0    False
# 261.0    False
# 134.0     True
# 262.0    False
# 263.0    False
# 166.0    False
# 264.0    False
# 265.0    False
# 115.0    False
# 118.0    False
# 143.0    False
# 145.0    False
# 148.0    False
# 266.0    False
# 128.0     True
# 267.0     True
# 268.0     True
# 269.0     True
# 270.0    False
# 271.0    False
# 272.0     True
# 273.0     True
# 274.0     True
# 275.0     True
# 276.0    False
# 277.0    False
# 278.0     True
# 279.0    False
# 280.0    False
# 281.0     True
# 282.0    False
# 283.0    False
# 284.0     True
# 285.0    False
# 286.0    False
# 287.0    False
# 288.0    False
# 289.0    False
# 290.0    False
# 291.0    False
# 292.0    False
# 293.0    False
# 294.0    False
# 295.0    False
# 296.0    False
# 297.0    False
# 298.0    False
# 299.0    False
# 300.0    False
# 301.0    False
# 302.0    False
# 303.0    False
# 304.0    False
# 305.0    False
# 306.0    False
# 308.0    False
# 309.0    False
# 310.0    False
# 311.0    False
# 312.0    False
# 313.0    False
# 314.0     True
# 315.0    False
# 316.0    False
# 317.0    False
# 318.0    False
# 319.0    False
# 320.0    False
# 321.0    False
# 322.0    False
# 210.0    False
# 323.0    False
# 325.0    False
#          ...
# 509.0    False
# 510.0    False
# 511.0    False
# 512.0    False
# 513.0    False
# 514.0    False
# 515.0    False
# 516.0    False
# 517.0    False
# 518.0    False
# 519.0    False
# 520.0    False
# 521.0    False
# 522.0    False
# 523.0    False
# 524.0    False
# 525.0    False
# 526.0    False
# 527.0    False
# 528.0    False
# 529.0    False
# 530.0    False
# 531.0    False
# 532.0    False
# 533.0    False
# 534.0    False
# 535.0    False
# 536.0    False
# 537.0    False
# 538.0    False
# 539.0    False
# 540.0    False
# 541.0    False
# 542.0    False
# 543.0    False
# 544.0    False
# 545.0    False
# 546.0    False
# 547.0    False
# 548.0    False
# 549.0    False
# 550.0    False
# 551.0    False
# 552.0    False
# 553.0    False
# 554.0    False
# 555.0    False
# 555.1     True
# 556.0    False
# 557.0    False
# 558.0    False
# 559.0    False
# 560.0    False
# 561.0    False
# 562.0    False
# 563.0    False
# 564.0    False
# 565.0    False
# 566.0    False
# 567.0     True
# 568.0    False
# 569.0    False
# 570.0    False
# 571.0    False
# 572.0    False
# 573.0    False
# 574.0    False
# 575.0    False
# 576.0    False
# 577.0    False
# 578.0    False
# 579.0    False
# 580.0    False
# 581.0    False
# 582.0    False
# 583.0    False
# 584.0     True
# 585.0    False
# 586.0    False
# 587.0    False
# 588.0    False
# 589.0    False
# 590.0    False
# 591.0    False
# 592.0    False
# 593.0    False
# 594.0    False
# 595.0    False
# 596.0    False
# 597.0    False
# 598.0    False
# 599.0    False
# 600.0    False
# 601.0    False
# 602.0    False
# 603.0    False
# 604.0    False
# 605.0    False
# 606.0    False
# 607.0    False
# 608.0    False
# 609.0    False
# 610.0    False
# 611.0    False
# 612.0     True
# 613.0    False
# 614.0    False
# 615.0    False
# 616.0    False
# 617.0    False
# 618.0    False
# 619.0    False
# 620.0    False
# 621.0    False
# 622.0    False
# 623.0    False
# 624.0    False
# 625.0    False
# 626.0    False
# 627.0    False
# 628.0    False
# 629.0    False
# 630.0    False
# 631.0    False
# 632.0    False
# 633.0    False
# 634.0    False
# 635.0     True
# 636.0    False
# 637.0     True
# 638.0     True
# 639.0     True
# 640.0     True
# 641.0     True
# 642.0     True
# 643.0     True
# 644.0     True
# 645.0     True
# 646.0     True
# 647.0     True
# 648.0     True
# 648.1     True
# 649.0     True
# 650.0    False
# 651.0    False
# 652.0     True
# 653.0    False
# 654.0    False
# 655.0     True
# 656.0    False
# 657.0    False
# 658.0     True
# 659.0    False
# 660.0    False
# 661.0    False
# 662.0    False
# 663.0    False
# 664.0    False
# 665.0    False
# 666.0    False
# 667.0    False
# 668.0    False
# 669.0    False
# 670.0    False
# 671.0     True
# 672.0    False
# 673.0     True
# 674.0    False
# 675.0    False
# 676.0    False
# 677.0    False
# 678.0    False
# 679.0    False
# 680.0    False
# 681.0    False
# 682.0    False
# 683.0    False
# 684.0    False
# 685.0    False
# 686.0    False
# 687.0    False
# 688.0    False
# 689.0    False
# 690.0    False
# 691.0    False
# 692.0    False
# 693.0    False
# 694.0    False
# 695.0    False
# 696.0    False
# 697.0     True
# 698.0    False
# 699.0     True
# 700.0     True
# 701.0    False
# 702.0    False
# 703.0    False
# 704.0    False
# 705.0    False
# 706.0     True
# 707.0    False
# 708.0    False
# 709.0    False
# 710.0    False
# 711.0    False
# 712.0    False
# 713.0    False
# 714.0    False
# 715.0     True
# 716.0     True
# 717.0     True
# 718.0     True
# 719.0     True
# 720.0     True
# 720.0     True
# 721.0     True
# 722.0    False
# 723.0    False
# 724.0     True
# 725.0    False
# 726.0    False
# 727.0     True
# 728.0    False
# 729.0    False
# 730.0     True
# 731.0    False
# 732.0    False
# 733.0    False
# 734.0    False
# 735.0    False
# 736.0    False
# 737.0    False
# 738.0    False
# 739.0    False
# 740.0    False
# 741.0    False
# 742.0    False
# 743.0    False
# 744.0    False
# 745.0    False
# 745.1    False
# 746.0    False
# 746.1     True
# 747.0    False
# 748.0    False
# 749.0    False
# 750.0    False
# 751.0    False
# 752.0    False
# 753.0    False
# 754.0    False
# 755.0    False
# 756.0    False
# 757.0    False
# 758.0    False
# 759.0    False
# 760.0    False
# 761.0    False
# 762.0    False
# 763.0    False
# 764.0    False
# 765.0    False
# 766.0    False
# 767.0    False
# 768.0     True
# 769.0    False
# 770.0    False
# 771.0    False
# 772.0     True
# 773.0     True
# 774.0    False
# 774.1    False
# 775.0    False
# 776.0    False
# 777.0    False
# 778.0    False
# 779.0    False
# 780.0    False
# 781.0    False
# 782.0    False
# 783.0    False
# 784.0     True
# 785.0     True
# 786.0     True
# 787.0     True
# 788.0     True
# 789.0    False
# 790.0    False
# 791.0     True
# 792.0     True
# 793.0     True
# 794.0     True
# 795.0     True
# 796.0     True
# 797.0     True
# 798.0     True
# 799.0     True
# 800.0     True
# 801.0     True
# 802.0     True
# Name: Total, Length: 820, dtype: bool

# %% [markdown]
# If you take that boolean column and use it to index the dataframe, you can get all of the entries that satisfy that condition.

# %%
pokedex_df.loc[pokedex_df['Total']>=520] # all of the pokemon with total base stats greater than 500
# Out:
#                    Pokemon   HP  Atk  ...       Hidden Ability   Color Nickname
# 3.0               Venusaur   80   82  ...          Chlorophyll   Green
# 6.0              Charizard   78   84  ...          Solar Power     Red
# 9.0              Blastoise   79   83  ...            Rain Dish    Blue
# 64.0              Arcanine   90  110  ...            Justified   Brown
# 99.0              Cloyster   50   90  ...             Overcoat  Purple
# 112.0            Exeggutor   95   95  ...              Harvest  Yellow
# 138.0              Starmie   60   75  ...             Analytic  Purple
# 154.0             Gyarados   95  125  ...                Moxie    Blue
# 155.0               Lapras  130   85  ...            Hydration    Blue
# 158.0             Vaporeon  130   65  ...            Hydration    Blue
# 159.0              Jolteon   65   65  ...           Quick Feet  Yellow
# 160.0              Flareon   65  130  ...                 Guts     Red
# 174.0              Snorlax  160  110  ...             Gluttony   Black
# 175.0             Articuno   90   85  ...           Snow Cloak    Blue
# 176.0               Zapdos   90   90  ...         Lightningrod  Yellow
# 177.0              Moltres   90  100  ...           Flame Body  Yellow
# 180.0            Dragonite   91  134  ...           Multiscale   Brown
# 181.0               Mewtwo  106  110  ...              Unnerve  Purple
# 182.0                  Mew  100  100  ...                         Pink
# 185.0             Meganium   80   82  ...           Leaf Guard   Green
# 188.0           Typhlosion   78   84  ...           Flash Fire  Yellow
# 191.0           Feraligatr   85  105  ...          Sheer Force    Blue
# 46.0                Crobat   85   90  ...          Infiltrator  Purple
# 161.0               Espeon   65   65  ...         Magic Bounce  Purple
# 162.0              Umbreon   95   65  ...          Inner Focus   Black
# 134.0              Kingdra   75   95  ...                 Damp    Blue
# 128.0              Blissey  255   10  ...               Healer    Pink
# 267.0               Raikou   90   85  ...          Volt Absorb  Yellow
# 268.0                Entei  115  115  ...           Flash Fire   Brown
# 269.0              Suicune  100   75  ...         Water Absorb    Blue
# 272.0            Tyranitar  100  134  ...              Unnerve   Green
# 273.0                Lugia  106   90  ...           Multiscale   White
# 274.0                Ho-oh  106  130  ...          Regenerator     Red
# 275.0               Celebi  100  100  ...                        Green
# 278.0             Sceptile   70   85  ...             Unburden   Green
# 281.0             Blaziken   80  120  ...          Speed Boost     Red
# 284.0             Swampert  100  110  ...                 Damp    Blue
# 314.0              Slaking  150  160  ...                        Brown
# 331.0               Aggron   70  110  ...          Heavy Metal    Gray
# 357.0               Flygon   80  100  ...                        Green
# 377.0              Milotic   95   60  ...           Cute Charm    Pink
# 394.0              Walrein  110   80  ...            Oblivious    Blue
# 402.0            Salamence   95  135  ...                Moxie    Blue
# 405.0            Metagross   80  135  ...          Light Metal    Blue
# 406.0             Regirock   80  100  ...               Sturdy   Brown
# 407.0               Regice   80   50  ...             Ice Body    Blue
# 408.0            Registeel   80   75  ...          Light Metal    Gray
# 409.0               Latias   80   80  ...                          Red
# 410.0               Latios   80   90  ...                         Blue
# 411.0               Kyogre  100  100  ...                         Blue
# 412.0              Groudon  100  150  ...                          Red
# 413.0             Rayquaza  105  150  ...                        Green
# 414.0              Jirachi  100  100  ...                       Yellow
# 415.0           Deoxys (N)   50  150  ...                          Red
# 415.1           Deoxys (A)   50  180  ...                          Red
# 415.2           Deoxys (D)   50   70  ...                          Red
# 415.3           Deoxys (S)   50   95  ...                          Red
# 418.0             Torterra   95  109  ...          Shell Armor   Green
# 421.0            Infernape   76  104  ...            Iron Fist   Brown
# 424.0             Empoleon   84   86  ...              Defiant    Blue
# 434.0               Luxray   80  120  ...                 Guts    Blue
# 465.0             Garchomp  108  130  ...           Rough Skin    Blue
# 467.0              Lucario   70  110  ...            Justified    Blue
# 469.0            Hippowdon  108  112  ...           Sand Force   Brown
# 90.0             Magnezone   70   70  ...             Analytic    Gray
# 125.0            Rhyperior  115  140  ...             Reckless    Gray
# 130.0            Tangrowth  100  100  ...          Regenerator    Blue
# 147.0           Electivire   75  123  ...         Vital Spirit  Yellow
# 150.0            Magmortar   75   95  ...         Vital Spirit     Red
# 204.0             Togekiss   85   50  ...           Super Luck   White
# 163.0              Leafeon   65  110  ...          Chlorophyll   Green
# 164.0              Glaceon   65   60  ...             Ice Body    Blue
# 252.0            Mamoswine  110  130  ...            Thick Fat   Brown
# 167.0            Porygon-Z   85   80  ...             Analytic     Red
# 324.0            Probopass   60   55  ...           Sand Force    Gray
# 384.0             Dusknoir   45  100  ...                        Black
# 479.1         Rotom (Heat)   50   65  ...                          Red
# 479.2         Rotom (Wash)   50   65  ...                          Red
# 479.3        Rotom (Frost)   50   65  ...                          Red
# 479.4         Rotom (Spin)   50   65  ...                          Red
# 479.5          Rotom (Cut)   50   65  ...                          Red
# 480.0                 Uxie   75   75  ...                       Yellow
# 481.0              Mesprit   80  105  ...                         Pink
# 482.0                Azelf   75  125  ...                         Blue
# 483.0               Dialga  100  120  ...            Telepathy   White
# 484.0               Palkia   90  120  ...            Telepathy  Purple
# 485.0              Heatran   91   90  ...           Flame Body   Brown
# 486.0            Regigigas  110  160  ...                        White
# 487.0             Giratina  150  100  ...            Telepathy   Black
# 487.1         Giratina (O)  150  120  ...                        Black
# 488.0            Cresselia  120   70  ...                       Yellow
# 490.0              Manaphy  100  100  ...                         Blue
# 491.0              Darkrai   70   90  ...                        Black
# 492.0              Shaymin  100  100  ...                        Green
# 492.1          Shaymin (S)  100  103  ...                        Green
# 493.0               Arceus  120  120  ...                         Gray
# 494.0              Victini  100  100  ...                       Yellow
# 497.0            Serperior   75   75  ...             Contrary   Green
# 500.0               Emboar  110  123  ...             Reckless     Red
# 503.0             Samurott   95  100  ...          Shell Armor    Blue
# 555.1       Darmanitan (Z)  105   30  ...             Zen Mode     Red
# 567.0             Archeops   75  140  ...                       Yellow
# 584.0            Vanilluxe   71   95  ...           Weak Armor   White
# 601.0            Klinklang   60  100  ...           Clear Body    Gray
# 609.0           Chandelure   60   55  ...           Shadow Tag   Black
# 612.0              Haxorus   76  147  ...              Unnerve  Yellow
# 635.0            Hydreigon   92  105  ...                         Blue
# 637.0            Volcarona   85   60  ...                Swarm   White
# 638.0             Cobalion   91   90  ...                         Blue
# 639.0            Terrakion   91  129  ...                         Gray
# 640.0             Virizion   91   90  ...                        Green
# 641.0             Tornadus   79  115  ...              Defiant   Green
# 642.0            Thundurus   79  115  ...              Defiant    Blue
# 643.0             Reshiram  100  120  ...                        White
# 644.0               Zekrom  100  150  ...                        Black
# 645.0             Landorus   89  125  ...          Sheer Force   Brown
# 646.0               Kyurem  125  130  ...                         Gray
# 647.0               Keldeo   91   72  ...                       Yellow
# 648.0         Meloetta (A)  100   77  ...                        White
# 648.1         Meloetta (P)  100  128  ...                        White
# 649.0             Genesect   71  120  ...                       Purple
# 652.0           Chesnaught   88  107  ...          Bulletproof   Green
# 655.0              Delphox   75   69  ...             Magician     Red
# 658.0             Greninja   72   95  ...              Protean    Blue
# 671.0              Florges   78   65  ...            Symbiosis   White
# 673.0               Gogoat  123  100  ...           Grass Pelt   Brown
# 681.0            Aegislash   60   50  ...                        Brown
# 697.0            Tyrantrum   82  121  ...               Sturdy     Red
# 699.0              Aurorus  123   77  ...         Snow Warning    Blue
# 700.0              Sylveon   95   65  ...             Pixilate    Pink
# 706.0               Goodra   90  100  ...                Gooey  Purple
# 715.0              Noivern   85   70  ...            Telepathy  Purple
# 716.0              Xerneas  126  131  ...                         Blue
# 717.0              Yveltal  126  131  ...                          Red
# 718.0              Zygarde  108  100  ...                        Green
# 719.0              Diancie   50  100  ...  Magic Bounce (Mega)    Pink
# 720.0            Hoopa (C)   80  110  ...                       Purple
# 720.0            Hoopa (U)   80  160  ...                       Purple
# 721.0            Volcanion   80  110  ...                        Brown
# 724.0            Decidueye   78  107  ...                        Brown
# 727.0           Incineroar   95  115  ...                          Red
# 730.0            Primarina   80   74  ...                         Blue
# 746.1  Wishiwashi (school)   45  140  ...                         Blue
# 768.0            Golisopod   75  125  ...                         Gray
# 772.0           Type: Null   95   95  ...                         Gray
# 773.0             Silvally   95   95  ...                         Gray
# 784.0              Kommo-o   75  110  ...             Overcoat    Gray
# 785.0            Tapu Koko   70  115  ...                       Yellow
# 786.0            Tapu Lele   70   85  ...                         Pink
# 787.0            Tapu Bulu   70  130  ...                          Red
# 788.0            Tapu Fini   70   75  ...                       Purple
# 791.0             Solgaleo  137  137  ...                        White
# 792.0               Lunala  137  113  ...                       Purple
# 793.0             Nihilego  109   53  ...                        White
# 794.0             Buzzwole  107  139  ...                          Red
# 795.0            Pheromosa   71  137  ...                        White
# 796.0            Xurkitree   83   89  ...                        Black
# 797.0           Celesteela   97  101  ...                        Green
# 798.0              Kartana   59  181  ...                        White
# 799.0             Guzzlord  223  101  ...                        Black
# 800.0             Necrozma   97  107  ...                        Black
# 801.0             Magearna   80   95  ...                         Gray
# 802.0            Marshadow   90  125  ...                         Gray
#
# [163 rows x 15 columns]

# %%
# Get all of the pokemon of a given color
pokedex_df.loc[pokedex_df['Color']=='Black']
# Out:
#             Pokemon   HP  Atk  ... Hidden Ability  Color Nickname
# 174.0       Snorlax  160  110  ...       Gluttony  Black
# 162.0       Umbreon   95   65  ...    Inner Focus  Black
# 226.0       Murkrow   60   85  ...      Prankster  Black
# 230.0         Unown   48   72  ...                 Black
# 244.0       Sneasel   55   95  ...     Pickpocket  Black
# 260.0      Houndour   45   60  ...        Unnerve  Black
# 261.0      Houndoom   75   90  ...        Unnerve  Black
# 328.0        Mawile   50   85  ...    Sheer Force  Black
# 352.0        Spoink   60   25  ...       Gluttony  Black
# 363.0       Seviper   73  100  ...    Infiltrator  Black
# 371.0       Claydol   60   70  ...                 Black
# 380.0       Shuppet   44   75  ...    Cursed Body  Black
# 381.0       Banette   64  115  ...    Cursed Body  Black
# 382.0       Duskull   20   40  ...                 Black
# 383.0      Dusclops   40   70  ...                 Black
# 227.0     Honchkrow  100  125  ...          Moxie  Black
# 461.0        Chatot   76   65  ...      Big Pecks  Black
# 173.0      Munchlax  135   85  ...       Gluttony  Black
# 245.0       Weavile   70  120  ...     Pickpocket  Black
# 384.0      Dusknoir   45  100  ...                 Black
# 487.0      Giratina  150  100  ...      Telepathy  Black
# 487.1  Giratina (O)  150  120  ...                 Black
# 491.0       Darkrai   70   90  ...                 Black
# 522.0       Blitzle   45   60  ...     Sap Sipper  Black
# 523.0     Zebstrika   75  100  ...     Sap Sipper  Black
# 561.0      Sigilyph   72   58  ...    Tinted Lens  Black
# 562.0        Yamask   38   30  ...                 Black
# 608.0       Lampent   60   40  ...     Shadow Tag  Black
# 609.0    Chandelure   60   55  ...     Shadow Tag  Black
# 644.0        Zekrom  100  150  ...                 Black
# 664.0    Scatterbug   38   35  ...   Friend Guard  Black
# 665.0        Spewpa   45   22  ...   Friend Guard  Black
# 666.0      Vivillon   80   52  ...   Friend Guard  Black
# 731.0       Pikipek   35   75  ...         Pickup  Black
# 732.0      Trumbeak   55   85  ...         Pickup  Black
# 733.0     Toucannon   80  120  ...    Sheer Force  Black
# 757.0      Salandit   48   44  ...      Oblivious  Black
# 758.0      Salazzle   68   64  ...      Oblivious  Black
# 771.0     Pyukumuku   55   60  ...        Unaware  Black
# 796.0     Xurkitree   83   89  ...                 Black
# 799.0      Guzzlord  223  101  ...                 Black
# 800.0      Necrozma   97  107  ...                 Black
#
# [42 rows x 15 columns]

# %%
pokedex_df.loc[pokedex_df['Hidden Ability'] == 'Cursed Body']
# Out:
#         Pokemon  HP  Atk Def  ... Ability II Hidden Ability  Color Nickname
# 380.0   Shuppet  44   75  35  ...      Frisk    Cursed Body  Black
# 381.0   Banette  64  115  65  ...      Frisk    Cursed Body  Black
# 391.0  Froslass  70   80  70  ...               Cursed Body  White
#
# [3 rows x 15 columns]

# %% [markdown]
# ### Compound boolean queries
# You can use boolean operations (OR, AND, NOT) to combine conditions
#
# We will look for pokemon with specific types to demonstrate compound queries

# %% [markdown]
# ### OR queries
# In the following example, we query for all pokemon who have at least part "Dragon" typing.
#
# The vertical line | represents the element-wise "OR" operation. "OR" operations require either or both statements on either side of the operation to be true.
#
# Thus, the below query
#
# ```query = (pokedex_df['Type I']=='Dragon') | (pokedex_df['Type II']=='Dragon')```
#
# asks, for each row, if 'Type I' is equal to "Dragon" OR 'Type II' is equal to "Dragon"

# %%
query = (pokedex_df['Type I']=='Dragon') | (pokedex_df['Type II']=='Dragon')
pokedex_df.loc[query] # Get all of the entries corresponding to the above query
# Out:
#             Pokemon   HP  Atk  ... Hidden Ability   Color Nickname
# 178.0       Dratini   41   64  ...   Marvel Scale    Blue
# 179.0     Dragonair   61   84  ...   Marvel Scale    Blue
# 180.0     Dragonite   91  134  ...     Multiscale   Brown
# 134.0       Kingdra   75   95  ...           Damp    Blue
# 356.0       Vibrava   50   70  ...                  Green
# 357.0        Flygon   80  100  ...                  Green
# 361.0       Altaria   75   70  ...     Cloud Nine    Blue
# 400.0         Bagon   45   75  ...    Sheer Force    Blue
# 401.0       Shelgon   65   95  ...       Overcoat   White
# 402.0     Salamence   95  135  ...          Moxie    Blue
# 409.0        Latias   80   80  ...                    Red
# 410.0        Latios   80   90  ...                   Blue
# 413.0      Rayquaza  105  150  ...                  Green
# 463.0         Gible   58   70  ...     Rough Skin    Blue
# 464.0        Gabite   68   90  ...     Rough Skin    Blue
# 465.0      Garchomp  108  130  ...     Rough Skin    Blue
# 483.0        Dialga  100  120  ...      Telepathy   White
# 484.0        Palkia   90  120  ...      Telepathy  Purple
# 487.0      Giratina  150  100  ...      Telepathy   Black
# 487.1  Giratina (O)  150  120  ...                  Black
# 610.0          Axew   46   87  ...        Unnerve   Green
# 611.0       Fraxure   66  117  ...        Unnerve   Green
# 612.0       Haxorus   76  147  ...        Unnerve  Yellow
# 621.0     Druddigon   77  120  ...   Mold Breaker     Red
# 633.0         Deino   52   65  ...                   Blue
# 634.0      Zweilous   72   85  ...                   Blue
# 635.0     Hydreigon   92  105  ...                   Blue
# 643.0      Reshiram  100  120  ...                  White
# 644.0        Zekrom  100  150  ...                  Black
# 646.0        Kyurem  125  130  ...                   Gray
# 691.0      Dragalge   65   75  ...   Adaptability   Brown
# 696.0        Tyrunt   58   89  ...         Sturdy   Brown
# 697.0     Tyrantrum   82  121  ...         Sturdy     Red
# 704.0         Goomy   45   50  ...          Gooey  Purple
# 705.0       Sliggoo   68   75  ...          Gooey  Purple
# 706.0        Goodra   90  100  ...          Gooey  Purple
# 714.0        Noibat   40   30  ...      Telepathy  Purple
# 715.0       Noivern   85   70  ...      Telepathy  Purple
# 718.0       Zygarde  108  100  ...                  Green
# 776.0    Turtonator   60   78  ...                    Red
# 780.0        Drampa   78   60  ...     Cloud Nine   White
# 782.0      Jangmo-o   45   55  ...       Overcoat    Gray
# 783.0      Hakamo-o   55   75  ...       Overcoat    Gray
# 784.0       Kommo-o   75  110  ...       Overcoat    Gray
# 799.0      Guzzlord  223  101  ...                  Black
#
# [45 rows x 15 columns]

# %%
query = (pokedex_df['Type I'] == 'Water') | (pokedex_df['Type II'] == 'Flying')
pokedex_df.loc[query]
# Out:
#                    Pokemon   HP  Atk  ... Hidden Ability   Color Nickname
# 6.0              Charizard   78   84  ...    Solar Power     Red
# 7.0               Squirtle   44   48  ...      Rain Dish    Blue
# 8.0              Wartortle   59   63  ...      Rain Dish    Blue
# 9.0              Blastoise   79   83  ...      Rain Dish    Blue
# 12.0            Butterfree   60   45  ...    Tinted Lens   White
# 16.0                Pidgey   40   45  ...      Big Pecks   Brown
# 17.0             Pidgeotto   63   60  ...      Big Pecks   Brown
# 18.0               Pidgeot   83   80  ...      Big Pecks   Brown
# 21.0               Spearow   40   60  ...         Sniper   Brown
# 22.0                Fearow   65   90  ...         Sniper   Brown
# 44.0                 Zubat   40   45  ...    Infiltrator  Purple
# 45.0                Golbat   75   80  ...    Infiltrator  Purple
# 59.0               Psyduck   50   52  ...     Swift Swim  Yellow
# 60.0               Golduck   80   82  ...     Swift Swim    Blue
# 65.0               Poliwag   40   50  ...     Swift Swim    Blue
# 66.0             Poliwhirl   65   65  ...     Swift Swim    Blue
# 67.0             Poliwrath   90   85  ...     Swift Swim    Blue
# 78.0             Tentacool   40   40  ...      Rain Dish    Blue
# 79.0            Tentacruel   80   70  ...      Rain Dish    Blue
# 85.0              Slowpoke   90   65  ...    Regenerator    Pink
# 86.0               Slowbro   95   75  ...    Regenerator    Pink
# 91.0            Farfetch'd   52   65  ...        Defiant   Brown
# 92.0                 Doduo   35   85  ...   Tangled Feet   Brown
# 93.0                Dodrio   60  110  ...   Tangled Feet   Brown
# 94.0                  Seel   65   45  ...       Ice Body   White
# 95.0               Dewgong   90   70  ...       Ice Body   White
# 98.0              Shellder   30   65  ...       Overcoat  Purple
# 99.0              Cloyster   50   90  ...       Overcoat  Purple
# 107.0               Krabby   30  105  ...    Sheer Force     Red
# 108.0              Kingler   55  130  ...    Sheer Force     Red
# 132.0               Horsea   30   40  ...           Damp    Blue
# 133.0               Seadra   55   65  ...           Damp    Blue
# 135.0              Goldeen   45   67  ...   Lightningrod     Red
# 136.0              Seaking   80   92  ...   Lightningrod     Red
# 137.0               Staryu   30   45  ...       Analytic   Brown
# 138.0              Starmie   60   75  ...       Analytic  Purple
# 141.0              Scyther   70  110  ...      Steadfast   Green
# 153.0             Magikarp   20   10  ...        Rattled     Red
# 154.0             Gyarados   95  125  ...          Moxie    Blue
# 155.0               Lapras  130   85  ...      Hydration    Blue
# 158.0             Vaporeon  130   65  ...      Hydration    Blue
# 172.0           Aerodactyl   80  105  ...        Unnerve  Purple
# 175.0             Articuno   90   85  ...     Snow Cloak    Blue
# 176.0               Zapdos   90   90  ...   Lightningrod  Yellow
# 177.0              Moltres   90  100  ...     Flame Body  Yellow
# 180.0            Dragonite   91  134  ...     Multiscale   Brown
# 189.0             Totodile   50   65  ...    Sheer Force    Blue
# 190.0             Croconaw   65   80  ...    Sheer Force    Blue
# 191.0           Feraligatr   85  105  ...    Sheer Force    Blue
# 194.0             Hoothoot   60   30  ...    Tinted Lens   Brown
# 195.0              Noctowl  100   50  ...    Tinted Lens   Brown
# 196.0               Ledyba   40   20  ...        Rattled     Red
# 197.0               Ledian   55   35  ...      Iron Fist     Red
# 46.0                Crobat   85   90  ...    Infiltrator  Purple
# 200.0             Chinchou   75   38  ...   Water Absorb    Blue
# 201.0              Lanturn  125   58  ...   Water Absorb    Blue
# 203.0              Togetic   55   40  ...     Super Luck   White
# 205.0                 Natu   40   50  ...   Magic Bounce   Green
# 206.0                 Xatu   65   75  ...   Magic Bounce   Green
# 211.0               Marill   70   20  ...     Sap Sipper    Blue
# 212.0            Azumarill  100   50  ...     Sap Sipper    Blue
# 68.0              Politoed   90   75  ...        Drizzle   Green
# 215.0               Hoppip   35   35  ...    Infiltrator    Pink
# 216.0             Skiploom   55   45  ...    Infiltrator   Green
# 217.0             Jumpluff   75   55  ...    Infiltrator    Blue
# 222.0                Yanma   65   65  ...          Frisk     Red
# 224.0               Wooper   55   45  ...        Unaware    Blue
# 225.0             Quagsire   95   85  ...        Unaware    Blue
# 226.0              Murkrow   60   85  ...      Prankster   Black
# 87.0              Slowking   95   75  ...    Regenerator    Pink
# 237.0               Gligar   65   75  ...       Immunity  Purple
# 241.0             Qwilfish   65   95  ...     Intimidate    Gray
# 253.0              Corsola   55   55  ...    Regenerator    Pink
# 254.0             Remoraid   35   65  ...          Moody    Gray
# 255.0            Octillery   75  105  ...          Moody     Red
# 256.0             Delibird   45   55  ...       Insomnia     Red
# 258.0              Mantine   65   40  ...     Water Veil  Purple
# 259.0             Skarmory   65   80  ...     Weak Armor    Gray
# 134.0              Kingdra   75   95  ...           Damp    Blue
# 269.0              Suicune  100   75  ...   Water Absorb    Blue
# 273.0                Lugia  106   90  ...     Multiscale   White
# 274.0                Ho-oh  106  130  ...    Regenerator     Red
# 282.0               Mudkip   50   70  ...           Damp    Blue
# 283.0            Marshtomp   70   85  ...           Damp    Blue
# 284.0             Swampert  100  110  ...           Damp    Blue
# 291.0            Beautifly   60   70  ...        Rivalry  Yellow
# 294.0                Lotad   40   30  ...      Own Tempo   Green
# 295.0               Lombre   60   50  ...      Own Tempo   Green
# 296.0             Ludicolo   80   70  ...      Own Tempo   Green
# 300.0              Taillow   40   55  ...        Scrappy    Blue
# 301.0              Swellow   60   85  ...        Scrappy    Blue
# 302.0              Wingull   40   30  ...      Rain Dish   White
# 303.0             Pelipper   60   50  ...      Rain Dish  Yellow
# 309.0           Masquerain   70   60  ...        Unnerve    Blue
# 316.0              Ninjask   61   90  ...    Infiltrator  Yellow
# 345.0             Carvanha   45   90  ...    Speed Boost     Red
# 346.0             Sharpedo   70  120  ...    Speed Boost    Blue
# 347.0              Wailmer  130   70  ...       Pressure    Blue
# 348.0              Wailord  170   90  ...       Pressure    Blue
# 360.0               Swablu   45   40  ...     Cloud Nine    Blue
# 361.0              Altaria   75   70  ...     Cloud Nine    Blue
# 366.0             Barboach   50   48  ...      Hydration    Gray
# 367.0             Whiscash  110   78  ...      Hydration    Blue
# 368.0             Corphish   43   80  ...   Adaptability     Red
# 369.0            Crawdaunt   63  120  ...   Adaptability     Red
# 376.0               Feebas   20   15  ...   Adaptability   Brown
# 377.0              Milotic   95   60  ...     Cute Charm    Pink
# 385.0              Tropius   99   68  ...        Harvest   Green
# 395.0             Clamperl   35   64  ...        Rattled    Blue
# 396.0              Huntail   55  104  ...     Water Veil    Blue
# 397.0             Gorebyss   55   84  ...      Hydration    Pink
# 398.0            Relicanth  100   90  ...         Sturdy    Gray
# 399.0              Luvdisc   43   30  ...      Hydration    Pink
# 402.0            Salamence   95  135  ...          Moxie    Blue
# 411.0               Kyogre  100  100  ...                   Blue
# 413.0             Rayquaza  105  150  ...                  Green
# 422.0               Piplup   53   51  ...        Defiant    Blue
# 423.0             Prinplup   64   66  ...        Defiant    Blue
# 424.0             Empoleon   84   86  ...        Defiant    Blue
# 425.0               Starly   40   55  ...                  Brown
# 426.0             Staravia   55   75  ...       Reckless   Brown
# 427.0            Staraptor   85  120  ...       Reckless   Brown
# 441.0               Mothim   70   94  ...    Tinted Lens  Yellow
# 442.0               Combee   30   30  ...         Hustle  Yellow
# 443.0            Vespiquen   70   80  ...        Unnerve  Yellow
# 445.0               Buizel   55   65  ...     Water Veil   Brown
# 446.0             Floatzel   85  105  ...     Water Veil   Brown
# 449.0              Shellos   76   48  ...     Sand Force  Purple
# 450.0            Gastrodon  111   83  ...     Sand Force  Purple
# 451.0             Drifloon   90   50  ...    Flare Boost  Purple
# 452.0             Drifblim  150   80  ...    Flare Boost  Purple
# 227.0            Honchkrow  100  125  ...          Moxie   Black
# 461.0               Chatot   76   65  ...      Big Pecks   Black
# 475.0              Finneon   49   49  ...     Water Veil    Blue
# 476.0             Lumineon   69   69  ...     Water Veil    Blue
# 257.0              Mantyke   45   20  ...                   Blue
# 204.0             Togekiss   85   50  ...     Super Luck   White
# 223.0              Yanmega   86   76  ...          Frisk   Green
# 238.0              Gliscor   75   95  ...    Poison Heal  Purple
# 479.4         Rotom (Spin)   50   65  ...                    Red
# 484.0               Palkia   90  120  ...      Telepathy  Purple
# 489.0               Phione   80   80  ...                   Blue
# 490.0              Manaphy  100  100  ...                   Blue
# 492.1          Shaymin (S)  100  103  ...                  Green
# 501.0             Oshawott   55   55  ...    Shell Armor    Blue
# 502.0               Dewott   75   75  ...    Shell Armor    Blue
# 503.0             Samurott   95  100  ...    Shell Armor    Blue
# 515.0              Panpour   50   53  ...        Torrent    Blue
# 516.0             Simipour   75   98  ...        Torrent    Blue
# 519.0               Pidove   50   55  ...        Rivalry    Gray
# 520.0            Tranquill   62   77  ...        Rivalry    Gray
# 521.0             Unfezant   80  105  ...        Rivalry    Gray
# 527.0               Woobat   55   45  ...         Simple    Blue
# 528.0              Swoobat   67   57  ...         Simple    Blue
# 535.0              Tympole   50   50  ...   Water Absorb    Blue
# 536.0            Palpitoad   75   65  ...   Water Absorb    Blue
# 537.0           Seismitoad  105   85  ...   Water Absorb    Blue
# 550.0             Basculin   70   92  ...   Mold Breaker   Green
# 561.0             Sigilyph   72   58  ...    Tinted Lens   Black
# 564.0             Tirtouga   54   78  ...     Swift Swim    Blue
# 565.0           Carracosta   74  108  ...     Swift Swim    Blue
# 566.0               Archen   55  112  ...                 Yellow
# 567.0             Archeops   75  140  ...                 Yellow
# 580.0             Ducklett   62   44  ...      Hydration    Blue
# 581.0               Swanna   75   87  ...      Hydration   White
# 587.0               Emolga   55   75  ...    Motor Drive   White
# 592.0             Frillish   55   40  ...                  White
# 593.0            Jellicent  100   60  ...           Damp   White
# 594.0            Alomomola  165   75  ...    Regenerator    Pink
# 627.0              Rufflet   70   83  ...         Hustle   White
# 628.0             Braviary  100  123  ...        Defiant     Red
# 629.0              Vullaby   70   55  ...     Weak Armor   Brown
# 630.0            Mandibuzz  110   65  ...     Weak Armor   Brown
# 642.0            Thundurus   79  115  ...        Defiant    Blue
# 645.0             Landorus   89  125  ...    Sheer Force   Brown
# 647.0               Keldeo   91   72  ...                 Yellow
# 656.0              Froakie   41   56  ...        Protean    Blue
# 657.0            Frogadier   54   63  ...        Protean    Blue
# 658.0             Greninja   72   95  ...        Protean    Blue
# 661.0           Fletchling   45   50  ...     Gale Wings     Red
# 662.0          Fletchinder   62   73  ...     Gale Wings     Red
# 663.0           Talonflame   78   81  ...     Gale Wings     Red
# 666.0             Vivillon   80   52  ...   Friend Guard   Black
# 692.0            Clauncher   50   53  ...                   Blue
# 693.0            Clawitzer   71   73  ...                   Blue
# 701.0             Hawlucha   78   92  ...   Mold Breaker   Green
# 717.0              Yveltal  126  131  ...                    Red
# 722.0               Rowlet   68   55  ...                  Brown
# 723.0              Dartrix   78   75  ...                  Brown
# 728.0              Popplio   50   54  ...                   Blue
# 729.0              Brionne   60   69  ...                   Blue
# 730.0            Primarina   80   74  ...                   Blue
# 731.0              Pikipek   35   75  ...         Pickup   Black
# 732.0             Trumbeak   55   85  ...         Pickup   Black
# 733.0            Toucannon   80  120  ...    Sheer Force   Black
# 741.0             Oricorio   75   70  ...                    Red
# 746.0    Wishiwashi (solo)   45   20  ...                   Blue
# 746.1  Wishiwashi (school)   45  140  ...                   Blue
# 751.0             Dewpider   38   40  ...   Water Absorb   Green
# 752.0            Araquanid   68   70  ...   Water Absorb   Green
# 771.0            Pyukumuku   55   60  ...        Unaware   Black
# 774.0      Minior (meteor)   60   60  ...                  Brown
# 774.1        Minior (core)   60  100  ...                   Pink
# 779.0              Bruxish   68  105  ...    Wonder Skin    Pink
# 788.0            Tapu Fini   70   75  ...                 Purple
# 797.0           Celesteela   97  101  ...                  Green
#
# [206 rows x 15 columns]

# %% [markdown]
# ### AND queries
# The ampersand `&` character represents the element-wise boolean operation "AND". In order for an "AND" statement to be true, both conditions on either side of the operation must be true.
#
# We can combine boolean operations to construct complex queries: for example, getting all pokemon who are both Dragon and Flying types. The query below looks for pokemon who are EITHER (Primary Type "Flying" AND Secondary Type "Dragon") OR (Primary Type "Dragon" AND Secondary Type "Flying")
#
# Note that parentheses should be used to group operations so that the order of operations is clear

# %%
# you can use the backslash operator \ to continue code on the next line
query = ((pokedex_df['Type I']=='Flying') & (pokedex_df['Type II']=='Dragon'))\ # slash shows continuation on next line
        | ((pokedex_df['Type I']=='Dragon') & (pokedex_df['Type II']=='Flying')) 
pokedex_df.loc[query]

# %% [markdown]
# ### NOT queries
# There are two ways to do negation. Consider the following query for selecting all pokemon who are Fire type, but not Flying
#
# ```
# query = ((pokedex_df['Type I']=='Fire') & ~(pokedex_df['Type II']=='Flying'))\
#         | ((pokedex_df['Type I']!='Flying') & (pokedex_df['Type II']=='Fire'))
# ```
#
# The first way to do negation is with the tilde ~ symbol, which negates the subsequent boolean statement:
# We use this in `~(pokedex_df['Type II']=='Flying')`.
# The parentheses determine order of operations. First we find all entries where their secondary type is "Flying"
# Then the tilde in front negates that statement, flipping all True values to False, and vice versa
#
# The second way to do negation is using the != notation, which represents "not equal to"
# We use this in `(pokedex_df['Type I']!='Flying')`
# This finds all entries where their primary type is not equal to "Flying"

# %%
query = ((pokedex_df['Type I']=='Fire') & ~(pokedex_df['Type II']=='Flying'))\
        | ((pokedex_df['Type I']!='Flying') & (pokedex_df['Type II']=='Fire'))

pokedex_df.loc[query]

# %% [markdown]
# ## Sorting
# Dataframes can be sorted by value

# %%
pokedex_df.sort_values('Pokemon', ascending=False) # Sort by name descending
# Out:
#                    Pokemon   HP  Atk  ...       Hidden Ability   Color Nickname
# 718.0              Zygarde  108  100  ...                        Green
# 634.0             Zweilous   72   85  ...                         Blue
# 44.0                 Zubat   40   45  ...          Infiltrator  Purple
# 570.0                Zorua   40   65  ...                         Gray
# 571.0              Zoroark   60  105  ...                         Gray
# 287.0            Zigzagoon   38   30  ...           Quick Feet   Brown
# 644.0               Zekrom  100  150  ...                        Black
# 523.0            Zebstrika   75  100  ...           Sap Sipper   Black
# 176.0               Zapdos   90   90  ...         Lightningrod  Yellow
# 362.0             Zangoose   73  115  ...       Poison Rampage   White
# 717.0              Yveltal  126  131  ...                          Red
# 734.0              Yungoos   48   70  ...         Adaptability   Brown
# 223.0              Yanmega   86   76  ...                Frisk   Green
# 222.0                Yanma   65   65  ...                Frisk     Red
# 562.0               Yamask   38   30  ...                        Black
# 796.0            Xurkitree   83   89  ...                        Black
# 716.0              Xerneas  126  131  ...                         Blue
# 206.0                 Xatu   65   75  ...         Magic Bounce   Green
# 231.0               Wynaut   95   23  ...            Telepathy    Blue
# 289.0              Wurmple   45   45  ...             Run Away     Red
# 440.2         Wormadam (T)   60   69  ...             Overcoat    Gray
# 440.1         Wormadam (S)   60   79  ...             Overcoat    Gray
# 440.0         Wormadam (P)   60   59  ...             Overcoat    Gray
# 224.0               Wooper   55   45  ...              Unaware    Blue
# 527.0               Woobat   55   45  ...               Simple    Blue
# 232.0            Wobbuffet  190   33  ...            Telepathy    Blue
# 746.0    Wishiwashi (solo)   45   20  ...                         Blue
# 746.1  Wishiwashi (school)   45  140  ...                         Blue
# 302.0              Wingull   40   30  ...            Rain Dish   White
# 767.0               Wimpod   25   35  ...                         Gray
# 43.0            Wigglytuff  140   70  ...                Frisk    Pink
# 318.0              Whismur   64   51  ...              Rattled    Pink
# 367.0             Whiscash  110   78  ...            Hydration    Blue
# 544.0           Whirlipede   40   55  ...           Quick Feet    Gray
# 547.0           Whimsicott   60   67  ...          Chlorophyll   Green
# 122.0              Weezing   65   90  ...                       Purple
# 76.0            Weepinbell   65   90  ...             Gluttony   Green
# 13.0                Weedle   40   35  ...             Run Away   Brown
# 245.0              Weavile   70  120  ...           Pickpocket   Black
# 505.0              Watchog   60   85  ...             Analytic   Brown
# 8.0              Wartortle   59   63  ...            Rain Dish    Blue
# 394.0              Walrein  110   80  ...            Oblivious    Blue
# 348.0              Wailord  170   90  ...             Pressure    Blue
# 347.0              Wailmer  130   70  ...             Pressure    Blue
# 39.0                Vulpix   38   41  ...              Drought   Brown
# 629.0              Vullaby   70   55  ...           Weak Armor   Brown
# 109.0              Voltorb   40   30  ...            Aftermath     Red
# 637.0            Volcarona   85   60  ...                Swarm   White
# 721.0            Volcanion   80  110  ...                        Brown
# 338.0              Volbeat   65   73  ...            Prankster    Gray
# 666.0             Vivillon   80   52  ...         Friend Guard   Black
# 640.0             Virizion   91   90  ...                        Green
# 49.0             Vileplume   75   80  ...         Effect Spore     Red
# 738.0             Vikavolt   77   70  ...                         Blue
# 313.0             Vigoroth   80   80  ...                        White
# 77.0            Victreebel   80  105  ...             Gluttony   Green
# 494.0              Victini  100  100  ...                       Yellow
# 356.0              Vibrava   50   70  ...                        Green
# 443.0            Vespiquen   70   80  ...              Unnerve  Yellow
# 3.0               Venusaur   80   82  ...          Chlorophyll   Green
# 53.0               Venonat   60   55  ...             Run Away  Purple
# 54.0              Venomoth   70   65  ...          Wonder Skin  Purple
# 543.0             Venipede   30   45  ...           Quick Feet     Red
# 158.0             Vaporeon  130   65  ...            Hydration    Blue
# 584.0            Vanilluxe   71   95  ...           Weak Armor   White
# 582.0            Vanillite   36   50  ...           Weak Armor   White
# 583.0            Vanillish   51   65  ...           Weak Armor   White
# 480.0                 Uxie   75   75  ...                       Yellow
# 247.0             Ursaring   90  130  ...              Unnerve   Brown
# 230.0                Unown   48   72  ...                        Black
# 521.0             Unfezant   80  105  ...              Rivalry    Gray
# 162.0              Umbreon   95   65  ...          Inner Focus   Black
# 696.0               Tyrunt   58   89  ...               Sturdy   Brown
# 115.0              Tyrogue   35   35  ...         Vital Spirit  Purple
# 697.0            Tyrantrum   82  121  ...               Sturdy     Red
# 272.0            Tyranitar  100  134  ...              Unnerve   Green
# 188.0           Typhlosion   78   84  ...           Flash Fire  Yellow
# 772.0           Type: Null   95   95  ...                         Gray
# 602.0               Tynamo   35   55  ...                        White
# 535.0              Tympole   50   50  ...         Water Absorb    Blue
# 416.0              Turtwig   55   68  ...          Shell Armor   Green
# 776.0           Turtonator   60   78  ...                          Red
# 763.0             Tsareena   72  120  ...           Sweet Veil  Purple
# 732.0             Trumbeak   55   85  ...               Pickup   Black
# 568.0             Trubbish   50   50  ...            Aftermath   Green
# 385.0              Tropius   99   68  ...              Harvest   Green
# 709.0            Trevenant   85  110  ...              Harvest   Brown
# 276.0              Treecko   40   45  ...             Unburden   Green
# 355.0             Trapinch   45  100  ...          Sheer Force   Brown
# 520.0            Tranquill   62   77  ...              Rivalry    Gray
# 473.0            Toxicroak   83  106  ...         Poison Touch    Blue
# 748.0              Toxapex   50   63  ...          Regenerator    Blue
# 733.0            Toucannon   80  120  ...          Sheer Force   Black
# 189.0             Totodile   50   65  ...          Sheer Force    Blue
# 418.0             Torterra   95  109  ...          Shell Armor   Green
# 726.0             Torracat   65   85  ...                          Red
# 641.0             Tornadus   79  115  ...              Defiant   Green
# 351.0              Torkoal   70   85  ...          Shell Armor   Brown
# 279.0              Torchic   45   60  ...          Speed Boost     Red
# 203.0              Togetic   55   40  ...           Super Luck   White
# 202.0               Togepi   35   20  ...           Super Luck   White
# 204.0             Togekiss   85   50  ...           Super Luck   White
# 777.0           Togedemaru   65   98  ...               Sturdy    Gray
# 564.0             Tirtouga   54   78  ...           Swift Swim    Blue
# 532.0              Timburr   75   80  ...            Iron Fist    Gray
# 642.0            Thundurus   79  115  ...              Defiant    Blue
# 538.0                Throh  120  100  ...         Mold Breaker     Red
# 639.0            Terrakion   91  129  ...                         Gray
# 498.0                Tepig   65   63  ...            Thick Fat     Red
# 79.0            Tentacruel   80   70  ...            Rain Dish    Blue
# 78.0             Tentacool   40   40  ...            Rain Dish    Blue
# 246.0            Teddiursa   60   80  ...         Honey Gather   Brown
# 152.0               Tauros   75  100  ...          Sheer Force   Brown
# 786.0            Tapu Lele   70   85  ...                         Pink
# 785.0            Tapu Koko   70  115  ...                       Yellow
# 788.0            Tapu Fini   70   75  ...                       Purple
# 787.0            Tapu Bulu   70  130  ...                          Red
# 130.0            Tangrowth  100  100  ...          Regenerator    Blue
# 129.0              Tangela   65   55  ...          Regenerator    Blue    Terry
# 663.0           Talonflame   78   81  ...           Gale Wings     Red
# 300.0              Taillow   40   55  ...              Scrappy    Blue
# 700.0              Sylveon   95   65  ...             Pixilate    Pink
# 528.0              Swoobat   67   57  ...               Simple    Blue
# 684.0              Swirlix   62   48  ...             Unburden   White
# 250.0               Swinub   50   50  ...            Thick Fat   Brown
# 301.0              Swellow   60   85  ...              Scrappy    Blue
# 581.0               Swanna   75   87  ...            Hydration   White
# 284.0             Swampert  100  110  ...                 Damp    Blue
# 344.0               Swalot  100   73  ...             Gluttony  Purple
# 541.0             Swadloon   55   63  ...             Overcoat   Green
# 360.0               Swablu   45   40  ...           Cloud Nine    Blue
# 308.0              Surskit   40   30  ...            Rain Dish    Blue
# 220.0              Sunkern   30   30  ...           Early Bird  Yellow
# 221.0             Sunflora   75   75  ...           Early Bird  Yellow
# 269.0              Suicune  100   75  ...         Water Absorb    Blue
# 214.0            Sudowoodo   70  100  ...              Rattled   Brown
# 457.0               Stunky   63   63  ...             Keen Eye  Purple
# 618.0             Stunfisk  109   66  ...            Sand Veil   Brown
# 759.0              Stufful   70   75  ...           Cute Charm    Pink
# 508.0            Stoutland   85  100  ...              Scrappy    Gray
# 762.0              Steenee   52   40  ...           Sweet Veil  Purple
# 104.0              Steelix   75   85  ...          Sheer Force    Gray
# 137.0               Staryu   30   45  ...             Analytic   Brown
# 138.0              Starmie   60   75  ...             Analytic  Purple
# 425.0               Starly   40   55  ...                        Brown
# 426.0             Staravia   55   75  ...             Reckless   Brown
# 427.0            Staraptor   85  120  ...             Reckless   Brown
# 264.0             Stantler   73   95  ...           Sap Sipper   Brown
# 7.0               Squirtle   44   48  ...            Rain Dish    Blue
# 682.0             Spritzee   78   52  ...           Aroma Veil    Pink
# 352.0               Spoink   60   25  ...             Gluttony   Black
# 462.0            Spiritomb   50   92  ...          Infiltrator  Purple
# 354.0               Spinda   60   60  ...             Contrary   Brown
# 198.0             Spinarak   40   60  ...               Sniper   Green
# 392.0               Spheal   70   40  ...            Oblivious    Blue
# 665.0               Spewpa   45   22  ...         Friend Guard   Black
# 21.0               Spearow   40   60  ...               Sniper   Brown
# 365.0              Solrock   70   95  ...                          Red
# 577.0              Solosis   45   30  ...          Regenerator   Green
# 791.0             Solgaleo  137  137  ...                        White
# 239.0             Snubbull   60   80  ...              Rattled    Pink
# 477.0               Snover   60   62  ...           Soundproof   White
# 389.0              Snorunt   50   50  ...                Moody    Gray
# 174.0              Snorlax  160  110  ...             Gluttony   Black
# 495.0                Snivy   45   45  ...             Contrary   Green
# 244.0              Sneasel   55   95  ...           Pickpocket   Black
# 143.0             Smoochum   45   30  ...            Hydration    Pink
# 265.0             Smeargle   55   20  ...                Moody   White
# 685.0             Slurpuff   82   80  ...             Unburden   White
# 248.0               Slugma   40   40  ...           Weak Armor     Red
# 85.0              Slowpoke   90   65  ...          Regenerator    Pink
# 87.0              Slowking   95   75  ...          Regenerator    Pink
# 86.0               Slowbro   95   75  ...          Regenerator    Pink
# 705.0              Sliggoo   68   75  ...                Gooey  Purple
# 312.0              Slakoth   60   60  ...                        Brown
# 314.0              Slaking  150  160  ...                        Brown
# 458.0             Skuntank  103   93  ...             Keen Eye  Purple
# 690.0               Skrelp   50   60  ...         Adaptability   Brown
# 470.0              Skorupi   40   50  ...             Keen Eye  Purple
# 325.0               Skitty   50   45  ...          Wonder Skin    Pink
# 216.0             Skiploom   55   45  ...          Infiltrator   Green
# 672.0               Skiddo   66   65  ...           Grass Pelt   Brown
# 259.0             Skarmory   65   80  ...           Weak Armor    Gray
# 514.0             Simisear   75   98  ...                Blaze     Red
# 512.0             Simisage   75   98  ...             Overgrow   Green
# 516.0             Simipour   75   98  ...              Torrent    Blue
# 773.0             Silvally   95   95  ...                         Gray
# 290.0              Silcoon   50   35  ...                        White
# 561.0             Sigilyph   72   58  ...          Tinted Lens   Black
# 380.0              Shuppet   44   75  ...          Cursed Body   Black
# 242.0              Shuckle   20   10  ...             Contrary  Yellow
# 310.0            Shroomish   60   40  ...           Quick Feet   Brown
# 432.0                Shinx   45   65  ...                 Guts    Blue
# 756.0            Shiinotic   60   45  ...            Rain Dish  Purple
# 299.0              Shiftry   90  100  ...           Pickpocket   Brown
# 437.0             Shieldon   30   42  ...           Soundproof    Gray
# 616.0              Shelmet   50   40  ...             Overcoat     Red
# 449.0              Shellos   76   48  ...           Sand Force  Purple
# 98.0              Shellder   30   65  ...             Overcoat  Purple
# 401.0              Shelgon   65   95  ...             Overcoat   White
# 317.0             Shedinja    1   90  ...                        Brown
# 492.1          Shaymin (S)  100  103  ...                        Green
# 492.0              Shaymin  100  100  ...                        Green
# 346.0             Sharpedo   70  120  ...          Speed Boost    Blue
# 540.0             Sewaddle   45   53  ...             Overcoat  Yellow
# 363.0              Seviper   73  100  ...          Infiltrator   Black
# 496.0              Servine   60   60  ...             Contrary   Green
# 497.0            Serperior   75   75  ...             Contrary   Green
# 192.0              Sentret   35   46  ...                Frisk   Brown
# 537.0           Seismitoad  105   85  ...         Water Absorb    Blue
# 94.0                  Seel   65   45  ...             Ice Body   White
# 297.0               Seedot   40   40  ...           Pickpocket   Brown
# 393.0               Sealeo   90   60  ...            Oblivious    Blue
# 136.0              Seaking   80   92  ...         Lightningrod     Red
# 133.0               Seadra   55   65  ...                 Damp    Blue
# 141.0              Scyther   70  110  ...            Steadfast   Green
# 559.0              Scraggy   50   75  ...           Intimidate  Yellow
# 560.0              Scrafty   65   90  ...           Intimidate     Red
# 545.0            Scolipede   60   90  ...           Quick Feet     Red
# 142.0               Scizor   70  130  ...          Light Metal     Red
# 278.0             Sceptile   70   85  ...             Unburden   Green
# 664.0           Scatterbug   38   35  ...         Friend Guard   Black
# 586.0             Sawsbuck   80  100  ...         Serene Grace   Brown
# 539.0                 Sawk   75  125  ...         Mold Breaker    Blue
# 769.0            Sandygast   55   55  ...            Sand Veil   Brown
# 29.0             Sandslash   75  100  ...            Sand Rush  Yellow
# 28.0             Sandshrew   50   75  ...            Sand Rush  Yellow
# 551.0              Sandile   50   72  ...          Anger Point   Brown
# 503.0             Samurott   95  100  ...          Shell Armor    Blue
# 758.0             Salazzle   68   64  ...            Oblivious   Black
# 757.0             Salandit   48   44  ...            Oblivious   Black
# 402.0            Salamence   95  135  ...                Moxie    Blue
# 327.0              Sableye   50   75  ...            Prankster  Purple
# 627.0              Rufflet   70   83  ...               Hustle   White
# 722.0               Rowlet   68   55  ...                        Brown
# 479.2         Rotom (Wash)   50   65  ...                          Red
# 479.4         Rotom (Spin)   50   65  ...                          Red
# 479.1         Rotom (Heat)   50   65  ...                          Red
# 479.3        Rotom (Frost)   50   65  ...                          Red
# 479.5          Rotom (Cut)   50   65  ...                          Red
# 479.0                Rotom   50   50  ...                          Red
# 342.0             Roserade   60   70  ...           Technician   Green
# 341.0              Roselia   50   60  ...           Leaf Guard   Green
# 524.0           Roggenrola   55   75  ...           Sand Force    Blue
# 744.0             Rockruff   45   65  ...            Steadfast   Brown
# 466.0                Riolu   40   70  ...            Prankster    Blue
# 743.0             Ribombee   60   55  ...           Sweet Veil  Yellow
# 125.0            Rhyperior  115  140  ...             Reckless    Gray
# 123.0              Rhyhorn   80   85  ...             Reckless    Gray
# 124.0               Rhydon  105  130  ...             Reckless    Gray
# 579.0            Reuniclus  110   65  ...          Regenerator   Green
# 643.0             Reshiram  100  120  ...                        White
# 254.0             Remoraid   35   65  ...                Moody    Gray
# 398.0            Relicanth  100   90  ...               Sturdy    Gray
# 408.0            Registeel   80   75  ...          Light Metal    Gray
# 406.0             Regirock   80  100  ...               Sturdy   Brown
# 486.0            Regigigas  110  160  ...                        White
# 407.0               Regice   80   50  ...             Ice Body    Blue
# 413.0             Rayquaza  105  150  ...                        Green
# 19.0               Rattata   30   56  ...               Hustle  Purple
# 20.0              Raticate   55   81  ...               Hustle   Brown
# 84.0              Rapidash   65  100  ...           Flame Body  Yellow
# 436.0            Rampardos   97  165  ...          Sheer Force    Blue
# 304.0                Ralts   28   25  ...            Telepathy   White
# 267.0               Raikou   90   85  ...          Volt Absorb  Yellow
# 27.0                Raichu   60   90  ...         Lightningrod  Yellow
# 241.0             Qwilfish   65   95  ...           Intimidate    Gray
# 651.0            Quilladin   61   78  ...          Bulletproof   Green
# 187.0              Quilava   58   64  ...           Flash Fire  Yellow
# 225.0             Quagsire   95   85  ...              Unaware    Blue
# 771.0            Pyukumuku   55   60  ...              Unaware   Black
# 668.0               Pyroar   86   68  ...                Moxie   Brown
# 456.0              Purugly   71   82  ...              Defiant    Gray
# 509.0             Purrloin   41   50  ...            Prankster  Purple
# 271.0              Pupitar   70   84  ...                         Gray
# 710.0            Pumpkaboo   44   66  ...             Insomnia   Brown
# 59.0               Psyduck   50   52  ...           Swift Swim  Yellow
# 324.0            Probopass   60   55  ...           Sand Force    Gray
# 423.0             Prinplup   64   66  ...              Defiant    Blue
# 62.0              Primeape   65  105  ...              Defiant   Brown
# 730.0            Primarina   80   74  ...                         Blue
# 166.0             Porygon2   85   80  ...             Analytic     Red
# 167.0            Porygon-Z   85   80  ...             Analytic     Red
# 165.0              Porygon   65   60  ...             Analytic    Pink
# 728.0              Popplio   50   54  ...                         Blue
# 285.0            Poochyena   35   55  ...              Rattled    Gray
# 83.0                Ponyta   50   85  ...           Flame Body  Yellow
# 67.0             Poliwrath   90   85  ...           Swift Swim    Blue
# 66.0             Poliwhirl   65   65  ...           Swift Swim    Blue
# 65.0               Poliwag   40   50  ...           Swift Swim    Blue
# 68.0              Politoed   90   75  ...              Drizzle   Green
# 336.0               Plusle   60   50  ...                       Yellow
# 422.0               Piplup   53   51  ...              Defiant    Blue
# 151.0               Pinsir   65  125  ...                Moxie   Brown
# 234.0               Pineco   50   65  ...             Overcoat    Gray
# 251.0            Piloswine  100  100  ...            Thick Fat   Brown
# 731.0              Pikipek   35   75  ...               Pickup   Black
# 26.0               Pikachu   35   55  ...         Lightningrod  Yellow
# 499.0              Pignite   90   93  ...            Thick Fat     Red
# 519.0               Pidove   50   55  ...              Rivalry    Gray
# ...                    ...  ...  ...  ...                  ...     ...      ...
# 695.0            Heliolisk   62   55  ...          Solar Power  Yellow
# 485.0              Heatran   91   90  ...           Flame Body   Brown
# 631.0              Heatmor   85   97  ...          White Smoke     Red
# 612.0              Haxorus   76  147  ...              Unnerve  Yellow
# 701.0             Hawlucha   78   92  ...         Mold Breaker   Green
# 101.0              Haunter   45   50  ...                       Purple
# 322.0             Hariyama  144  120  ...          Sheer Force   Brown
# 126.0              Happiny  100    5  ...         Friend Guard    Pink
# 783.0             Hakamo-o   55   75  ...             Overcoat    Gray
# 154.0             Gyarados   95  125  ...                Moxie    Blue
# 799.0             Guzzlord  223  101  ...                        Black
# 533.0              Gurdurr   85  105  ...            Iron Fist    Gray
# 735.0             Gumshoos   88  110  ...         Adaptability   Brown
# 343.0               Gulpin   70   43  ...             Gluttony   Green
# 353.0              Grumpig   80   45  ...             Gluttony  Purple
# 736.0              Grubbin   47   62  ...                         Gray
# 63.0             Growlithe   55   70  ...            Justified   Brown
# 277.0              Grovyle   50   65  ...             Unburden   Green
# 412.0              Groudon  100  150  ...                          Red
# 417.0               Grotle   75   89  ...          Shell Armor   Green
# 96.0                Grimer   80   80  ...         Poison Touch  Purple
# 658.0             Greninja   72   95  ...              Protean    Blue
# 81.0              Graveler   55   95  ...            Sand Veil   Brown
# 240.0             Granbull   90  120  ...              Rattled  Purple
# 711.0            Gourgeist   55   85  ...             Insomnia   Brown
# 575.0            Gothorita   60   45  ...           Shadow Tag  Purple
# 576.0           Gothitelle   70   55  ...           Shadow Tag  Purple
# 574.0              Gothita   45   30  ...           Shadow Tag  Purple
# 397.0             Gorebyss   55   84  ...            Hydration    Pink
# 704.0                Goomy   45   50  ...                Gooey  Purple
# 706.0               Goodra   90  100  ...                Gooey  Purple
# 623.0               Golurk   89  124  ...             No Guard   Green
# 768.0            Golisopod   75  125  ...                         Gray
# 622.0               Golett   59   74  ...             No Guard   Green
# 82.0                 Golem   80  110  ...            Sand Veil   Brown
# 60.0               Golduck   80   82  ...           Swift Swim    Blue
# 135.0              Goldeen   45   67  ...         Lightningrod     Red
# 45.0                Golbat   75   80  ...          Infiltrator  Purple
# 673.0               Gogoat  123  100  ...           Grass Pelt   Brown
# 48.0                 Gloom   60   65  ...               Stench    Blue
# 238.0              Gliscor   75   95  ...          Poison Heal  Purple
# 237.0               Gligar   65   75  ...             Immunity  Purple
# 455.0              Glameow   49   55  ...             Keen Eye    Gray
# 390.0               Glalie   80   80  ...                Moody    Gray
# 164.0              Glaceon   65   60  ...             Ice Body    Blue
# 487.1         Giratina (O)  150  120  ...                        Black
# 487.0             Giratina  150  100  ...            Telepathy   Black
# 233.0            Girafarig   70   80  ...           Sap Sipper  Yellow
# 526.0             Gigalith   85  135  ...           Sand Force    Blue
# 463.0                Gible   58   70  ...           Rough Skin    Blue
# 80.0               Geodude   40   80  ...            Sand Veil   Brown
# 102.0               Gengar   60   65  ...                       Purple
# 649.0             Genesect   71  120  ...                       Purple
# 450.0            Gastrodon  111   83  ...           Sand Force  Purple
# 100.0               Gastly   30   35  ...                       Purple
# 306.0            Gardevoir   68   65  ...            Telepathy   White
# 465.0             Garchomp  108  130  ...           Rough Skin    Blue
# 569.0             Garbodor   80   95  ...            Aftermath   Green
# 596.0           Galvantula   70   77  ...                Swarm  Yellow
# 307.0              Gallade   68  125  ...            Justified   White
# 464.0               Gabite   68   90  ...           Rough Skin    Blue
# 193.0               Furret   85   76  ...                Frisk   Brown
# 676.0              Furfrou   75   80  ...                        White
# 391.0             Froslass   70   80  ...          Cursed Body   White
# 657.0            Frogadier   54   63  ...              Protean    Blue
# 656.0              Froakie   41   56  ...              Protean    Blue
# 592.0             Frillish   55   40  ...                        White
# 611.0              Fraxure   66  117  ...              Unnerve   Green
# 235.0           Forretress   75   90  ...             Overcoat  Purple
# 590.0              Foongus   69   55  ...          Regenerator   White
# 753.0             Fomantis   40   55  ...             Contrary    Pink
# 357.0               Flygon   80  100  ...                        Green
# 671.0              Florges   78   65  ...            Symbiosis   White
# 670.0              Floette   54   45  ...            Symbiosis   White
# 446.0             Floatzel   85  105  ...           Water Veil   Brown
# 661.0           Fletchling   45   50  ...           Gale Wings     Red
# 662.0          Fletchinder   62   73  ...           Gale Wings     Red
# 160.0              Flareon   65  130  ...                 Guts     Red
# 669.0              Flabébé   44   38  ...            Symbiosis   White
# 208.0              Flaaffy   70   55  ...                 Plus    Pink
# 475.0              Finneon   49   49  ...           Water Veil    Blue
# 598.0           Ferrothorn   74   94  ...                         Gray
# 597.0            Ferroseed   44   50  ...                         Gray
# 191.0           Feraligatr   85  105  ...          Sheer Force    Blue
# 653.0             Fennekin   40   45  ...             Magician     Red
# 376.0               Feebas   20   15  ...         Adaptability   Brown
# 22.0                Fearow   65   90  ...               Sniper   Brown
# 91.0            Farfetch'd   52   65  ...              Defiant   Brown
# 320.0              Exploud  104   91  ...              Scrappy    Blue
# 112.0            Exeggutor   95   95  ...              Harvest  Yellow
# 111.0            Exeggcute   60   40  ...              Harvest    Pink
# 530.0            Excadrill  110  135  ...         Mold Breaker    Gray
# 677.0               Espurr   62   48  ...            Own Tempo    Gray
# 161.0               Espeon   65   65  ...         Magic Bounce  Purple
# 589.0           Escavalier   70  135  ...             Overcoat    Gray
# 268.0                Entei  115  115  ...           Flash Fire   Brown
# 424.0             Empoleon   84   86  ...              Defiant    Blue
# 587.0               Emolga   55   75  ...          Motor Drive   White
# 500.0               Emboar  110  123  ...             Reckless     Red
# 605.0               Elgyem   55   55  ...             Analytic    Blue
# 145.0               Elekid   45   63  ...         Vital Spirit  Yellow
# 110.0            Electrode   60   50  ...            Aftermath     Red
# 334.0            Electrike   40   45  ...                Minus   Green
# 147.0           Electivire   75  123  ...         Vital Spirit  Yellow
# 146.0           Electabuzz   65   83  ...         Vital Spirit  Yellow
# 23.0                 Ekans   30   60  ...              Unnerve  Purple
# 157.0                Eevee   55   55  ...         Anticipation   Brown
# 604.0           Eelektross   85  115  ...                         Blue
# 603.0            Eelektrik   65   85  ...                         Blue
# 557.0              Dwebble   50   65  ...           Weak Armor     Red
# 293.0               Dustox   60   50  ...         Compoundeyes   Green
# 382.0              Duskull   20   40  ...                        Black
# 384.0             Dusknoir   45  100  ...                        Black
# 383.0             Dusclops   40   70  ...                        Black
# 632.0               Durant   58  109  ...               Truant    Gray
# 578.0              Duosion   65   40  ...          Regenerator   Green
# 236.0            Dunsparce  100   70  ...              Rattled  Yellow
# 56.0               Dugtrio   35   80  ...           Sand Force   Brown
# 580.0             Ducklett   62   44  ...            Hydration    Blue
# 621.0            Druddigon   77  120  ...         Mold Breaker     Red
# 105.0              Drowzee   60   48  ...          Inner Focus  Yellow
# 529.0              Drilbur   60   85  ...         Mold Breaker    Gray
# 451.0             Drifloon   90   50  ...          Flare Boost  Purple
# 452.0             Drifblim  150   80  ...          Flare Boost  Purple
# 178.0              Dratini   41   64  ...         Marvel Scale    Blue
# 471.0              Drapion   70   90  ...             Keen Eye  Purple
# 780.0               Drampa   78   60  ...           Cloud Nine   White
# 180.0            Dragonite   91  134  ...           Multiscale   Brown
# 179.0            Dragonair   61   84  ...         Marvel Scale    Blue
# 691.0             Dragalge   65   75  ...         Adaptability   Brown
# 680.0             Doublade   59  110  ...                        Brown
# 263.0              Donphan   90  120  ...            Sand Veil    Gray
# 92.0                 Doduo   35   85  ...         Tangled Feet   Brown
# 93.0                Dodrio   60  110  ...         Tangled Feet   Brown
# 156.0                Ditto   48   48  ...             Imposter  Purple
# 55.0               Diglett   10   55  ...           Sand Force   Brown
# 660.0            Diggersby   85   56  ...           Huge Power   Brown
# 719.0              Diancie   50  100  ...  Magic Bounce (Mega)    Pink
# 483.0               Dialga  100  120  ...            Telepathy   White
# 781.0             Dhelmise   70  131  ...                        Green
# 751.0             Dewpider   38   40  ...         Water Absorb   Green
# 502.0               Dewott   75   75  ...          Shell Armor    Blue
# 95.0               Dewgong   90   70  ...             Ice Body   White
# 415.3           Deoxys (S)   50   95  ...                          Red
# 415.0           Deoxys (N)   50  150  ...                          Red
# 415.2           Deoxys (D)   50   70  ...                          Red
# 415.1           Deoxys (A)   50  180  ...                          Red
# 655.0              Delphox   75   69  ...             Magician     Red
# 256.0             Delibird   45   55  ...             Insomnia     Red
# 326.0             Delcatty   70   65  ...          Wonder Skin  Purple
# 633.0                Deino   52   65  ...                         Blue
# 585.0             Deerling   60   60  ...         Serene Grace  Yellow
# 702.0              Dedenne   67   58  ...                 Plus  Yellow
# 724.0            Decidueye   78  107  ...                        Brown
# 554.0             Darumaka   70   90  ...          Inner Focus     Red
# 723.0              Dartrix   78   75  ...                        Brown
# 555.1       Darmanitan (Z)  105   30  ...             Zen Mode     Red
# 555.0           Darmanitan  105  140  ...             Zen Mode     Red
# 491.0              Darkrai   70   90  ...                        Black
# 186.0            Cyndaquil   39   52  ...           Flash Fire  Yellow
# 742.0             Cutiefly   40   45  ...           Sweet Veil  Yellow
# 113.0               Cubone   50   50  ...         Battle Armor   Brown
# 613.0              Cubchoo   55   70  ...              Rattled   White
# 615.0            Cryogonal   70   50  ...                         Blue
# 558.0              Crustle   70   95  ...           Weak Armor     Red
# 190.0             Croconaw   65   80  ...          Sheer Force    Blue
# 46.0                Crobat   85   90  ...          Infiltrator  Purple
# 472.0             Croagunk   48   61  ...         Poison Touch    Blue
# 488.0            Cresselia  120   70  ...                       Yellow
# 369.0            Crawdaunt   63  120  ...         Adaptability     Red
# 435.0             Cranidos   67  125  ...          Sheer Force    Blue
# 373.0              Cradily   86   81  ...          Storm Drain   Green
# 739.0           Crabrawler   47   82  ...          Anger Point  Purple
# 740.0         Crabominable   97  132  ...          Anger Point   White
# 546.0             Cottonee   40   27  ...          Chlorophyll   Green
# 789.0               Cosmog   43   29  ...                         Blue
# 790.0              Cosmoem   43   29  ...                         Blue
# 253.0              Corsola   55   55  ...          Regenerator    Pink
# 368.0             Corphish   43   80  ...         Adaptability     Red
# 534.0           Conkeldurr  105  140  ...            Iron Fist   Brown
# 764.0               Comfey   51   52  ...         Natural Cure   Green
# 280.0            Combusken   60   85  ...          Speed Boost     Red
# 442.0               Combee   30   30  ...               Hustle  Yellow
# 563.0           Cofagrigus   58   50  ...                       Yellow
# 638.0             Cobalion   91   90  ...                         Blue
# 99.0              Cloyster   50   90  ...             Overcoat  Purple
# 36.0                Cleffa   50   25  ...         Friend Guard    Pink
# 37.0              Clefairy   70   45  ...         Friend Guard    Pink
# 38.0              Clefable   95   70  ...              Unaware    Pink
# 371.0              Claydol   60   70  ...                        Black
# 693.0            Clawitzer   71   73  ...                         Blue
# 692.0            Clauncher   50   53  ...                         Blue
# 395.0             Clamperl   35   64  ...              Rattled    Blue
# 573.0             Cinccino   75   95  ...           Skill Link    Gray
# 386.0            Chingling   45   30  ...                       Yellow
# 200.0             Chinchou   75   38  ...         Water Absorb    Blue
# 387.0             Chimecho   65   50  ...                         Blue
# 419.0             Chimchar   44   58  ...            Iron Fist   Brown
# 183.0            Chikorita   45   49  ...           Leaf Guard   Green
# 650.0              Chespin   56   61  ...          Bulletproof   Green
# 652.0           Chesnaught   88  107  ...          Bulletproof   Green
# 447.0              Cherubi   45   35  ...                         Pink
# 448.0              Cherrim   70   60  ...                         Pink
# 461.0               Chatot   76   65  ...            Big Pecks   Black
# 5.0             Charmeleon   58   64  ...          Solar Power     Red
# 4.0             Charmander   39   52  ...          Solar Power     Red     Abby
# 737.0            Charjabug   57   82  ...                        Green
# 6.0              Charizard   78   84  ...          Solar Power     Red
# 127.0              Chansey  250    5  ...               Healer    Pink
# 609.0           Chandelure   60   55  ...           Shadow Tag   Black
# 797.0           Celesteela   97  101  ...                        Green
# 275.0               Celebi  100  100  ...                        Green
# 10.0              Caterpie   45   30  ...             Run Away   Green
# 378.0             Castform   70   70  ...                        White
# 292.0              Cascoon   50   35  ...                       Purple
# 345.0             Carvanha   45   90  ...          Speed Boost     Red
# 565.0           Carracosta   74  108  ...           Swift Swim    Blue
# 474.0            Carnivine   74  100  ...                        Green
# 703.0              Carbink   50   50  ...               Sturdy    Gray
# 350.0             Camerupt   70  100  ...          Anger Point     Red
# 359.0             Cacturne   70  115  ...         Water Absorb   Green
# 358.0               Cacnea   50   85  ...         Water Absorb   Green
# 794.0             Buzzwole  107  139  ...                          Red
# 12.0            Butterfree   60   45  ...          Tinted Lens   White
# 439.0                Burmy   40   29  ...             Overcoat    Gray
# 659.0             Bunnelby   38   36  ...           Huge Power   Brown
# 453.0              Buneary   55   66  ...               Limber   Brown
# 1.0              Bulbasaur   45   49  ...          Chlorophyll   Green
# 445.0               Buizel   55   65  ...           Water Veil   Brown
# 340.0                Budew   40   30  ...           Leaf Guard   Green
# 779.0              Bruxish   68  105  ...          Wonder Skin    Pink
# 459.0              Bronzor   57   24  ...          Heavy Metal   Green
# 460.0             Bronzong   67   89  ...          Heavy Metal   Green
# 729.0              Brionne   60   69  ...                         Blue
# 311.0              Breloom   60  130  ...           Technician   Green
# 628.0             Braviary  100  123  ...              Defiant     Red
# 654.0              Braixen   59   59  ...             Magician     Red
# 761.0            Bounsweet   42   30  ...           Sweet Veil  Purple
# 626.0           Bouffalant   95  110  ...           Soundproof   Brown
# 213.0               Bonsly   50   80  ...              Rattled   Brown
# 525.0              Boldore   70  105  ...           Sand Force    Blue
# 522.0              Blitzle   45   60  ...           Sap Sipper   Black
# 128.0              Blissey  255   10  ...               Healer    Pink
# 281.0             Blaziken   80  120  ...          Speed Boost     Red
# 9.0              Blastoise   79   83  ...            Rain Dish    Blue
# 625.0              Bisharp   65  125  ...             Pressure     Red
# 688.0              Binacle   42   52  ...           Pickpocket   Brown
# 428.0               Bidoof   59   45  ...                Moody   Brown
# 429.0              Bibarel   79   85  ...                Moody   Brown
# 760.0               Bewear  120  125  ...              Unnerve    Pink
# 712.0             Bergmite   55   69  ...               Sturdy    Blue
# 75.0            Bellsprout   50   75  ...             Gluttony   Green
# 50.0             Bellossom   75   80  ...               Healer   Green
# 403.0               Beldum   40   55  ...          Light Metal    Blue
# 606.0             Beheeyem   75   75  ...             Analytic   Brown
# 15.0              Beedrill   65   80  ...               Sniper  Yellow
# 291.0            Beautifly   60   70  ...              Rivalry  Yellow
# 614.0              Beartic   95  110  ...           Swift Swim   White
# 184.0              Bayleef   60   62  ...           Leaf Guard   Green
# 438.0            Bastiodon   60   52  ...           Soundproof    Gray
# 550.0             Basculin   70   92  ...         Mold Breaker   Green
# 366.0             Barboach   50   48  ...            Hydration    Gray
# 689.0           Barbaracle   72  105  ...           Pickpocket   Brown
# 381.0              Banette   64  115  ...          Cursed Body   Black
# 370.0               Baltoy   40   40  ...                        Brown
# 400.0                Bagon   45   75  ...          Sheer Force    Blue
# 210.0              Azurill   50   20  ...           Sap Sipper    Blue
# 212.0            Azumarill  100   50  ...           Sap Sipper    Blue
# 482.0                Azelf   75  125  ...                         Blue
# 610.0                 Axew   46   87  ...              Unnerve   Green
# 713.0              Avalugg   95  117  ...               Sturdy    Blue
# 699.0              Aurorus  123   77  ...         Snow Warning    Blue
# 531.0               Audino  103   60  ...                Klutz    Pink
# 175.0             Articuno   90   85  ...           Snow Cloak    Blue
# 329.0                 Aron   50   70  ...          Heavy Metal    Gray
# 683.0           Aromatisse  101   72  ...           Aroma Veil    Pink
# 375.0              Armaldo   75  125  ...           Swift Swim    Gray
# 199.0              Ariados   70   90  ...               Sniper     Red
# 567.0             Archeops   75  140  ...                       Yellow
# 566.0               Archen   55  112  ...                       Yellow
# 493.0               Arceus  120  120  ...                         Gray
# 64.0              Arcanine   90  110  ...            Justified   Brown
# 24.0                 Arbok   60   85  ...              Unnerve  Purple
# 752.0            Araquanid   68   70  ...         Water Absorb   Green
# 374.0              Anorith   45   95  ...           Swift Swim    Gray
# 209.0             Ampharos   90   75  ...                 Plus  Yellow
# 591.0            Amoonguss  114   85  ...          Regenerator   White
# 219.0              Ambipom   75  100  ...           Skill Link  Purple
# 698.0               Amaura   77   59  ...         Snow Warning    Blue
# 361.0              Altaria   75   70  ...           Cloud Nine    Blue
# 594.0            Alomomola  165   75  ...          Regenerator    Pink
# 71.0              Alakazam   55   50  ...          Magic Guard   Brown
# 218.0                Aipom   55   70  ...           Skill Link  Purple
# 331.0               Aggron   70  110  ...          Heavy Metal    Gray
# 172.0           Aerodactyl   80  105  ...              Unnerve  Purple
# 681.0            Aegislash   60   50  ...                        Brown
# 617.0             Accelgor   80   70  ...             Unburden     Red
# 388.0                Absol   65  130  ...            Justified   White
# 69.0                  Abra   25   20  ...          Magic Guard   Brown
# 478.0            Abomasnow   90   92  ...           Soundproof   White
#
# [820 rows x 15 columns]

# %%
# You can sort by multiple columns
pokedex_df.sort_values(['Type I','Type II', 'Total'], ascending=False) # Sort by type combination, then stats descending

# %%
pokedex_df.sort_values('Type I')
# Out:
#                    Pokemon   HP  ...   Color Nickname
# 235.0           Forretress   75  ...  Purple
# 589.0           Escavalier   70  ...    Gray
# 588.0           Karrablast   50  ...    Blue
# 291.0            Beautifly   60  ...  Yellow
# 736.0              Grubbin   47  ...    Gray
# 737.0            Charjabug   57  ...   Green
# 738.0             Vikavolt   77  ...    Blue
# 666.0             Vivillon   80  ...   Black
# 292.0              Cascoon   50  ...  Purple
# 338.0              Volbeat   65  ...    Gray
# 54.0              Venomoth   70  ...  Purple
# 53.0               Venonat   60  ...  Purple
# 52.0              Parasect   60  ...     Red
# 51.0                 Paras   35  ...     Red
# 742.0             Cutiefly   40  ...  Yellow
# 540.0             Sewaddle   45  ...  Yellow
# 443.0            Vespiquen   70  ...  Yellow
# 339.0             Illumise   65  ...  Purple
# 545.0            Scolipede   60  ...     Red
# 595.0               Joltik   50  ...  Yellow
# 596.0           Galvantula   70  ...  Yellow
# 199.0              Ariados   70  ...     Red
# 223.0              Yanmega   86  ...   Green
# 198.0             Spinarak   40  ...   Green
# 542.0             Leavanny   75  ...  Yellow
# 308.0              Surskit   40  ...    Blue
# 309.0           Masquerain   70  ...    Blue
# 543.0             Venipede   30  ...     Red
# 197.0               Ledian   55  ...     Red
# 196.0               Ledyba   40  ...     Red
# 616.0              Shelmet   50  ...     Red
# 315.0              Nincada   31  ...    Gray
# 316.0              Ninjask   61  ...  Yellow
# 617.0             Accelgor   80  ...     Red
# 234.0               Pineco   50  ...    Gray
# 317.0             Shedinja    1  ...   Brown
# 293.0               Dustox   60  ...   Green
# 544.0           Whirlipede   40  ...    Gray
# 442.0               Combee   30  ...  Yellow
# 441.0               Mothim   70  ...  Yellow
# 743.0             Ribombee   60  ...  Yellow
# 440.1         Wormadam (S)   60  ...    Gray
# 142.0               Scizor   70  ...     Red
# 649.0             Genesect   71  ...  Purple
# 15.0              Beedrill   65  ...  Yellow
# 14.0                Kakuna   45  ...  Yellow
# 13.0                Weedle   40  ...   Brown
# 12.0            Butterfree   60  ...   White
# 440.2         Wormadam (T)   60  ...    Gray
# 11.0               Metapod   50  ...   Green
# 794.0             Buzzwole  107  ...     Red
# 795.0            Pheromosa   71  ...   White
# 557.0              Dwebble   50  ...     Red
# 632.0               Durant   58  ...    Gray
# 637.0            Volcarona   85  ...   White
# 636.0             Larvesta   55  ...   White
# 10.0              Caterpie   45  ...   Green
# 141.0              Scyther   70  ...   Green
# 151.0               Pinsir   65  ...   Brown
# 767.0               Wimpod   25  ...    Gray
# 440.0         Wormadam (P)   60  ...    Gray
# 439.0                Burmy   40  ...    Gray
# 665.0               Spewpa   45  ...   Black
# 243.0            Heracross   80  ...    Blue
# 222.0                Yanma   65  ...     Red
# 242.0              Shuckle   20  ...  Yellow
# 664.0           Scatterbug   38  ...   Black
# 290.0              Silcoon   50  ...   White
# 768.0            Golisopod   75  ...    Gray
# 431.0           Kricketune   77  ...     Red
# 541.0             Swadloon   55  ...   Green
# 289.0              Wurmple   45  ...     Red
# 558.0              Crustle   70  ...     Red
# 430.0            Kricketot   37  ...     Red
# 260.0             Houndour   45  ...   Black
# 687.0              Malamar   86  ...    Blue
# 510.0              Liepard   64  ...  Purple
# 629.0              Vullaby   70  ...   Brown
# 633.0                Deino   52  ...    Blue
# 625.0              Bisharp   65  ...     Red
# 630.0            Mandibuzz  110  ...   Brown
# 285.0            Poochyena   35  ...    Gray
# 624.0             Pawniard   45  ...     Red
# 286.0            Mightyena   70  ...    Gray
# 261.0             Houndoom   75  ...   Black
# 491.0              Darkrai   70  ...   Black
# 686.0                Inkay   53  ...    Blue
# 509.0             Purrloin   41  ...  Purple
# 634.0             Zweilous   72  ...    Blue
# 560.0              Scrafty   65  ...     Red
# 559.0              Scraggy   50  ...  Yellow
# 570.0                Zorua   40  ...    Gray
# 571.0              Zoroark   60  ...    Gray
# 244.0              Sneasel   55  ...   Black
# 327.0              Sableye   50  ...  Purple
# 227.0            Honchkrow  100  ...   Black
# 162.0              Umbreon   95  ...   Black
# 717.0              Yveltal  126  ...     Red
# 635.0            Hydreigon   92  ...    Blue
# 245.0              Weavile   70  ...   Black
# 799.0             Guzzlord  223  ...   Black
# 388.0                Absol   65  ...   White
# 226.0              Murkrow   60  ...   Black
# 643.0             Reshiram  100  ...   White
# 179.0            Dragonair   61  ...    Blue
# 180.0            Dragonite   91  ...   Brown
# 783.0             Hakamo-o   55  ...    Gray
# 782.0             Jangmo-o   45  ...    Gray
# 646.0               Kyurem  125  ...    Gray
# 402.0            Salamence   95  ...    Blue
# 401.0              Shelgon   65  ...   White
# 410.0               Latios   80  ...    Blue
# 400.0                Bagon   45  ...    Blue
# 178.0              Dratini   41  ...    Blue
# 413.0             Rayquaza  105  ...   Green
# 784.0              Kommo-o   75  ...    Gray
# 644.0               Zekrom  100  ...   Black
# 409.0               Latias   80  ...     Red
# 718.0              Zygarde  108  ...   Green
# 610.0                 Axew   46  ...   Green
# 463.0                Gible   58  ...    Blue
# 464.0               Gabite   68  ...    Blue
# 621.0            Druddigon   77  ...     Red
# 465.0             Garchomp  108  ...    Blue
# 704.0                Goomy   45  ...  Purple
# 705.0              Sliggoo   68  ...  Purple
# 612.0              Haxorus   76  ...  Yellow
# 611.0              Fraxure   66  ...   Green
# 361.0              Altaria   75  ...    Blue
# 706.0               Goodra   90  ...  Purple
# 603.0            Eelektrik   65  ...    Blue
# 523.0            Zebstrika   75  ...   Black
# 604.0           Eelektross   85  ...    Blue
# 176.0               Zapdos   90  ...  Yellow
# 207.0               Mareep   55  ...   White
# 208.0              Flaaffy   70  ...    Pink
# 209.0             Ampharos   90  ...  Yellow
# 587.0               Emolga   55  ...   White
# 602.0               Tynamo   35  ...   White
# 25.0                 Pichu   20  ...  Yellow
# 479.2         Rotom (Wash)   50  ...     Red
# 159.0              Jolteon   65  ...  Yellow
# 433.0                Luxio   60  ...    Blue
# 434.0               Luxray   80  ...    Blue
# 337.0                Minun   60  ...  Yellow
# 479.0                Rotom   50  ...     Red
# 336.0               Plusle   60  ...  Yellow
# 694.0           Helioptile   44  ...  Yellow
# 695.0            Heliolisk   62  ...  Yellow
# 335.0            Manectric   70  ...  Yellow
# 147.0           Electivire   75  ...  Yellow
# 522.0              Blitzle   45  ...   Black
# 702.0              Dedenne   67  ...  Yellow
# 89.0              Magneton   50  ...    Gray
# 334.0            Electrike   40  ...   Green
# 88.0             Magnemite   25  ...    Gray
# 90.0             Magnezone   70  ...    Gray
# 444.0            Pachirisu   60  ...   White
# 110.0            Electrode   60  ...     Red
# 109.0              Voltorb   40  ...     Red
# 777.0           Togedemaru   65  ...    Gray
# 479.3        Rotom (Frost)   50  ...     Red
# 479.4         Rotom (Spin)   50  ...     Red
# 432.0                Shinx   45  ...    Blue
# 27.0                Raichu   60  ...  Yellow
# 479.5          Rotom (Cut)   50  ...     Red
# 26.0               Pikachu   35  ...  Yellow
# 479.1         Rotom (Heat)   50  ...     Red
# 785.0            Tapu Koko   70  ...  Yellow
# 267.0               Raikou   90  ...  Yellow
# 146.0           Electabuzz   65  ...  Yellow
# 145.0               Elekid   45  ...  Yellow
# 796.0            Xurkitree   83  ...   Black
# 642.0            Thundurus   79  ...    Blue
# 239.0             Snubbull   60  ...    Pink
# 240.0             Granbull   90  ...  Purple
# 764.0               Comfey   51  ...   Green
# 37.0              Clefairy   70  ...    Pink
# 38.0              Clefable   95  ...    Pink
# 716.0              Xerneas  126  ...    Blue
# 36.0                Cleffa   50  ...    Pink
# 683.0           Aromatisse  101  ...    Pink
# 669.0              Flabébé   44  ...   White
# 670.0              Floette   54  ...   White
# 671.0              Florges   78  ...   White
# 682.0             Spritzee   78  ...    Pink
# 684.0              Swirlix   62  ...   White
# 685.0             Slurpuff   82  ...   White
# 202.0               Togepi   35  ...   White
# 700.0              Sylveon   95  ...    Pink
# 203.0              Togetic   55  ...   White
# 204.0             Togekiss   85  ...   White
# 539.0                 Sawk   75  ...    Blue
# 466.0                Riolu   40  ...    Blue
# 333.0             Medicham   60  ...     Red
# 538.0                Throh  120  ...     Red
# 534.0           Conkeldurr  105  ...   Brown
# 533.0              Gurdurr   85  ...    Gray
# 332.0             Meditite   30  ...    Blue
# 467.0              Lucario   70  ...    Blue
# 322.0             Hariyama  144  ...   Brown
# 532.0              Timburr   75  ...    Gray
# 118.0            Hitmontop   50  ...   Brown
# 115.0              Tyrogue   35  ...  Purple
# 321.0             Makuhita   72  ...  Yellow
# 802.0            Marshadow   90  ...    Gray
# 739.0           Crabrawler   47  ...  Purple
# 619.0              Mienfoo   45  ...  Yellow
# 740.0         Crabominable   97  ...   White
# 766.0            Passimian  100  ...   White
# 117.0           Hitmonchan   50  ...   Brown
# 116.0            Hitmonlee   50  ...   Brown
# 674.0              Pancham   67  ...   White
# 675.0              Pangoro   95  ...   White
# 72.0                Machop   70  ...    Gray
# 620.0             Mienshao   65  ...  Purple
# 73.0               Machoke   80  ...    Gray
# 61.0                Mankey   40  ...   Brown
# 701.0             Hawlucha   78  ...   Green
# 74.0               Machamp   90  ...    Gray
# 62.0              Primeape   65  ...   Brown
# 653.0             Fennekin   40  ...     Red
# 64.0              Arcanine   90  ...   Brown
# 279.0              Torchic   45  ...     Red
# 274.0                Ho-oh  106  ...     Red
# 280.0            Combusken   60  ...     Red
# 498.0                Tepig   65  ...     Red
# 499.0              Pignite   90  ...     Red
# 281.0             Blaziken   80  ...     Red
# 727.0           Incineroar   95  ...     Red
# 63.0             Growlithe   55  ...   Brown
# 554.0             Darumaka   70  ...     Red
# 654.0              Braixen   59  ...     Red
# 655.0              Delphox   75  ...     Red
# 485.0              Heatran   91  ...   Brown
# 663.0           Talonflame   78  ...     Red
# 667.0               Litleo   62  ...   Brown
# 668.0               Pyroar   86  ...   Brown
# 725.0               Litten   45  ...     Red
# 555.0           Darmanitan  105  ...     Red
# 150.0            Magmortar   75  ...     Red
# 721.0            Volcanion   80  ...   Brown
# 84.0              Rapidash   65  ...  Yellow
# 83.0                Ponyta   50  ...  Yellow
# 726.0             Torracat   65  ...     Red
# 662.0          Fletchinder   62  ...     Red
# 500.0               Emboar  110  ...     Red
# 268.0                Entei  115  ...   Brown
# 776.0           Turtonator   60  ...     Red
# 4.0             Charmander   39  ...     Red     Abby
# 419.0             Chimchar   44  ...   Brown
# 248.0               Slugma   40  ...     Red
# 249.0             Magcargo   50  ...     Red
# 420.0             Monferno   64  ...   Brown
# 421.0            Infernape   76  ...   Brown
# 555.1       Darmanitan (Z)  105  ...     Red
# 351.0              Torkoal   70  ...   Brown
# 350.0             Camerupt   70  ...     Red
# 188.0           Typhlosion   78  ...  Yellow
# 5.0             Charmeleon   58  ...     Red
# 187.0              Quilava   58  ...  Yellow
# 6.0              Charizard   78  ...     Red
# 177.0              Moltres   90  ...  Yellow
# 741.0             Oricorio   75  ...     Red
# 40.0             Ninetales   73  ...  Yellow
# 39.0                Vulpix   38  ...   Brown
# 148.0                Magby   45  ...     Red
# 186.0            Cyndaquil   39  ...  Yellow
# 513.0              Pansear   50  ...     Red
# 149.0               Magmar   65  ...     Red
# 349.0                Numel   60  ...  Yellow
# 514.0             Simisear   75  ...     Red
# 160.0              Flareon   65  ...     Red
# 631.0              Heatmor   85  ...     Red
# 714.0               Noibat   40  ...  Purple
# 715.0              Noivern   85  ...  Purple
# 641.0             Tornadus   79  ...   Green
# 383.0             Dusclops   40  ...   Black
# 382.0              Duskull   20  ...   Black
# 770.0            Palossand   85  ...   Brown
# 778.0              Mimikyu   55  ...  Yellow
# 462.0            Spiritomb   50  ...  Purple
# 229.0            Mismagius   60  ...  Purple
# 452.0             Drifblim  150  ...  Purple
# 769.0            Sandygast   55  ...   Brown
# 451.0             Drifloon   90  ...  Purple
# 781.0             Dhelmise   70  ...   Green
# 711.0            Gourgeist   55  ...   Brown
# 101.0              Haunter   45  ...  Purple
# 380.0              Shuppet   44  ...   Black
# 710.0            Pumpkaboo   44  ...   Brown
# 607.0              Litwick   50  ...   White
# 381.0              Banette   64  ...   Black
# 608.0              Lampent   60  ...   Black
# 563.0           Cofagrigus   58  ...  Yellow
# 487.0             Giratina  150  ...   Black
# 562.0               Yamask   38  ...   Black
# 228.0           Misdreavus   60  ...    Gray
# 102.0               Gengar   60  ...  Purple
# 487.1         Giratina (O)  150  ...   Black
# ...                    ...  ...  ...     ...      ...
# 219.0              Ambipom   75  ...  Purple
# 120.0           Lickilicky  110  ...    Pink
# 326.0             Delcatty   70  ...  Purple
# 360.0               Swablu   45  ...    Blue
# 453.0              Buneary   55  ...   Brown
# 325.0               Skitty   50  ...    Pink
# 455.0              Glameow   49  ...    Gray
# 456.0              Purugly   71  ...    Gray
# 126.0              Happiny  100  ...    Pink
# 461.0               Chatot   76  ...   Black
# 210.0              Azurill   50  ...    Blue
# 320.0              Exploud  104  ...    Blue
# 312.0              Slakoth   60  ...   Brown
# 313.0             Vigoroth   80  ...   White
# 314.0              Slaking  150  ...   Brown
# 173.0             Munchlax  135  ...   Black
# 319.0              Loudred   84  ...    Blue
# 454.0              Lopunny   65  ...   Brown
# 362.0             Zangoose   73  ...   White
# 318.0              Whismur   64  ...    Pink
# 379.0              Kecleon   60  ...   Green
# 493.0               Arceus  120  ...    Gray
# 287.0            Zigzagoon   38  ...   Brown
# 486.0            Regigigas  110  ...   White
# 288.0              Linoone   78  ...   White
# 34.0              Nidorino   61  ...  Purple
# 344.0               Swalot  100  ...  Purple
# 343.0               Gulpin   70  ...   Green
# 33.0              Nidoran♂   46  ...  Purple
# 32.0             Nidoqueen   90  ...    Blue
# 31.0              Nidorina   70  ...    Blue
# 30.0              Nidoran♀   55  ...    Blue
# 568.0             Trubbish   50  ...   Green
# 569.0             Garbodor   80  ...   Green
# 24.0                 Arbok   60  ...  Purple
# 23.0                 Ekans   30  ...  Purple
# 457.0               Stunky   63  ...  Purple
# 458.0             Skuntank  103  ...  Purple
# 473.0            Toxicroak   83  ...    Blue
# 472.0             Croagunk   48  ...    Blue
# 471.0              Drapion   70  ...  Purple
# 470.0              Skorupi   40  ...  Purple
# 46.0                Crobat   85  ...  Purple
# 122.0              Weezing   65  ...  Purple
# 121.0              Koffing   40  ...  Purple
# 97.0                   Muk  105  ...  Purple
# 747.0             Mareanie   50  ...    Blue
# 35.0              Nidoking   81  ...  Purple
# 690.0               Skrelp   50  ...   Brown
# 748.0              Toxapex   50  ...    Blue
# 363.0              Seviper   73  ...   Black
# 691.0             Dragalge   65  ...   Brown
# 758.0             Salazzle   68  ...   Black
# 45.0                Golbat   75  ...  Purple
# 96.0                Grimer   80  ...  Purple
# 757.0             Salandit   48  ...   Black
# 44.0                 Zubat   40  ...  Purple
# 677.0               Espurr   62  ...    Gray
# 790.0              Cosmoem   43  ...    Blue
# 70.0               Kadabra   40  ...   Brown
# 69.0                  Abra   25  ...   Brown
# 415.0           Deoxys (N)   50  ...     Red
# 791.0             Solgaleo  137  ...   White
# 792.0               Lunala  137  ...  Purple
# 415.3           Deoxys (S)   50  ...     Red
# 606.0             Beheeyem   75  ...   Brown
# 605.0               Elgyem   55  ...    Blue
# 800.0             Necrozma   97  ...   Black
# 205.0                 Natu   40  ...   Green
# 789.0               Cosmog   43  ...    Blue
# 71.0              Alakazam   55  ...   Brown
# 720.0            Hoopa (C)   80  ...  Purple
# 387.0             Chimecho   65  ...    Blue
# 353.0              Grumpig   80  ...  Purple
# 352.0               Spoink   60  ...   Black
# 106.0                Hypno   85  ...  Yellow
# 105.0              Drowzee   60  ...  Yellow
# 273.0                Lugia  106  ...   White
# 415.1           Deoxys (A)   50  ...     Red
# 786.0            Tapu Lele   70  ...    Pink
# 206.0                 Xatu   65  ...   Green
# 182.0                  Mew  100  ...    Pink
# 231.0               Wynaut   95  ...    Blue
# 386.0            Chingling   45  ...  Yellow
# 678.0             Meowstic   74  ...   White
# 720.0            Hoopa (U)   80  ...  Purple
# 139.0             Mime Jr.   20  ...    Pink
# 181.0               Mewtwo  106  ...  Purple
# 415.2           Deoxys (D)   50  ...     Red
# 140.0             Mr. Mime   40  ...    Pink
# 306.0            Gardevoir   68  ...   White
# 232.0            Wobbuffet  190  ...    Blue
# 307.0              Gallade   68  ...   White
# 561.0             Sigilyph   72  ...   Black
# 494.0              Victini  100  ...  Yellow
# 574.0              Gothita   45  ...  Purple
# 575.0            Gothorita   60  ...  Purple
# 576.0           Gothitelle   70  ...  Purple
# 488.0            Cresselia  120  ...  Yellow
# 161.0               Espeon   65  ...  Purple
# 518.0             Musharna  116  ...    Pink
# 517.0                Munna   76  ...    Pink
# 577.0              Solosis   45  ...   Green
# 578.0              Duosion   65  ...   Green
# 275.0               Celebi  100  ...   Green
# 305.0               Kirlia   38  ...   White
# 579.0            Reuniclus  110  ...   Green
# 482.0                Azelf   75  ...    Blue
# 480.0                 Uxie   75  ...  Yellow
# 230.0                Unown   48  ...   Black
# 481.0              Mesprit   80  ...    Pink
# 527.0               Woobat   55  ...    Blue
# 304.0                Ralts   28  ...   White
# 528.0              Swoobat   67  ...    Blue
# 525.0              Boldore   70  ...    Blue
# 774.1        Minior (core)   60  ...    Pink
# 703.0              Carbink   50  ...    Gray
# 699.0              Aurorus  123  ...    Blue
# 698.0               Amaura   77  ...    Blue
# 697.0            Tyrantrum   82  ...     Red
# 696.0               Tyrunt   58  ...   Brown
# 438.0            Bastiodon   60  ...    Gray
# 689.0           Barbaracle   72  ...   Brown
# 524.0           Roggenrola   55  ...    Blue
# 688.0              Binacle   42  ...   Brown
# 103.0                 Onix   35  ...    Gray
# 435.0             Cranidos   67  ...    Blue
# 436.0            Rampardos   97  ...    Blue
# 437.0             Shieldon   30  ...    Gray
# 324.0            Probopass   60  ...    Gray
# 406.0             Regirock   80  ...   Brown
# 774.0      Minior (meteor)   60  ...   Brown
# 270.0             Larvitar   50  ...   Green
# 272.0            Tyranitar  100  ...   Green
# 372.0               Lileep   66  ...  Purple
# 364.0             Lunatone   70  ...  Yellow
# 271.0              Pupitar   70  ...    Gray
# 719.0              Diancie   50  ...    Pink
# 214.0            Sudowoodo   70  ...   Brown
# 793.0             Nihilego  109  ...   White
# 213.0               Bonsly   50  ...   Brown
# 365.0              Solrock   70  ...     Red
# 80.0               Geodude   40  ...   Brown
# 744.0             Rockruff   45  ...   Brown
# 745.0    Lycanroc (midday)   75  ...
# 526.0             Gigalith   85  ...    Blue
# 375.0              Armaldo   75  ...    Gray
# 323.0             Nosepass   30  ...    Gray
# 81.0              Graveler   55  ...   Brown
# 171.0             Kabutops   60  ...   Brown
# 639.0            Terrakion   91  ...    Gray
# 168.0              Omanyte   35  ...    Blue
# 169.0              Omastar   70  ...    Blue
# 170.0               Kabuto   30  ...   Brown
# 82.0                 Golem   80  ...   Brown
# 172.0           Aerodactyl   80  ...  Purple
# 745.1  Lycanroc (midnight)   85  ...   Brown
# 374.0              Anorith   45  ...    Gray
# 566.0               Archen   55  ...  Yellow
# 567.0             Archeops   75  ...  Yellow
# 373.0              Cradily   86  ...   Green
# 681.0            Aegislash   60  ...   Brown
# 680.0             Doublade   59  ...   Brown
# 679.0              Honedge   45  ...   Brown
# 414.0              Jirachi  100  ...  Yellow
# 408.0            Registeel   80  ...    Gray
# 259.0             Skarmory   65  ...    Gray
# 707.0               Klefki   57  ...    Gray
# 483.0               Dialga  100  ...   White
# 104.0              Steelix   75  ...    Gray
# 403.0               Beldum   40  ...    Blue
# 405.0            Metagross   80  ...    Blue
# 328.0               Mawile   50  ...   Black
# 459.0              Bronzor   57  ...   Green
# 329.0                 Aron   50  ...    Gray
# 330.0               Lairon   60  ...    Gray
# 460.0             Bronzong   67  ...   Green
# 801.0             Magearna   80  ...    Gray
# 797.0           Celesteela   97  ...   Green
# 601.0            Klinklang   60  ...    Gray
# 638.0             Cobalion   91  ...    Blue
# 331.0               Aggron   70  ...    Gray
# 404.0               Metang   60  ...    Blue
# 600.0                Klang   60  ...    Gray
# 599.0                Klink   40  ...    Gray
# 501.0             Oshawott   55  ...    Blue
# 746.0    Wishiwashi (solo)   45  ...    Blue
# 282.0               Mudkip   50  ...    Blue
# 788.0            Tapu Fini   70  ...  Purple
# 295.0               Lombre   60  ...   Green
# 294.0                Lotad   40  ...   Green
# 503.0             Samurott   95  ...    Blue
# 502.0               Dewott   75  ...    Blue
# 9.0              Blastoise   79  ...    Blue
# 8.0              Wartortle   59  ...    Blue
# 60.0               Golduck   80  ...    Blue
# 376.0               Feebas   20  ...   Brown
# 59.0               Psyduck   50  ...  Yellow
# 7.0               Squirtle   44  ...    Blue
# 395.0             Clamperl   35  ...    Blue
# 283.0            Marshtomp   70  ...    Blue
# 516.0             Simipour   75  ...    Blue
# 515.0              Panpour   50  ...    Blue
# 422.0               Piplup   53  ...    Blue
# 284.0             Swampert  100  ...    Blue
# 484.0               Palkia   90  ...  Purple
# 489.0               Phione   80  ...    Blue
# 368.0             Corphish   43  ...     Red
# 369.0            Crawdaunt   63  ...     Red
# 771.0            Pyukumuku   55  ...   Black
# 399.0              Luvdisc   43  ...    Pink
# 398.0            Relicanth  100  ...    Gray
# 367.0             Whiscash  110  ...    Blue
# 752.0            Araquanid   68  ...   Green
# 751.0             Dewpider   38  ...   Green
# 366.0             Barboach   50  ...    Gray
# 397.0             Gorebyss   55  ...    Pink
# 490.0              Manaphy  100  ...    Blue
# 269.0              Suicune  100  ...    Blue
# 411.0               Kyogre  100  ...    Blue
# 396.0              Huntail   55  ...    Blue
# 779.0              Bruxish   68  ...    Pink
# 746.1  Wishiwashi (school)   45  ...    Blue
# 730.0            Primarina   80  ...    Blue
# 212.0            Azumarill  100  ...    Blue
# 728.0              Popplio   50  ...    Blue
# 450.0            Gastrodon  111  ...  Purple
# 155.0               Lapras  130  ...    Blue
# 154.0             Gyarados   95  ...    Blue
# 449.0              Shellos   76  ...  Purple
# 153.0             Magikarp   20  ...     Red
# 647.0               Keldeo   91  ...  Yellow
# 446.0             Floatzel   85  ...   Brown
# 445.0               Buizel   55  ...   Brown
# 138.0              Starmie   60  ...  Purple
# 137.0               Staryu   30  ...   Brown
# 136.0              Seaking   80  ...     Red
# 135.0              Goldeen   45  ...     Red
# 656.0              Froakie   41  ...    Blue
# 657.0            Frogadier   54  ...    Blue
# 658.0             Greninja   72  ...    Blue
# 224.0               Wooper   55  ...    Blue
# 225.0             Quagsire   95  ...    Blue
# 158.0             Vaporeon  130  ...    Blue
# 565.0           Carracosta   74  ...    Blue
# 594.0            Alomomola  165  ...    Pink
# 593.0            Jellicent  100  ...   White
# 201.0              Lanturn  125  ...    Blue
# 592.0             Frillish   55  ...   White
# 200.0             Chinchou   75  ...    Blue
# 68.0              Politoed   90  ...   Green
# 581.0               Swanna   75  ...   White
# 580.0             Ducklett   62  ...    Blue
# 191.0           Feraligatr   85  ...    Blue
# 190.0             Croconaw   65  ...    Blue
# 189.0             Totodile   50  ...    Blue
# 475.0              Finneon   49  ...    Blue
# 377.0              Milotic   95  ...    Pink
# 476.0             Lumineon   69  ...    Blue
# 257.0              Mantyke   45  ...    Blue
# 564.0             Tirtouga   54  ...    Blue
# 729.0              Brionne   60  ...    Blue
# 133.0               Seadra   55  ...    Blue
# 345.0             Carvanha   45  ...     Red
# 85.0              Slowpoke   90  ...    Pink
# 255.0            Octillery   75  ...     Red
# 296.0             Ludicolo   80  ...   Green
# 79.0            Tentacruel   80  ...    Blue
# 78.0             Tentacool   40  ...    Blue
# 258.0              Mantine   65  ...  Purple
# 424.0             Empoleon   84  ...    Blue
# 537.0           Seismitoad  105  ...    Blue
# 423.0             Prinplup   64  ...    Blue
# 536.0            Palpitoad   75  ...    Blue
# 535.0              Tympole   50  ...    Blue
# 134.0              Kingdra   75  ...    Blue
# 67.0             Poliwrath   90  ...    Blue
# 66.0             Poliwhirl   65  ...    Blue
# 65.0               Poliwag   40  ...    Blue
# 86.0               Slowbro   95  ...    Pink
# 132.0               Horsea   30  ...    Blue
# 254.0             Remoraid   35  ...    Gray
# 94.0                  Seel   65  ...   White
# 346.0             Sharpedo   70  ...    Blue
# 347.0              Wailmer  130  ...    Blue
# 348.0              Wailord  170  ...    Blue
# 87.0              Slowking   95  ...    Pink
# 108.0              Kingler   55  ...     Red
# 107.0               Krabby   30  ...     Red
# 303.0             Pelipper   60  ...  Yellow
# 302.0              Wingull   40  ...   White
# 99.0              Cloyster   50  ...  Purple
# 550.0             Basculin   70  ...   Green
# 692.0            Clauncher   50  ...    Blue
# 693.0            Clawitzer   71  ...    Blue
# 98.0              Shellder   30  ...  Purple
# 241.0             Qwilfish   65  ...    Gray
# 211.0               Marill   70  ...    Blue
# 253.0              Corsola   55  ...    Pink
# 95.0               Dewgong   90  ...   White
#
# [820 rows x 15 columns]

# %% [markdown]
# ## Calculations and operations
# There are various ways to do math to the dataframes

# %% [markdown]
# ### Column operations
# You can perform basic math element-wise between columns, such as addition, subtraction, multiplication, and division

# %%
pokedex_df['Total']/ pokedex_df['HP'] # computes the ratio between total stats and HP
# Out:
# 1.0      7.06667
# 2.0         6.75
# 3.0       6.5625
# 4.0      7.92308
# 5.0      6.98276
# 6.0      6.84615
# 7.0      7.13636
# 8.0      6.86441
# 9.0      6.70886
# 10.0     4.33333
# 11.0         4.1
# 12.0     6.41667
# 13.0       4.875
# 14.0     4.55556
# 15.0     5.84615
# 16.0       6.275
# 17.0     5.53968
# 18.0      5.6506
# 19.0     8.43333
# 20.0     7.50909
# 21.0        6.55
# 22.0         6.8
# 23.0     9.43333
# 24.0         7.3
# 26.0     8.57143
# 27.0     7.91667
# 28.0           6
# 29.0           6
# 30.0           5
# 31.0     5.21429
# 32.0         5.5
# 33.0     5.93478
# 34.0     5.98361
# 35.0     6.11111
# 37.0     4.61429
# 38.0     4.97895
# 39.0     7.86842
# 40.0     6.91781
# 42.0     2.34783
# 43.0     3.03571
# 44.0       6.125
# 45.0     6.06667
# 47.0     7.11111
# 48.0     6.58333
# 49.0         6.4
# 51.0     8.14286
# 52.0        6.75
# 53.0     5.08333
# 54.0     6.42857
# 55.0        26.5
# 56.0     11.5714
# 57.0        7.25
# 58.0     6.76923
# 59.0         6.4
# 60.0        6.25
# 61.0       7.625
# 62.0           7
# 63.0     6.36364
# 64.0     6.16667
# 65.0         7.5
# 66.0     5.92308
# 67.0     5.55556
# 69.0        12.4
# 70.0          10
# 71.0     8.90909
# 72.0     4.35714
# 73.0      5.0625
# 74.0     5.61111
# 75.0           6
# 76.0           6
# 77.0           6
# 78.0       8.375
# 79.0      6.4375
# 80.0         7.5
# 81.0     7.09091
# 82.0      6.0625
# 83.0         8.2
# 84.0     7.69231
# 85.0         3.5
# 86.0     5.15789
# 88.0          13
# 89.0         9.3
# 91.0     6.76923
# 92.0     8.85714
# 93.0     7.66667
# 94.0           5
# 95.0     5.27778
# 96.0      4.0625
# 97.0      4.7619
# 98.0     10.1667
# 99.0        10.4
# 100.0    10.3333
# 101.0          9
# 102.0    8.33333
# 103.0         11
# 105.0    5.46667
# 106.0    5.68235
# 107.0    10.8333
# 108.0    8.63636
# 109.0       8.25
# 110.0          8
# 111.0    5.41667
# 112.0    5.47368
# 113.0        6.4
# 114.0    7.08333
# 116.0        9.1
# 117.0        9.1
# 119.0    4.27778
# 121.0        8.5
# 122.0    7.53846
# 123.0     4.3125
# 124.0    4.61905
# 127.0        1.8
# 129.0    6.69231
# 131.0    4.66667
# 132.0    9.83333
# 133.0          8
# 135.0    7.11111
# 136.0      5.625
# 137.0    11.3333
# 138.0    8.66667
# 140.0       11.5
# 141.0    7.14286
# 144.0          7
# 146.0    7.53846
# 149.0    7.61538
# 151.0    7.69231
# 152.0    6.53333
# 153.0         10
# 154.0    5.68421
# 155.0    4.11538
# 156.0          6
# 157.0    5.90909
# 158.0    4.03846
# 159.0    8.07692
# 160.0    8.07692
# 165.0    6.07692
# 168.0    10.1429
# 169.0    7.07143
# 170.0    11.8333
# 171.0       8.25
# 172.0     6.4375
# 174.0      3.375
# 175.0    6.44444
# 176.0    6.44444
# 177.0    6.44444
# 178.0    7.31707
# 179.0    6.88525
# 180.0    6.59341
# 181.0    6.41509
# 182.0          6
# 183.0    7.06667
# 184.0        6.9
# 185.0     6.5625
# 186.0    7.92308
# 187.0    6.98276
# 188.0    6.84615
# 189.0       6.28
# 190.0    6.23077
# 191.0    6.23529
# 192.0    6.14286
# 193.0    4.88235
# 194.0    4.36667
# 195.0       4.42
# 196.0      6.625
# 197.0    7.09091
# 198.0       6.25
# 199.0    5.57143
# 46.0     6.29412
# 200.0        4.4
# 201.0       3.68
# 25.0       10.25
# 36.0        4.36
# 41.0     2.33333
# 202.0          7
# 203.0    7.36364
# 205.0          8
# 206.0    7.23077
# 207.0    5.09091
# 208.0    5.21429
# 209.0    5.55556
# 50.0         6.4
# 211.0    3.57143
# 212.0        4.1
# 214.0    5.85714
# 68.0     5.55556
# 215.0    7.14286
# 216.0    6.18182
# 217.0          6
# 218.0    6.54545
# 220.0          6
# 221.0    5.66667
# 222.0          6
# 224.0    3.81818
# 225.0    4.52632
# 161.0    8.07692
# 162.0    5.52632
# 226.0       6.75
# 87.0     5.15789
# 228.0       7.25
# 230.0          7
# 232.0    2.13158
# 233.0        6.5
# 234.0        5.8
# 235.0        6.2
# 236.0       4.15
# 237.0    6.61538
# 104.0        6.8
# 239.0          5
# 240.0          5
# 241.0    6.61538
# 142.0    7.14286
# 242.0      25.25
# 243.0       6.25
# 244.0    7.81818
# 246.0        5.5
# 247.0    5.55556
# 248.0       6.25
# 249.0        8.2
# 250.0          5
# 251.0        4.5
# 253.0    6.90909
# 254.0    8.57143
# 255.0        6.4
# 256.0    7.33333
# 258.0    7.15385
# 259.0    7.15385
# 260.0    7.33333
# 261.0    6.66667
# 134.0        7.2
# 262.0    3.66667
# 263.0    5.55556
# 166.0    6.05882
# 264.0    6.36986
# 265.0    4.54545
# 115.0          6
# 118.0        9.1
# 143.0    6.77778
# 145.0          8
# 148.0    8.11111
# 266.0    5.15789
# 128.0    2.11765
# 267.0    6.44444
# 268.0    5.04348
# 269.0        5.8
# 270.0          6
# 271.0    5.85714
# 272.0          6
# 273.0    6.41509
# 274.0    6.41509
# 275.0          6
# 276.0       7.75
# 277.0        8.1
# 278.0    7.57143
# 279.0    6.88889
# 280.0       6.75
# 281.0      6.625
# 282.0        6.2
# 283.0    5.78571
# 284.0       5.35
# 285.0    6.28571
# 286.0          6
# 287.0    6.31579
# 288.0    5.38462
# 289.0    4.33333
# 290.0        4.1
# 291.0    6.41667
# 292.0        4.1
# 293.0    6.41667
# 294.0        5.5
# 295.0    5.66667
# 296.0          6
# 297.0        5.5
# 298.0    4.85714
# 299.0    5.33333
# 300.0       6.75
# 301.0    7.16667
# 302.0       6.75
# 303.0    7.16667
# 304.0    7.07143
# 305.0    7.31579
# 306.0    7.61765
# 308.0      6.725
# 309.0    5.91429
# 310.0    4.91667
# 311.0    7.66667
# 312.0    4.66667
# 313.0        5.5
# 314.0    4.46667
# 315.0    8.58065
# 316.0    7.47541
# 317.0        236
# 318.0       3.75
# 319.0    4.28571
# 320.0    4.61538
# 321.0    3.29167
# 322.0    3.29167
# 210.0        3.8
# 323.0       12.5
# 325.0        5.2
#           ...
# 509.0    6.85366
# 510.0    6.96875
# 511.0       6.32
# 512.0       6.64
# 513.0       6.32
# 514.0       6.64
# 515.0       6.32
# 516.0       6.64
# 517.0    3.84211
# 518.0    4.19828
# 519.0       5.28
# 520.0    5.77419
# 521.0      5.975
# 522.0    6.55556
# 523.0    6.62667
# 524.0    5.09091
# 525.0    5.57143
# 526.0    5.94118
# 527.0    5.69091
# 528.0    6.34328
# 529.0    5.46667
# 530.0    4.61818
# 531.0    4.32039
# 532.0    4.06667
# 533.0    4.76471
# 534.0    4.80952
# 535.0       5.88
# 536.0       5.12
# 537.0    4.75238
# 538.0      3.875
# 539.0        6.2
# 540.0    6.88889
# 541.0    6.90909
# 542.0    6.53333
# 543.0    8.66667
# 544.0          9
# 545.0    7.91667
# 546.0          7
# 547.0          8
# 548.0    6.22222
# 549.0    6.85714
# 550.0    6.57143
# 551.0       5.84
# 552.0       5.85
# 553.0    5.35789
# 554.0        4.5
# 555.0    4.57143
# 555.1    5.14286
# 556.0    6.14667
# 557.0        6.5
# 558.0    6.78571
# 559.0       6.96
# 560.0    7.50769
# 561.0    6.80556
# 562.0    7.97368
# 563.0    8.32759
# 564.0    6.57407
# 565.0    6.68919
# 566.0    7.29091
# 567.0       7.56
# 568.0       6.58
# 569.0       6.05
# 570.0       8.25
# 571.0        8.5
# 572.0    5.45455
# 573.0    6.26667
# 574.0    6.44444
# 575.0        6.5
# 576.0          7
# 577.0    6.44444
# 578.0    5.69231
# 579.0    4.45455
# 580.0    4.91935
# 581.0    6.30667
# 582.0    8.47222
# 583.0     7.7451
# 584.0    7.53521
# 585.0    5.58333
# 586.0     5.9375
# 587.0    7.78182
# 588.0        6.3
# 589.0    7.07143
# 590.0    4.26087
# 591.0    4.07018
# 592.0    6.09091
# 593.0        4.8
# 594.0    2.84848
# 595.0       6.38
# 596.0    6.74286
# 597.0    6.93182
# 598.0    6.60811
# 599.0        7.5
# 600.0    7.33333
# 601.0    8.66667
# 602.0    7.85714
# 603.0    6.23077
# 604.0    6.05882
# 605.0    6.09091
# 606.0    6.46667
# 607.0        5.5
# 608.0    6.16667
# 609.0    8.66667
# 610.0    6.95652
# 611.0    6.21212
# 612.0    7.10526
# 613.0    5.54545
# 614.0    5.10526
# 615.0    6.92857
# 616.0        6.1
# 617.0     6.1875
# 618.0     4.3211
# 619.0    7.77778
# 620.0    7.84615
# 621.0     6.2987
# 622.0    5.13559
# 623.0    5.42697
# 624.0    7.55556
# 625.0    7.53846
# 626.0    5.15789
# 627.0          5
# 628.0        5.1
# 629.0    5.28571
# 630.0    4.63636
# 631.0    5.69412
# 632.0    8.34483
# 633.0    5.76923
# 634.0    5.83333
# 635.0    6.52174
# 636.0    6.54545
# 637.0    6.47059
# 638.0    6.37363
# 639.0    6.37363
# 640.0    6.37363
# 641.0    7.34177
# 642.0    7.34177
# 643.0        6.8
# 644.0        6.8
# 645.0    6.74157
# 646.0       5.28
# 647.0    6.37363
# 648.0          6
# 648.1          6
# 649.0     8.4507
# 650.0    5.58929
# 651.0    6.63934
# 652.0    6.02273
# 653.0      7.675
# 654.0     6.9322
# 655.0       7.12
# 656.0    7.65854
# 657.0        7.5
# 658.0    7.36111
# 659.0    6.23684
# 660.0    4.97647
# 661.0    6.17778
# 662.0    6.16129
# 663.0    6.39744
# 664.0    5.26316
# 665.0    4.73333
# 666.0     5.1375
# 667.0    5.95161
# 668.0    5.89535
# 669.0    6.88636
# 670.0    6.87037
# 671.0    7.07692
# 672.0    5.30303
# 673.0    4.31707
# 674.0    5.19403
# 675.0    5.21053
# 676.0    6.29333
# 677.0    5.72581
# 678.0     6.2973
# 679.0    7.22222
# 680.0    7.59322
# 681.0    8.66667
# 682.0    4.37179
# 683.0    4.57426
# 684.0        5.5
# 685.0    5.85366
# 686.0    5.43396
# 687.0    5.60465
# 688.0    7.28571
# 689.0    6.94444
# 690.0        6.4
# 691.0        7.6
# 692.0        6.6
# 693.0    7.04225
# 694.0    6.56818
# 695.0    7.75806
# 696.0    6.24138
# 697.0    6.35366
# 698.0     4.7013
# 699.0    4.23577
# 700.0    5.52632
# 701.0    6.41026
# 702.0    6.43284
# 703.0         10
# 704.0    6.66667
# 705.0    6.64706
# 706.0    6.66667
# 707.0    8.24561
# 708.0    7.18605
# 709.0    5.57647
# 710.0    7.61364
# 711.0    8.98182
# 712.0    5.52727
# 713.0    5.41053
# 714.0      6.125
# 715.0    6.29412
# 716.0    5.39683
# 717.0    5.39683
# 718.0    5.55556
# 719.0         12
# 720.0        7.5
# 720.0        8.5
# 721.0        7.5
# 722.0    4.70588
# 723.0    5.38462
# 724.0    6.79487
# 725.0    7.11111
# 726.0    6.46154
# 727.0    5.57895
# 728.0        6.4
# 729.0          7
# 730.0      6.625
# 731.0    7.57143
# 732.0    6.45455
# 733.0     6.0625
# 734.0    5.27083
# 735.0       4.75
# 736.0    6.38298
# 737.0    7.01754
# 738.0    6.49351
# 739.0    7.19149
# 740.0    4.92784
# 741.0    6.34667
# 742.0        7.6
# 743.0    7.73333
# 744.0    6.22222
# 745.0    6.49333
# 745.1    5.72941
# 746.0    3.88889
# 746.1    13.7778
# 747.0        6.1
# 748.0        9.9
# 749.0        5.5
# 750.0          5
# 751.0    7.07895
# 752.0    6.67647
# 753.0       6.25
# 754.0    6.85714
# 755.0      7.125
# 756.0       6.75
# 757.0    6.66667
# 758.0    7.05882
# 759.0    4.85714
# 760.0    4.16667
# 761.0          5
# 762.0    5.57692
# 763.0    7.08333
# 764.0     9.5098
# 765.0    5.44444
# 766.0        4.9
# 767.0        9.2
# 768.0    7.06667
# 769.0    5.81818
# 770.0    5.64706
# 771.0    7.45455
# 772.0    5.62105
# 773.0          6
# 774.0    7.33333
# 774.1    8.33333
# 775.0    7.38462
# 776.0    8.08333
# 777.0    6.69231
# 778.0    8.65455
# 779.0    6.98529
# 780.0    6.21795
# 781.0    7.38571
# 782.0    6.66667
# 783.0    7.63636
# 784.0          8
# 785.0    8.14286
# 786.0    8.14286
# 787.0    8.14286
# 788.0    8.14286
# 789.0    4.65116
# 790.0    9.30233
# 791.0     4.9635
# 792.0     4.9635
# 793.0    5.22936
# 794.0     5.3271
# 795.0    8.02817
# 796.0    6.86747
# 797.0    5.87629
# 798.0    9.66102
# 799.0    2.55605
# 800.0    6.18557
# 801.0        7.5
# 802.0    6.66667
# Length: 820, dtype: object

# %% [markdown]
# ### Universal functions
# Universal functions can operate on entire dataframes or slices of dataframes. They return a dataframe copy with the same index as the original dataframe. Numpy universal functions can be applied to any numeric dataframe or slice.

# %%
import numpy as np

# %%
pokedex_df.loc[:, 'HP':'Total'].astype(float, inplace=True)
np.log(pokedex_df.loc[:,'HP':'Total']) # take natural log of all stats
# again, these functions operate on each element independently, and return a dataframe with the same index and size of input

# %% [markdown]
# ### .apply()
# You can apply an arbitrary function to each row or column using the `.apply()` function.
#
# If you pass the name of a function (e.g. np.mean, or the name of any function you've written), you can apply it to either each column, or each row using `.apply()`

# %%
pokedex_df.loc[:,'Atk':'Speed'].apply(np.mean) # applies the function np.mean() to each column
# Out:
# Atk      76.115854
# Def      71.919512
# SpAtk    69.957317
# SpDef    70.370732
# Speed    66.140244
# dtype: float64

# %%
pokedex_df.loc[:,'Atk':'Speed'].apply(np.mean, axis=1) # if you wanted to apply it to each row instead, use the argument axis=1

# %% [markdown]
# The above example is actually a bit unnecessary. There are several built-in functions in dataframes, including a `.mean()` which has the same functionality.

# %%
pokedex_df.loc[:,'Atk':'Speed'].mean()

# %%
pokedex_df.loc[:,'Atk':'Speed'].mean(axis=1) #applies per row

# %% [markdown]
# Most [descriptive statistics](https://pandas.pydata.org/pandas-docs/stable/reference/frame.html#computations-descriptive-stats) (median, mode, standard deviation, count, quantile, etc) have built-in functions. Where `.apply()` really shines, however, is for applying custom functions.
#
# To show that functionality, let's take a sidebar and talk about lambda functions.

# %% [markdown]
# #### Lambda functions
# Sometimes you want to define a function, but you don't want to write a whole
# ```
# def functionname(inputs):
#   ...
#   return outputs
# ```
#
# In those situations, you can write lambda (anonymous) functions. The syntax for lambda functions is:
#
# ```
# functionname = lambda x: operations_on_x
# ```
#
# For example, if you wanted to write a function that squares the input, you could write:

# %%
square_it = lambda x: x**2 # recall that ** is exponentiation in python, this function returns the square of the input
for num in range(10):
  print(square_it(num))

# %% [markdown]
# This is especially useful if some function takes another function as an argument, like panda's `.apply()`
#
# The typical usage of `.apply()` is:
#
# `dataframe_obj.apply(functionname)`, which calls `functionname` on each column of `dataframe_obj`
#
# However, you can replace `functionname` with a lambda function. In this example, we use the following lambda function:
#
# ```lambda col: [np.min(col), np.max(col)]```
#
# The word `col` represents the argument, and then to the right of the colon, we return a list with two elements: the minimum and maximum values of the column

# %%
pokedex_df.loc[:,'HP':'Total'].apply(lambda col: [np.min(col), np.max(col)])

# %% [markdown]
# the above can be expanded into a dataframe:

# %%
pokedex_df.loc[:,'HP':'Total'].apply(lambda col: [np.min(col), np.max(col)], result_type='expand')

# %% [markdown]
# ### Groupby
# Dataframes can be grouped by column values, and operations can be applied to each group

# %%
pokedex_df.groupby(['Type I','Type II'])['Total'].count()

# %%
pokedex_df.groupby(['Type I','Type II'])['Total'].apply(lambda col: [np.min(col), np.max(col)])

# %% [markdown]
# # Intermediate Pandas
# In this section, we'll cover some more advanced topics in pandas, including
# *   Multi-indexing
# *   Joining and merging
# *   Pivot tables
#
# We'll be introducing some more data to play with, based on state populations over time

# %%
state_populations_url = 'https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-population.csv'
state_abbrevs_url = 'https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-abbrevs.csv'
state_areas_url = 'https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-areas.csv'

state_areas = pd.read_csv(state_areas_url, index_col='state')
state_areas.head() # just print top 5 rows

# %%
state_abbrevs = pd.read_csv(state_abbrevs_url)
state_abbrevs.head()

# %%
state_populations = pd.read_csv(state_populations_url) 
state_populations.head(10) #print first 10 rows

# %% [markdown]
# Note that the state populations are just listed by abbreviations. It may be useful to include the state names as a column in a table. We have this information in the `state_abbrevs` table. We'd like to merge it with the population data.
#
# The function `pd.merge()` merges two dataframes using set logic.

# %%
merged = pd.merge(state_populations, state_abbrevs, how='outer',
                 left_on='state/region', right_on='abbreviation') # state/region matches abbreviation
# The arguments left_on and right_on specify what columns to join on. It looks for matching values in each dataframe
# and fills in the additional columns of the merged dataframe based on the matching data
# The 'how' argument specifies what kind of join. Outer means keep all entries even if one does not show up in the other
# conversely, 'inner' discards rows where a corresponding entry does not exist in the other
merged.head()

# %%
# we can also drop the unnecessary extra abbreviation column now
merged = merged.drop('abbreviation', axis=1) #drop from columns
merged.head()

# %%
# we can check if there were any missing values
merged.isnull().any()

# %%
# let's see where the issue is. What entries are missing population entries?
merged.loc[merged['population'].isnull()]

# %%
# what about where there's no state entry?
merged.loc[merged['state'].isnull(), 'state/region']

# %%
# more concicely, we can use .unique() to only see the unique values
merged.loc[merged['state'].isnull(), 'state/region'].unique()

# %%
# We can fix this easily
merged.loc[merged['state/region'] == 'PR', 'state'] = 'Puerto Rico'
merged.loc[merged['state/region'] == 'USA', 'state'] = 'United States'
merged.isnull().any()

# %%
# now let's combine the data with the area data
final = pd.merge(merged, state_areas, on='state', how='left') # inner join --> overlapping rows
final.head()

# %%
# we can use the .query() syntax to search for specific data
data2010 = final.query("year == 2010 & ages == 'total'") # specify column name 
data2010.set_index('state', inplace=True) # equivalent to data2010 = data2010.set_index('state')
data2010.head()

# %%
# Let's compute the density of each state and then sort by density
density = data2010['population'] / data2010['area (sq. mi)']
density.sort_values(ascending=False, inplace=True)
density.head()

# %%
density.tail()

# %% [markdown]
# ### Exercises
# Compute the total population of the entire united states, as well as its population density for each year.
#
# What year saw the biggest change in population for the US as a whole?
#
# Which states had the biggest percentage change in population in that year?

# %%
USA_data = final.query("state == 'United States' & ages == 'total'")
area_data = final.query("year == '2010' & ages == 'total'")
US_total_area = area_data['area (sq. mi)'].sum()
USA_data['area (sq. mi)'] = US_total_area
USA_data['population density'] = USA_data['population']/USA_data['area (sq. mi)']


USA_data

# %%
USA_data = USA_data.sort_values(['year'])
population = USA_data['population']

greatest_change = population.diff().max()

greatest_change

# %%
final

# %% [markdown]
# ## Multiindexing
# You can use multiple columns to define an index, as long as each row has a unique combination of values within those columns. In the following example, we will use the columns "state/region", "year", and "ages" of the population dataframe as an index

# %% [markdown]
# We use the `.set_index(['column_name1', 'column_name2, ...])'` command to create a multiindex from existing columns.
#
# Note that many operations require a multiindex to be sorted, so we also call `.sort_index()` on the dataframe. Also, `.set_index()` and `.sort_index()` return a _copy_ of the dataframe, so we assign the output to itself to update the value.

# %%
# set index to use multiple columns
final = final.set_index(['state/region','year','ages']) # overwrite old version with new version with index set
final = final.sort_index() # replace itself with a version with a sorted index
final.tail(10) # print last 10 entries

# %% [markdown]
# ### Stacking and unstacking
# Columns can also have multiple levels. In fact, the columns can be thought of as just another index that runs horizontally. This is most easily illustrated by stacking, unstacking, and transposing.
#
# You can convert a level of the row index to a column level using the `.unstack()` command. Conversely, `.stack()` moves a column level to the index

# %%
unstacked = final.unstack(level='ages') # you can unstack by level name; this moves the 'ages' categories into the column index
unstacked

# %%
restacked = unstacked.stack('ages', dropna=False) # stacks the column level back into the row index
# by default, .stack() omits entries with NaN. If you want to preserve the NaN entries, use the option dropna=False
restacked == final # just like the original state_populations dataframe

# %%
final.unstack(level=0) # you can also unstack using integer levels. Here we unstacked level 0, corresponding to state/region

# %% [markdown]
# You can switch the row and column index using the transpose function `.T`

# %%
final.unstack(level=0).T

# %% [markdown]
# ### Pivoting
# Pivoting is another advanced way to transform data. It creates a new dataframe using the values of columns as `index` and `column` values.
#
# You can then aggregate using `aggfunc` the elements of another column, which becomes the `values` of this new dataframe.

# %%
# let's create a table which lists all pokemon for given type combinations
pokedex_df.pivot_table(values='Pokemon', # line breaks within parentheses automatically continue onto next line
                       index='Type I', # values of Type I become index entries
                       columns='Type II', # likewise Type II become columns
                       aggfunc=lambda x:", ".join(x)).fillna('') # the lambda function here just joins a list of strings using a comma
                      # we also fill nan values with empty string for aesthetics

# %%
# compute the average stats for each type combination
pokedex_df.pivot_table(values='Total',
                       index='Type I', 
                       columns='Type II', 
                       aggfunc=np.mean).fillna('')

# %%
# You can compute multiple aggregations on multiple columns by passing a dict
# into the aggfunc argument: aggfunc={'column_name':[list_of_function_names]}
# Note that in this case, the 'value' argument is ignored
pokedex_df.pivot_table(index='Type I', 
                       columns='Type II', 
                       aggfunc={'Total':[np.mean,np.std], 
                                'Atk':[np.mean,np.std]}).fillna('')

# %% [markdown]
# # Exercise
# Using this data (or any other data you're interested in and you find online), put together an analysis using pandas that investigates an interesting question.
#
# It can be serious or silly. Like "Do states with higher population density tend to vote democratic?" (you'd need to pull additional data for this) or "Do pokemon whose names start with the letter D have better stats than those who start with F?"
#
# We'll ask some volunteers to present their analysis at the end
